# %% [markdown]
# # algoritmo_deidentificacion_regex
#
# Este script permite deidentificar texto libre proveniente de registros clínicos electrónicos.
#
# 0. Configura el ambiente.
# 1. Carga los datos (input)
# ~~Chequea la sanidad de los datos (backlog)~~
# 2. Preprocesa los textos ("limpieza")
# ~~Parametriza el modelo de deidentificación a aplicar (cambaa, regex, regex+spacy)~~
# ~~Chequea la cantidad de textos y de ser necesario, particiona la tarea.~~
# 3. Parametriza el output deseado (texto censurado, resaltado, reemplazado, clasificado).
# 4. Procesa los textos (aplica las reglas).
# 5. Devuelve los datos procesados (output)
#
#
# ## Lista de entidades
#
# - PACIENTE: PERSONA
# - EDAD:
# - GÉNERO: no se detecta.
# - FAMILIAR: PERSONA
# - ~~DRX~~
# - ~~FECHA~~
# - ~~EFECTOR~~
# - ~~INSTITUCIÓN~~: escolares.
# - ~~DIRECCIÓN~~
# - ~~ZONA~~
# - ~~PAÍS~~
# - ~~NÚM_TELÉFONO~~
# - ~~CORREO_ELECTRÓNICO~~
# - ~~NÚM_DNI~~
# - ~~NÚM_CUIT_CUIL~~
# - ~~PASAPORTE~~
# - ~~MATRICULA~~
# - ~~EPOF:~~ queda pendiente estrategia para reemplazar por el nombre de la EPof entre <>
# - ~~PATENTE~~: no se cuenta con ejemplos (no se detectaron en la base de datos).
# - NÚM_SERIE_DISPOSITIVOS: no se detectan.
# - ~~OTROS_NÚM~~: no se detectan.
# - DUDOSOS: no se detectan.

# %% [markdown]
# ## 0. Configura el ambiente

# %%
import pandas as pd
import os
import re

# This code allows to view full lenght text
pd.set_option("display.max_colwidth", None)

# %%
def remove_accents(text: str)  -> str:
    """Removes common accent characters, converts to lowercase."""
    new = re.sub(r'[àáâãäå]', 'a', text)
    new = re.sub(r'[èéêë]', 'e', new)
    new = re.sub(r'[ìíîï]', 'i', new)
    new = re.sub(r'[òóôõö]', 'o', new)
    new = re.sub(r'[ùúûü]', 'u', new)
    new = re.sub(r'[ÀÁÂÃÄÅ]', 'A', new)
    new = re.sub(r'[ÈÉÊË]', 'E', new)
    new = re.sub(r'[ÌÍÎÏ]', 'I', new)
    new = re.sub(r'[ÒÓÔÕÖ]', 'O', new)
    new = re.sub(r'[ÙÚÛÜ]', 'U', new)
    return new

# %% [markdown]
# ## 1. Carga los datos (input)

# %%
INPUT_DIR = '/home/usuario/Documentos/TrabajoEspecial/Datasets/SPG/integral'
TEXT_COLUMN = 'informes'

# %%
# Obtener lista de archivos .txt
txt_files = sorted([f for f in os.listdir(INPUT_DIR) if f.endswith(".txt")])

# Mostrar los archivos encontrados
print(txt_files[:5])

data = []

for txt_file in txt_files:
    txt_path = os.path.join(INPUT_DIR, txt_file)
    
    with open(txt_path, 'r', encoding='utf-8') as f:
        texto = f.read()
    
    data.append({
        TEXT_COLUMN: texto
    })

documents = pd.DataFrame(data)

# Mostrar primeras filas
print(documents.head(2))
# Out:
# ['000096468.txt', '001956719.txt', '002769099.txt', '003666606.txt', '004954246.txt']
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      informes
# 0                                                                                                                                                                         Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1  Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.

# %% [markdown]
# ## 2. Preprocesa los textos ("limpieza")

# %%
# Genera una nueva columna con el texto preprocesado
documents.rename(columns={TEXT_COLUMN: 'original'}, inplace=True)
documents['preprocessed'] = documents['original'].apply(remove_accents)
# Apply further transformations if necessary

# Remove nan
documents = documents.dropna()
documents.head(2)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      original  \
# 0                                                                                                                                                                         Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1  Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  preprocessed
# 0                                                                                                                                                                         Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 960 66 89 48\nTelefono movil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1  Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.

# %% [markdown]
# ## 3. Parametriza el output deseado
#
# Ejemplos de outputs posibles:
#
# 1. Texto resaltado: La usuaria <María>
# 2. Texto censurado: La usuaria xxxx
# 3. Texto clasificado: La usuaria PACIENTE

# %%
from enum import Enum

class AnonymizationMode(Enum):
    HIGHLIGHT = 1
    CENSOR = 2
    REPLACE = 3

# Ingresar el tipo de output deseado
OUTPUT_TYPE = AnonymizationMode.REPLACE

ILLEGAL_CHAR_REGEX = r"[\/<>\:\"\\|\?\*\+\[\]\(\)]"

# %%
class RegexAnnonimizer(object):
    """
    The RegexAnonymizer class is designed to find and replace matches of a given regular expression
    within a text string, according to a specified output type. The purpose of this class is to 
    anonymize text by either highlighting, censoring, or replacing specific patterns in the text.

    Attributes:
        regex (str): The regular expression pattern used to identify the text to be anonymized.
        output_type (AnonymizationMode): The mode of anonymization, determining the action taken on matches.
        category (str): The text used for replacement when using the REPLACE output type.
        verbose (bool): Whether to print the replaced text. Useful for debug.

    Methods:
        anonymize(text: str) -> str:
            Anonymizes the input text based on the provided regular expression and output type.
            Depending on the output type, it either highlights, censors, or replaces the matched text.

    Output Types:
        1 (AnonymizationMode.HIGHLIGHT): Wraps the matched text with angle brackets.
            Example: "The user Maria" -> "The user <Maria>"
        2 (AnonymizationMode.CENSOR): Replaces the matched text with 'x' characters, maintaining the length of the original text.
            Example: "The user Maria" -> "The user xxxxx"
        3 (AnonymizationMode.REPLACE): Replaces the matched text with the provided replacement text.
            Example: "The user Maria" -> "The user PACIENTE"
    """
    def __init__(self,
                 content_regex: str,
                 output_type: AnonymizationMode = AnonymizationMode.REPLACE,
                 category: str = None,
                 re_flags: re.RegexFlag = None,
                 verbose: bool = False):
        """
        Initializes the RegexAnonymizer instance with the specified parameters.
        
        Args:
            content_regex (str): The regular expression pattern used to identify the text for anonymization.
            output_type (AnonymizationMode, optional): The mode of anonymization, determining the action taken on matches.
                Default is AnonymizationMode.REPLACE.
            category (str, optional): The text used for replacement when using the REPLACE output type. Required
                if output_type is AnonymizationMode.REPLACE.
            re_flags (re.RegexFlag, optional): flags to pass to re.compile when compiling patterns. Default is None.
            verbose (bool, optional): If True, enables verbose output, providing details about the anonymization
                process. Default is False.
        
        Raises:
            ValueError: If output_type is not an instance of AnonymizationMode.
            ValueError: If output_type is AnonymizationMode.REPLACE and category is not provided.
        """
        if not isinstance(output_type, AnonymizationMode):
            raise ValueError('`output_type` must be an instance of `AnonymizationMode`.')
        self.output_type = output_type
        if re_flags is None:
            self.content_regex = re.compile(content_regex)
        else:
            self.content_regex = re.compile(content_regex, re_flags)
        if self.output_type == AnonymizationMode.REPLACE and not category:
            raise ValueError('When `output_type` is `AnonymizationMode.REPLACE`, you need to provide '
                             'a valid string value for `category`.')
        self.category = category
        self.verbose = verbose

    def _replace_match(self, match: re.Match) -> str:
        """Replaces all matches in string according to self.output_type."""
        matched_name = match.group(0)
        if self.verbose:
            # TODO replace with logger
            print('Replacing', matched_name)

        if self.output_type == AnonymizationMode.HIGHLIGHT:
            return f"<{matched_name}>"
        if self.output_type == AnonymizationMode.CENSOR:
            return "x" * len(matched_name)
        if self.output_type == AnonymizationMode.REPLACE:
            return self.category
        raise ValueError('Output type not suported', self.output_type)

    def _post_process(self, anonymized_text: str) -> str:
        """Collapse consecutive replacements into a single occurrence of category."""
        if self.output_type == AnonymizationMode.REPLACE:
            anonymized_text = re.sub(r'({})(\s+\1)+'.format(self.category), r'\1', anonymized_text)
        return anonymized_text

    def anonymize(self, text: str) -> str:
        """Anonymizes text by replacing content matches, according to output type."""
        # Replace the matched names with the desired output
        anonymized_text = self.content_regex.sub(self._replace_match, text)
        return self._post_process(anonymized_text)

class PrefixRegexAnnonimizer(RegexAnnonimizer):
    """
    A specialized anonymizer that detects and replaces text based on a prefix and content pattern.
    
    This class inherits from RegexAnonymizer and extends its functionality by allowing two regular
    expressions to be specified: one for the prefix and another for the content. If the content is 
    found immediately following the prefix, it is subject to anonymization according to the specified 
    output type. This is particularly useful for identifying and anonymizing structured information, 
    
    such as phone numbers, addresses, or any other context-specific data that is preceded by a 
    particular keyword or phrase.
    
    Attributes:
        prefix_regex (str): A regular expression pattern to identify the prefix text.
        content_regex (str): A regular expression pattern to identify the content to be anonymized.
        output_type (AnonymizationMode): Specifies how the matched content should be anonymized.
        category (str): The replacement text used when the output_type is AnonymizationMode.REPLACE.
        verbose (bool): Determines if detailed information about the anonymization process should be printed.
    
    Methods:
        anonymize(text: str) -> str:
            Processes the input text and replaces occurrences of content following the specified 
            prefix according to the anonymization rules defined by the output_type.
    """
    def __init__(self,
                 prefix_regex: str,
                 content_regex: str,
                 output_type: AnonymizationMode = AnonymizationMode.REPLACE,
                 category: str = None,
                 re_flags: re.RegexFlag = None,
                 verbose: bool = False):
        """
        Initializes the PrefixRegexAnnonimizer instance with the specified parameters.
        
        Args:
            prefix_regex: (str): The regular expression pattern used to identify the prefix before the text to anonymize.
            content_regex: (str): The regular expression pattern used to identify the text for anonymization.
            output_type (AnonymizationMode, optional): The mode of anonymization, determining the action taken on matches.
                Default is AnonymizationMode.REPLACE.
            category (str, optional): The text used for replacement when using the REPLACE output type. Required
                if output_type is AnonymizationMode.REPLACE.
            re_flags (re.RegexFlag, optional): flags to pass to re.compile when compiling patterns. Default is None.
            verbose (bool, optional): If True, enables verbose output, providing details about the anonymization
                process. Default is False.
        
        Raises:
            ValueError: If output_type is not an instance of AnonymizationMode.
            ValueError: If output_type is AnonymizationMode.REPLACE and category is not provided.
        """
        super().__init__(
            content_regex=content_regex,
            output_type=output_type,
            category=category,
            verbose=verbose,
            re_flags=re_flags
        )
        if re_flags is None:
            self.prefix_regex = re.compile(prefix_regex)
            self._full_regex = re.compile(fr'(?P<prefix>{prefix_regex})\s*(?P<content>{content_regex})')
        else:
            self.prefix_regex = re.compile(prefix_regex, re_flags)
            self._full_regex = re.compile(fr'(?P<prefix>{prefix_regex})\s*(?P<content>{content_regex})', re_flags)
    
    def _replace_if_prefix(self, match: re.Match):
        """Replace matches to self. of regex only if matches self._full_regex.""" 
        # Check if a phone-related term precedes the number, and then replace
        return match.group('prefix') + ' ' + self.content_regex.sub(self._replace_match, match.group('content'), count=1)

    def anonymize(self, text: str) -> str:
        """Anonymizes text by replacing content matches that follow prefix matches, according to output type."""
        # Replace the matched names with the desired output
        anonymized_text = self._full_regex.sub(self._replace_if_prefix, text)
        return self._post_process(anonymized_text)

# %% [markdown]
# ## 4. Procesa los textos (aplica las reglas).

# %% [markdown]
# ### FECHA

# %%
import datetime
## Expresiones regulares para FECHA
regexp_day = r'(\d{1,2}[\/ |-](\d{1,2}|Enero|Ene|Febrero|Feb|Marzo|Mar|Abril|Abr|Mayo|May|Junio|Jun|Julio|Jul|Agosto|Ago|Septiembre|Sep|Octubre|Oct|Noviembre|Nov|Diciembre|Dic)[\/ |-]\d{2,4})'
regexp_month = r'\b(Enero|Ene|Febrero|Feb|Marzo|Mar|Abril|Abr|Mayo|May|Junio|Jun|Julio|Jul|Agosto|Ago|Septiembre|Sep|Octubre|Oct|Noviembre|Nov|Diciembre|Dic)\b'
regexp_year = r'\b(19[89][0-9]|20[0-4][0-9]|{})\b'.format(datetime.date.today().year)
regexp_date = '|'.join([regexp_day, regexp_month, regexp_year])

date_anonymizer = RegexAnnonimizer(
    content_regex=regexp_date,
    category='XFECHAX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE
)
# Ejemplos:
print(date_anonymizer.anonymize("Se programa turno para dìa 21/03/2021. Jueves 17:00hrs, 31 de Marzo."))
print(date_anonymizer.anonymize("Se programa turno para octubre. Control 2023"))
# Out:
# Se programa turno para dìa XFECHAX. Jueves 17:00hrs, 31 de XFECHAX.
# Se programa turno para XFECHAX. Control XFECHAX

# %%
documents['anonymized'] = documents['preprocessed'].apply(date_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XFECHAX', case=False)].head(2)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      original  \
# 0                                                                                                                                                                         Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1  Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  preprocessed  \
# 0                                                                                                                                                                         Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 960 66 89 48\nTelefono movil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1  Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            anonymized
# 0                                                                                                                                                                         Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 9XFECHAX 48\nTelefono movil: +34 6XFECHAX 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1  Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 6XFECHAX 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.

# %% [markdown]
# ### NUM_TELEFONO

# %%
## Expresión regular para NUM_TELEFONO
regexp_phone_prefix =  '(tel[ée]fono|(tel(?![aA-zZ]))|celular|(cel(?![aA-zZ])))\s*(?:n\s*[\.\°]|.)?\s*[:\.]?'
regexp_phone_number = '[0-9]+'
separators = r'\s*[:\.]?\s*'

phone_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_phone_prefix,
    content_regex=regexp_phone_number,
    re_flags=re.IGNORECASE,
    category='XTELEFONOX',
    output_type=OUTPUT_TYPE,
)

print(phone_anonymizer.anonymize("Paciente indica llamar a tel 3514790943 sin poder comunicarse."))
print(phone_anonymizer.anonymize("Paciente indica llamar a telefono n° 3514790943 sin poder comunicarse."))
print(phone_anonymizer.anonymize("Rescinde celular durante 400 dias"))
print(phone_anonymizer.anonymize("Proximo turno enero, mandar recordatorio cel: 3514790943"))
print(phone_anonymizer.anonymize("Proximo turno enero, mandar recordatorio cel.: 3514790943"))
# Out:
# Paciente indica llamar a tel 3 XTELEFONOX sin poder comunicarse.
# Paciente indica llamar a telefono n°  XTELEFONOX sin poder comunicarse.
# Rescinde celular durante 400 dias
# Proximo turno enero, mandar recordatorio cel:  XTELEFONOX
# Proximo turno enero, mandar recordatorio cel.: XTELEFONOX
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_63444/1487379825.py:2: SyntaxWarning: invalid escape sequence '\s'
#   regexp_phone_prefix =  '(tel[ée]fono|(tel(?![aA-zZ]))|celular|(cel(?![aA-zZ])))\s*(?:n\s*[\.\°]|.)?\s*[:\.]?'

# %%
documents['anonymized'] = documents.anonymized.apply(phone_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XNUM_TELEFONOX',case=False)].head(2)
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### CORREO ELECTRÓNICO

# %%
## Expresión regular para CORREO ELECTRÓNICO
regexp_email = r'[\w\.-]+@[\w\.-]+\.\w+'

email_anonymizer = RegexAnnonimizer(
    content_regex=regexp_email,
    category='XCORREO_ELECTRONICOX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
)

print(email_anonymizer.anonymize("Contactar paciente a fakemail@fakedomain.com"))
print(email_anonymizer.anonymize("Contactar paciente a fakemail@fakedomain.com.ar"))
print(email_anonymizer.anonymize("Paciente refiere conflicto con herman@"))
# Out:
# Contactar paciente a XCORREO_ELECTRONICOX
# Contactar paciente a XCORREO_ELECTRONICOX
# Paciente refiere conflicto con herman@

# %%
documents['anonymized'] = documents['anonymized'].apply(email_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XCORREO_ELECTRONICOX',case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             original  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGénero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCódigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTeléfono fijo: +34 972 65 06 71\nTeléfono móvil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondición de riesgo: Trabajador de Sanitización\n\nDatos asistenciales.\nMédico: Dra. Emma Vicente Santos. NC 588434040. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartín\n\nInforme clínico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGénero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragón\nCódigo postal: 44075\nEmail: manuela@uca.es\nTeléfono fijo: +34 978 49 11 69\nTeléfono móvil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMédico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clínico del paciente:\nPaciente judío de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGénero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCódigo postal: 07533\nEmail: alejandro@ciberned.es\nTeléfono fijo: +34 971 59 71 11\nTeléfono móvil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondición de riesgo: Soldador\n\nDatos asistenciales.\nMédico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepción Sánchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGénero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellón, Comunidad Valenciana\nCódigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTeléfono fijo: +34 964 68 03 70\nTeléfono móvil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMédico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clínico en Enfermedades Digestivas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clínico del paciente:\nPaciente de ascendencia indígena sudamericana de 13 años de edad, acompañado de su madre. Se realizó un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco López\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGénero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCódigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTeléfono fijo: +34 913 43 68 26\nTeléfono móvil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMédico: Dra. Remedios Casas Martínez. NC 002225764. Residente de 3° año en Oftalmología. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Málaga Oeste\n\nInforme clínico del paciente:\nPaciente exfumador de 59 años de edad. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: María Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGénero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCódigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTeléfono fijo: +34 926 82 07 12\nTeléfono móvil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondición de riesgo: Soldado\n\nDatos asistenciales.\nMédico: Dra. Sofía Zamora Bermudez. NC 674953567. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de León\nMatrícula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGénero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Úbeda, Salamanca, Castilla y León\nCódigo postal: 37590\nEmail: montoya@ciberehd.org\nTeléfono fijo: +34 923 00 92 67\nTeléfono móvil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondición de riesgo: Pintor de Construcción\n\nDatos asistenciales.\nMédico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcalá de Henares\nMatrícula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clínico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.239.21, con dirección MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Méndez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGénero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCódigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTeléfono fijo: +34 942 14 64 21\nTeléfono móvil: +34 742 35 80 90\nNHC: 8508366\nCondición de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMédico: Dr. César Vega Alonso. NC 585819417. Residente de 5° año en Neurología. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática de 88 años de edad, acompañado de su hijo. El servidor para envío de información desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         preprocessed  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 960 66 89 48\nTelefono movil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGenero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTelefono fijo: +34 972 65 06 71\nTelefono movil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGenero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: manuela@uca.es\nTelefono fijo: +34 978 49 11 69\nTelefono movil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGenero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: alejandro@ciberned.es\nTelefono fijo: +34 971 59 71 11\nTelefono movil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGenero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTelefono fijo: +34 964 68 03 70\nTelefono movil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGenero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTelefono fijo: +34 913 43 68 26\nTelefono movil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGenero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTelefono fijo: +34 926 82 07 12\nTelefono movil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGenero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: montoya@ciberehd.org\nTelefono fijo: +34 923 00 92 67\nTelefono movil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGenero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTelefono fijo: +34 942 14 64 21\nTelefono movil: +34 742 35 80 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   anonymized
# 0                                                                                                                                                                                                    Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 48\nTelefono movil: +34 6XFECHAX 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                             Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 6XFECHAX 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 71\nTelefono movil: +34 7XFECHAX 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 69\nTelefono movil: +34 6XFECHAX 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: XFECHAX\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                   Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 11\nTelefono movil: +34 6XFECHAX 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 995                                                                                                                                Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 70\nTelefono movil: +34 6XFECHAX 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                                       Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: XFECHAX\nGenero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 26\nTelefono movil: +34 6XFECHAX 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                            Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 12\nTelefono movil: +34 6XFECHAX 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: XFECHAX\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 67\nTelefono movil: +34 6XFECHAX 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                           Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 21\nTelefono movil: +34 7XFECHAX 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### NUM_DNI

# %%
## Expresión regular para NUM_DNI

regexp_dni_prefix = r'(d\.n\.i|dni|doc(?= )|documento)(\sn\s?\.?\°?)?\s*[:\.]?\s*'
regexp_dni_numbers = r'\b\d{1,3}(?:\.*\d{3})*\b'

dni_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_dni_prefix,
    content_regex=regexp_dni_numbers,
    re_flags=re.IGNORECASE,
    category='XNUM_DNIX',
    output_type=OUTPUT_TYPE,
)

print(dni_anonymizer.anonymize("Paciente dni 27.384.234 control prenatal semana 27"))
print(dni_anonymizer.anonymize("Paciente dni n° 27.384.234 control prenatal semana 27"))
print(dni_anonymizer.anonymize("Paciente dni n ° 27.384.234 control prenatal semana 27"))
print(dni_anonymizer.anonymize("Paciente dni 27384234, control prenatal"))
print(dni_anonymizer.anonymize("Paciente dni: 27384234 control prenatal"))
print(dni_anonymizer.anonymize("Para mas detalles ver documento 25"))
print(dni_anonymizer.anonymize("Refiere extravio dni sin sintomatologia tel 27384234"))
# Out:
# Paciente dni  XNUM_DNIX control prenatal semana 27
# Paciente dni n°  XNUM_DNIX control prenatal semana 27
# Paciente dni n °  XNUM_DNIX control prenatal semana 27
# Paciente dni  XNUM_DNIX, control prenatal
# Paciente dni:  XNUM_DNIX control prenatal
# Para mas detalles ver documento  XNUM_DNIX
# Refiere extravio dni sin sintomatologia tel 27384234

# %%
documents['anonymized'] = documents['anonymized'].apply(dni_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XNUM_DNIX',case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### NUM_CUIT_CUIL

# %%
## Expresión regular para NUM_CUIT_CUIL
regexp_cuil_prefix = r'(c.u.i.l.|cuil|c.u.i.t|cuit)(\sn\s?\.?\°?)?\s*[:\.]?\s*'
# Numbers, or numbers with . or -
regexp_cuil_numbers = r'\b(?:\d(?:[\.\-]\d)*)+\b'

cuit_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_cuil_prefix,
    content_regex=regexp_cuil_numbers,
    re_flags=re.IGNORECASE,
    category='XNUM_CUIT_CUILX',
    output_type=OUTPUT_TYPE,
)

print(cuit_anonymizer.anonymize("Paciente CUIT 25-27.384.234-4 control prenatal semana 27"))
print(cuit_anonymizer.anonymize("Paciente cuil 25-27384234-4, control prenatal"))
print(cuit_anonymizer.anonymize("Paciente c.u.i.t 25273842344 control prenatal"))
print(cuit_anonymizer.anonymize("Refiere extravio cuit sin sintomatologia tel 27384234"))
# Out:
# Paciente CUIT  XNUM_CUIT_CUILX control prenatal semana 27
# Paciente cuil  XNUM_CUIT_CUILX, control prenatal
# Paciente c.u.i.t  XNUM_CUIT_CUILX control prenatal
# Refiere extravio cuit sin sintomatologia tel 27384234

# %%
documents['anonymized'] = documents['anonymized'].apply(cuit_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XNUM_CUIT_CUILX',case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### PASAPORTE

# %%
## Expresión regular para Pasaporte

regexp_passport_prefix = r'pasaporte(\sn\s?\.?\°?)?\s*[:\.]?\s*'
# Between 3 and 10 alphanumeric characters with at least one number
regexp_passport_numbers = r'\b[a-zA-Z0-9]*[0-9][a-zA-Z0-9]*\b'

passport_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_passport_prefix,
    content_regex=regexp_passport_numbers,
    re_flags=re.IGNORECASE,
    category='XPASAPORTEX',
    output_type=OUTPUT_TYPE,
)

print(passport_anonymizer.anonymize("Paciente pasaporte AAA342034, control prenatal semana 27"))
print(passport_anonymizer.anonymize("Paciente pasaporte n AAA342034, control prenatal semana 27"))
print(passport_anonymizer.anonymize("Paciente pasaporte n°: AAA342034, control prenatal semana 27"))
print(passport_anonymizer.anonymize("Paciente pasaporte 2527384234"))
print(passport_anonymizer.anonymize("Refiere extravio pasaporte sin sintomatologia tel 27384234"))
# Out:
# Paciente pasaporte  XPASAPORTEX, control prenatal semana 27
# Paciente pasaporte n  XPASAPORTEX, control prenatal semana 27
# Paciente pasaporte n°:  XPASAPORTEX, control prenatal semana 27
# Paciente pasaporte  XPASAPORTEX
# Refiere extravio pasaporte sin sintomatologia tel 27384234

# %%
documents['anonymized'] = documents['anonymized'].apply(passport_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XPASAPORTEX',case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### MATRICULA

# %%
## Expresión regular para MATRICULA
regexp_license_prefix = r'\bm(\.?)(p|n)(\.?)\s*[:\.]?\s*'
regexp_license_numbers = r'\b[0-9]{3,}\b'

license_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_license_prefix,
    content_regex=regexp_license_numbers,
    re_flags=re.IGNORECASE,
    category='XMATRICULAX',
    output_type=OUTPUT_TYPE,
)

print(license_anonymizer.anonymize("Atendido por dr. Ortiz mp 23411, control prenatal semana 27"))
print(license_anonymizer.anonymize("Atendido por dr. Ortiz m.p. 23411 control prenatal semana 27"))
print(license_anonymizer.anonymize("Atendido por dr. Ortiz m.n.: 23411 control prenatal semana 27"))
print(license_anonymizer.anonymize("Refiere extravio m.p. sin sintomatologia tel 27384234"))
# Out:
# Atendido por dr. Ortiz mp  XMATRICULAX, control prenatal semana 27
# Atendido por dr. Ortiz m.p.  XMATRICULAX control prenatal semana 27
# Atendido por dr. Ortiz m.n.:  XMATRICULAX control prenatal semana 27
# Refiere extravio m.p. sin sintomatologia tel 27384234

# %%
documents['anonymized'] = documents['anonymized'].apply(license_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XMATRICULAX',case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### PATENTE

# %%
## Expresión regular para PATENTE
regexp_license_plate = r'\b([aA-zZ]{3}[0-9]{3})|([aA-zZ]{2}[0-9]{3}[aA-zZ]{2})\b'

license_plate_anonymizer = RegexAnnonimizer(
    content_regex=regexp_license_plate,
    category='XPATENTEX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
)

print(license_plate_anonymizer.anonymize("Auto patente AA345QP fuera de servicio"))
print(license_plate_anonymizer.anonymize("Auto patente aub325- fuera de servicio"))
# Out:
# Auto patente XPATENTEX fuera de servicio
# Auto patente XPATENTEX- fuera de servicio

# %%
documents['anonymized'] = documents['anonymized'].apply(license_plate_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XPATENTEX', case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            original  \
# 16                                                                            Datos del paciente.\nNombre: Sonia Giménez Mateo\nDNI: 28458568R\nFecha de nacimiento: 12/10/1979\nGénero: F\nDomicilio: Calle de Amor de Dios 28\nCiudad: Málaga, Región de Murcia, Región de Murcia\nCódigo postal: 30174\nEmail: sonia-mateo@udc.es\nTeléfono fijo: +34 968 81 89 78\nTeléfono móvil: +34 668 04 26 48\nNHC: 3502518\nNASS: 148472849379\n\nDatos asistenciales.\nMédico: Dra. Remedios Torres Gutiérrez. NC 729610890. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 22/01/1987\nHospital: Hospital Universitario de Basurto\nMatrícula del coche: 4884RKT\nModelo: Toyota RAV4\nVIN: VSU906M506F437481\n\nInforme clínico del paciente:\nPaciente de ascendencia gitana de 7 años de edad, acompañado de su hermana. Se registró una sesión de reconocimiento facial, el código obtenido para revisarla es FZ253TPZ757. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es OS931MNR959.
# 33                                                                                                                                                                        Datos del paciente.\nNombre: Borja Silva Mateos\nDNI: 60347220G\nFecha de nacimiento: 11/03/2005\nGénero: H\nDomicilio: Calle de Ferraz 63\nCiudad: Santa Cruz de Tenerife, Teruel, Aragón\nCódigo postal: 44128\nEmail: u9kIJ@ual.es\nTeléfono fijo: +34 978 64 47 30\nTeléfono móvil: +34 678 69 16 51\nNHC: 6566985\nCondición de riesgo: Técnico de Laboratorio\n\nDatos asistenciales.\nMédico: Dr. Juan José Márquez Otero. NC 792000217. Residente de 4° año en Endocrinología. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 13/04/2021\nEpisodio: 76196258\nHospital: Hospital Universitario La Paz\nMatrícula del coche: 3109HGC\nModelo: Toyota Corolla\nVIN: VSS174DQ75N979276\n\nInforme clínico del paciente:\nPaciente vegetariano de 16 años de edad, acompañado de su hija. Se registró una sesión de huella dactilar, el código obtenido para revisarla es YO026ZOB747.
# 76                                                                                 Datos del paciente.\nNombre: Carla Costa Tomas\nDNI: 41653699D\nFecha de nacimiento: 13/07/2003\nGénero: Femenino\nDomicilio: Calle del Marqués de Urquijo 17\nCiudad: Ciudad Real, Barcelona, Cataluña\nCódigo postal: 08314\nEmail: carlacosta-tomas1789@icloud.com\nTeléfono fijo: +34 937 17 58 17\nTeléfono móvil: +34 630 32 55 13\nNHC: 8506538\nCondición de riesgo: Técnico de Cuidados Auxiliares de Enfermería\n\nDatos asistenciales.\nMédico: Dr. Marcos Hidalgo Navarro. NC 912637984. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 30/11/2020\nCentro de salud: Centro de Salud Pozuelo de Alarcón\nMatrícula del coche: 4404KEF\nModelo: Jeep Wrangler\nVIN: VSE198TH61G794235\n\nInforme clínico del paciente:\nPaciente de descendencia africana de 17 años de edad, acompañado de su madre. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es KB192NUG355.
# 129                                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Arturo Marcos Ramos\nDNI: 62826618W\nFecha de nacimiento: 28/07/1975\nGénero: Masculino\nDomicilio: Calle de Áncora 65, 1V\nCiudad: Orense, Barcelona, Cataluña\nCódigo postal: 08034\nEmail: arturo.ramos@aol.com\nTeléfono fijo: +34 939 40 27 60\nFAX: +34 931 61 41 68\nNHC: 1361726\nCondición de riesgo: Limpiador\n\nDatos asistenciales.\nMédico: Dra. Natalia Méndez Mesa. NC 615594360. Investigadora Clínica en Síndromes Raros. Instituto de Investigación Biomédica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 13/12/1976\nEpisodio: 75291213\nCentro de salud: Centro de Salud Boadilla del Monte\nMatrícula del coche: 4775NFN\nModelo: Toyota RAV4\nVIN: VSN824GLV5O101241\n\nInforme clínico del paciente:\nPaciente no fumador de un año de edad, acompañado de su abuela.
# 331                                                                                                                                                                           Datos del paciente.\nNombre: Natalia Padilla De la Fuente\nDNI: 93306180X\nFecha de nacimiento: 19/02/1990\nGénero: Femenino\nDomicilio: Calle de Fuencarral 29, 10B\nCiudad: Aranda de Duero, Orense, Galicia\nCódigo postal: 32229\nEmail: natalia-padilla_delafuente@aol.com\nTeléfono fijo: +34 988 92 34 73\nTeléfono móvil: +34 788 64 25 84\nNHC: 5052916\nNASS: 097272229925\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dra. María Asunción Crespo Guzman. NC 838560104. Especialista en Enfermedades Infecciosas. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 01/09/2018\nEpisodio: 61727998\nCentro de salud: Centro de Salud San Blas\nMatrícula del coche: 3650OVO\nModelo: Mazda CX-5\nVIN: VSQ368DR70V377478\n\nInforme clínico del paciente:\nPaciente vegano de 28 años de edad, acompañado de su hija.
# 489                                                                                                                                                                                                          Datos del paciente.\nNombre: Ismael De la Fuente Ferrer\nDNI: 11401440H\nFecha de nacimiento: 09/01/1935\nGénero: Hombre\nDomicilio: Calle Mayor 83\nCiudad: Jaén, Santa Cruz de Tenerife, Canarias\nCódigo postal: 38674\nEmail: ismael@ciberehd.org\nTeléfono fijo: +34 922 31 47 30\nTeléfono móvil: +34 622 56 87 79\nNHC: 8362853\nNASS: 734963587204\nCondición de riesgo: Trabajador de Minería\n\nDatos asistenciales.\nMédico: Dr. Jorge Lara Rivera. NC 749350177. Residente de 2° año en Pediatría. Instituto de Investigación Biomédica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 06/12/2003\nEpisodio: 31724173\nHospital: Hospital Regional Universitario de Málaga\nMatrícula del coche: 6561POQ\nModelo: Toyota Corolla\nVIN: VSZ3658I9FS625848\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 68 años de edad, acompañado de su hermana.
# 602                                                                                                                                                                                                                                           Datos del paciente.\nNombre: Ángel Rivas Estevez\nDNI: 51081656J\nFecha de nacimiento: 15/10/2014\nGénero: Masculino\nDomicilio: Calle de Fortuny 57, 8J\nCiudad: Torrelodones, Álava, Pais Vasco\nCódigo postal: 01674\nEmail: angel_rivasestevez290@ciberned.es\nTeléfono fijo: +34 945 33 13 89\nTeléfono móvil: +34 745 19 90 72\nNHC: 9847442\nNASS: 652100069553\nCondición de riesgo: Fabricante\n\nDatos asistenciales.\nMédico: Dr. Nicolás Simon Varela. NC 805731645. Residente de 3° año en Oftalmología. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 11/02/2016\nHospital: Hospital Universitario Río Hortega\nMatrícula del coche: 7224LXS\nModelo: Ford F-150\nVIN: VSD5236YPTL605726\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática oriental de un año de edad, acompañado de su abuela.
# 740                                                                                                                                                                                                Datos del paciente.\nNombre: Izan Blazquez Iglesias\nDNI: 98239436L\nFecha de nacimiento: 01/04/1946\nGénero: V\nDomicilio: Calle de San Bernardo 26\nCiudad: Vilanova i la Geltrú, Menorca, Islas Baleares\nCódigo postal: 07120\nEmail: izanblazquez.iglesias@udc.es\nTeléfono fijo: +34 971 52 42 87\nTeléfono móvil: +34 771 76 00 03\nNHC: 9289479\nNASS: 029449249741\nCondición de riesgo: Trabajador de Línea de Producción\n\nDatos asistenciales.\nMédico: Dra. Fátima Heredia Montes. NC 488530099. Residente de 2° año en Pediatría. Instituto de Investigación Biomédica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 31/12/1948\nHospital: Hospital Universitario de Cabueñes\nMatrícula del coche: 9908EGP\nModelo: Ram 1500\nVIN: VSW58407PGV209796\n\nInforme clínico del paciente:\nPaciente de ascendencia africana del norte de 2 años de edad, acompañado de su padre.
# 773                                                                                                                                                                                                   Datos del paciente.\nNombre: Mohammed Pardo Campos\nDNI: 42077094C\nFecha de nacimiento: 15/12/1984\nGénero: Varón\nDomicilio: Calle del Marqués de Cubas 20, 7B\nCiudad: Gandía, Granada, Andalucía\nCódigo postal: 18540\nEmail: pardo.campos1370@us.es\nTeléfono fijo: +34 958 44 39 15\nTeléfono móvil: +34 758 71 14 00\nNHC: 3987664\nNASS: 312744005702\nCondición de riesgo: Dentista\n\nDatos asistenciales.\nMédico: Dr. Antonio Santana Flores. NC 934189127. Residente de 4° año en Medicina Interna. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 26/08/1991\nEpisodio: 52568202\nHospital: Hospital Universitari de Bellvitge\nMatrícula del coche: 5957SJL\nModelo: Chevrolet Silverado\nVIN: VSE290IT3VZ794125\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 794                                                                                                                                                                                                                              Datos del paciente.\nNombre: Christian Calvo Molina\nDNI: 92126748H\nFecha de nacimiento: 26/09/1973\nGénero: Masculino\nDomicilio: Calle de Bravo Murillo 58\nCiudad: Orense, Santa Cruz de Tenerife, Canarias\nCódigo postal: 38172\nEmail: christian-calvo.molina@ual.es\nTeléfono fijo: +34 922 92 46 18\nTeléfono móvil: +34 622 90 61 68\nNHC: 8179427\nNASS: 209104432091\n\nDatos asistenciales.\nMédico: Dra. Magdalena Ibáñez Arroyo. NC 428101765. Cardióloga de Unidad de Cuidados Intensivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 29/12/2011\nEpisodio: 01691686\nHospital: Hospital Universitario Virgen del Rocío\nMatrícula del coche: 3245ZMB\nModelo: Mazda CX-5\nVIN: VSQ401KFPTO158829\n\nInforme clínico del paciente:\nPaciente fumador de 38 años de edad, acompañado de su compañero de estudio.
# 871                                                                                                                                                                                                                                                               Datos del paciente.\nNombre: Marcos Gil Ruiz\nDNI: 48351620P\nFecha de nacimiento: 23/07/1938\nGénero: H\nDomicilio: Calle de Génova 17\nCiudad: Alcalá de Henares, Segovia, Castilla y León\nCódigo postal: 40774\nEmail: ruiz@ciberned.es\nTeléfono fijo: +34 921 53 16 72\nTeléfono móvil: +34 721 04 60 09\nNHC: 0499026\nNASS: 403898434393\nCondición de riesgo: Ama de casa\n\nDatos asistenciales.\nMédico: Dra. Elisa Santiago Muñoz. NC 477001414. Residente de 4° año en Cardiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 20/12/2015\nHospital: Complejo Asistencial Universitario de León\nMatrícula del coche: 5674YKX\nModelo: Tesla Model 3\nVIN: VSO6043KCEI761020\n\nInforme clínico del paciente:\nPaciente usuario de drogas de 77 años de edad.
# 943  Datos del paciente.\nNombre: Aurora Romero Calderon\nDNI: 62560371A\nFecha de nacimiento: 06/07/1970\nGénero: F\nDomicilio: Calle de Bravo Murillo 50\nCiudad: Zamora, Navarra, Navarra\nCódigo postal: 31837\nEmail: romero.calderon@gmail.com\nTeléfono fijo: +34 948 61 52 06\nFAX: +34 948 23 28 07\nNHC: 5821545\n\nDatos asistenciales.\nMédico: Dr. Joaquín Ríos Aparicio. NC 892652926. Investigador Clínico en Enfermedades Digestivas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 26/01/1971\nHospital: Hospital Universitario de Gran Canaria Dr. Negrín\nMatrícula del coche: 1742QDS\nModelo: Toyota RAV4\nVIN: VST77587KVE251216\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 meses de edad, acompañado de su abuelo. Se realizó un expediente con URL http://example-pharma.org//55764505E. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es UQ667MDC769. Se registró una sesión de firma biométrica, el código obtenido para revisarla es MI782XWY930.
# 955                                                             Datos del paciente.\nNombre: Martín Pérez Guerrero\nDNI: 84570471T\nFecha de nacimiento: 24/04/2017\nGénero: Hombre\nDomicilio: Calle de la Alameda 29, 7W\nCiudad: Puertollano, Álava, Pais Vasco\nCódigo postal: 01642\nEmail: martin-perez@outlook.com\nTeléfono fijo: +34 945 65 07 27\nTeléfono móvil: +34 645 55 00 77\nNHC: 7848584\nNASS: 906597168013\nCondición de riesgo: Técnico de Radiología\n\nDatos asistenciales.\nMédico: Dra. Matilde Marti Costa. NC 721589568. Investigadora Clínica en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 36026136\nHospital: Complejo Hospitalario Universitario de Cartagena\nMatrícula del coche: 6575GOA\nModelo: Chevrolet Silverado\nVIN: VSH746CZU8X648016\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 7 años de edad, acompañado de su padre. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es QJ824IVC466.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        preprocessed  \
# 16                                                                            Datos del paciente.\nNombre: Sonia Gimenez Mateo\nDNI: 28458568R\nFecha de nacimiento: 12/10/1979\nGenero: F\nDomicilio: Calle de Amor de Dios 28\nCiudad: Malaga, Region de Murcia, Region de Murcia\nCodigo postal: 30174\nEmail: sonia-mateo@udc.es\nTelefono fijo: +34 968 81 89 78\nTelefono movil: +34 668 04 26 48\nNHC: 3502518\nNASS: 148472849379\n\nDatos asistenciales.\nMedico: Dra. Remedios Torres Gutierrez. NC 729610890. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 22/01/1987\nHospital: Hospital Universitario de Basurto\nMatricula del coche: 4884RKT\nModelo: Toyota RAV4\nVIN: VSU906M506F437481\n\nInforme clinico del paciente:\nPaciente de ascendencia gitana de 7 años de edad, acompañado de su hermana. Se registro una sesion de reconocimiento facial, el codigo obtenido para revisarla es FZ253TPZ757. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es OS931MNR959.
# 33                                                                                                                                                                        Datos del paciente.\nNombre: Borja Silva Mateos\nDNI: 60347220G\nFecha de nacimiento: 11/03/2005\nGenero: H\nDomicilio: Calle de Ferraz 63\nCiudad: Santa Cruz de Tenerife, Teruel, Aragon\nCodigo postal: 44128\nEmail: u9kIJ@ual.es\nTelefono fijo: +34 978 64 47 30\nTelefono movil: +34 678 69 16 51\nNHC: 6566985\nCondicion de riesgo: Tecnico de Laboratorio\n\nDatos asistenciales.\nMedico: Dr. Juan Jose Marquez Otero. NC 792000217. Residente de 4° año en Endocrinologia. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 13/04/2021\nEpisodio: 76196258\nHospital: Hospital Universitario La Paz\nMatricula del coche: 3109HGC\nModelo: Toyota Corolla\nVIN: VSS174DQ75N979276\n\nInforme clinico del paciente:\nPaciente vegetariano de 16 años de edad, acompañado de su hija. Se registro una sesion de huella dactilar, el codigo obtenido para revisarla es YO026ZOB747.
# 76                                                                                 Datos del paciente.\nNombre: Carla Costa Tomas\nDNI: 41653699D\nFecha de nacimiento: 13/07/2003\nGenero: Femenino\nDomicilio: Calle del Marques de Urquijo 17\nCiudad: Ciudad Real, Barcelona, Cataluña\nCodigo postal: 08314\nEmail: carlacosta-tomas1789@icloud.com\nTelefono fijo: +34 937 17 58 17\nTelefono movil: +34 630 32 55 13\nNHC: 8506538\nCondicion de riesgo: Tecnico de Cuidados Auxiliares de Enfermeria\n\nDatos asistenciales.\nMedico: Dr. Marcos Hidalgo Navarro. NC 912637984. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 30/11/2020\nCentro de salud: Centro de Salud Pozuelo de Alarcon\nMatricula del coche: 4404KEF\nModelo: Jeep Wrangler\nVIN: VSE198TH61G794235\n\nInforme clinico del paciente:\nPaciente de descendencia africana de 17 años de edad, acompañado de su madre. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es KB192NUG355.
# 129                                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Arturo Marcos Ramos\nDNI: 62826618W\nFecha de nacimiento: 28/07/1975\nGenero: Masculino\nDomicilio: Calle de Ancora 65, 1V\nCiudad: Orense, Barcelona, Cataluña\nCodigo postal: 08034\nEmail: arturo.ramos@aol.com\nTelefono fijo: +34 939 40 27 60\nFAX: +34 931 61 41 68\nNHC: 1361726\nCondicion de riesgo: Limpiador\n\nDatos asistenciales.\nMedico: Dra. Natalia Mendez Mesa. NC 615594360. Investigadora Clinica en Sindromes Raros. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 13/12/1976\nEpisodio: 75291213\nCentro de salud: Centro de Salud Boadilla del Monte\nMatricula del coche: 4775NFN\nModelo: Toyota RAV4\nVIN: VSN824GLV5O101241\n\nInforme clinico del paciente:\nPaciente no fumador de un año de edad, acompañado de su abuela.
# 331                                                                                                                                                                           Datos del paciente.\nNombre: Natalia Padilla De la Fuente\nDNI: 93306180X\nFecha de nacimiento: 19/02/1990\nGenero: Femenino\nDomicilio: Calle de Fuencarral 29, 10B\nCiudad: Aranda de Duero, Orense, Galicia\nCodigo postal: 32229\nEmail: natalia-padilla_delafuente@aol.com\nTelefono fijo: +34 988 92 34 73\nTelefono movil: +34 788 64 25 84\nNHC: 5052916\nNASS: 097272229925\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dra. Maria Asuncion Crespo Guzman. NC 838560104. Especialista en Enfermedades Infecciosas. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 01/09/2018\nEpisodio: 61727998\nCentro de salud: Centro de Salud San Blas\nMatricula del coche: 3650OVO\nModelo: Mazda CX-5\nVIN: VSQ368DR70V377478\n\nInforme clinico del paciente:\nPaciente vegano de 28 años de edad, acompañado de su hija.
# 489                                                                                                                                                                                                          Datos del paciente.\nNombre: Ismael De la Fuente Ferrer\nDNI: 11401440H\nFecha de nacimiento: 09/01/1935\nGenero: Hombre\nDomicilio: Calle Mayor 83\nCiudad: Jaen, Santa Cruz de Tenerife, Canarias\nCodigo postal: 38674\nEmail: ismael@ciberehd.org\nTelefono fijo: +34 922 31 47 30\nTelefono movil: +34 622 56 87 79\nNHC: 8362853\nNASS: 734963587204\nCondicion de riesgo: Trabajador de Mineria\n\nDatos asistenciales.\nMedico: Dr. Jorge Lara Rivera. NC 749350177. Residente de 2° año en Pediatria. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 06/12/2003\nEpisodio: 31724173\nHospital: Hospital Regional Universitario de Malaga\nMatricula del coche: 6561POQ\nModelo: Toyota Corolla\nVIN: VSZ3658I9FS625848\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 68 años de edad, acompañado de su hermana.
# 602                                                                                                                                                                                                                                           Datos del paciente.\nNombre: Angel Rivas Estevez\nDNI: 51081656J\nFecha de nacimiento: 15/10/2014\nGenero: Masculino\nDomicilio: Calle de Fortuny 57, 8J\nCiudad: Torrelodones, Alava, Pais Vasco\nCodigo postal: 01674\nEmail: angel_rivasestevez290@ciberned.es\nTelefono fijo: +34 945 33 13 89\nTelefono movil: +34 745 19 90 72\nNHC: 9847442\nNASS: 652100069553\nCondicion de riesgo: Fabricante\n\nDatos asistenciales.\nMedico: Dr. Nicolas Simon Varela. NC 805731645. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 11/02/2016\nHospital: Hospital Universitario Rio Hortega\nMatricula del coche: 7224LXS\nModelo: Ford F-150\nVIN: VSD5236YPTL605726\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica oriental de un año de edad, acompañado de su abuela.
# 740                                                                                                                                                                                                Datos del paciente.\nNombre: Izan Blazquez Iglesias\nDNI: 98239436L\nFecha de nacimiento: 01/04/1946\nGenero: V\nDomicilio: Calle de San Bernardo 26\nCiudad: Vilanova i la Geltru, Menorca, Islas Baleares\nCodigo postal: 07120\nEmail: izanblazquez.iglesias@udc.es\nTelefono fijo: +34 971 52 42 87\nTelefono movil: +34 771 76 00 03\nNHC: 9289479\nNASS: 029449249741\nCondicion de riesgo: Trabajador de Linea de Produccion\n\nDatos asistenciales.\nMedico: Dra. Fatima Heredia Montes. NC 488530099. Residente de 2° año en Pediatria. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 31/12/1948\nHospital: Hospital Universitario de Cabueñes\nMatricula del coche: 9908EGP\nModelo: Ram 1500\nVIN: VSW58407PGV209796\n\nInforme clinico del paciente:\nPaciente de ascendencia africana del norte de 2 años de edad, acompañado de su padre.
# 773                                                                                                                                                                                                   Datos del paciente.\nNombre: Mohammed Pardo Campos\nDNI: 42077094C\nFecha de nacimiento: 15/12/1984\nGenero: Varon\nDomicilio: Calle del Marques de Cubas 20, 7B\nCiudad: Gandia, Granada, Andalucia\nCodigo postal: 18540\nEmail: pardo.campos1370@us.es\nTelefono fijo: +34 958 44 39 15\nTelefono movil: +34 758 71 14 00\nNHC: 3987664\nNASS: 312744005702\nCondicion de riesgo: Dentista\n\nDatos asistenciales.\nMedico: Dr. Antonio Santana Flores. NC 934189127. Residente de 4° año en Medicina Interna. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 26/08/1991\nEpisodio: 52568202\nHospital: Hospital Universitari de Bellvitge\nMatricula del coche: 5957SJL\nModelo: Chevrolet Silverado\nVIN: VSE290IT3VZ794125\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 794                                                                                                                                                                                                                              Datos del paciente.\nNombre: Christian Calvo Molina\nDNI: 92126748H\nFecha de nacimiento: 26/09/1973\nGenero: Masculino\nDomicilio: Calle de Bravo Murillo 58\nCiudad: Orense, Santa Cruz de Tenerife, Canarias\nCodigo postal: 38172\nEmail: christian-calvo.molina@ual.es\nTelefono fijo: +34 922 92 46 18\nTelefono movil: +34 622 90 61 68\nNHC: 8179427\nNASS: 209104432091\n\nDatos asistenciales.\nMedico: Dra. Magdalena Ibañez Arroyo. NC 428101765. Cardiologa de Unidad de Cuidados Intensivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 29/12/2011\nEpisodio: 01691686\nHospital: Hospital Universitario Virgen del Rocio\nMatricula del coche: 3245ZMB\nModelo: Mazda CX-5\nVIN: VSQ401KFPTO158829\n\nInforme clinico del paciente:\nPaciente fumador de 38 años de edad, acompañado de su compañero de estudio.
# 871                                                                                                                                                                                                                                                               Datos del paciente.\nNombre: Marcos Gil Ruiz\nDNI: 48351620P\nFecha de nacimiento: 23/07/1938\nGenero: H\nDomicilio: Calle de Genova 17\nCiudad: Alcala de Henares, Segovia, Castilla y Leon\nCodigo postal: 40774\nEmail: ruiz@ciberned.es\nTelefono fijo: +34 921 53 16 72\nTelefono movil: +34 721 04 60 09\nNHC: 0499026\nNASS: 403898434393\nCondicion de riesgo: Ama de casa\n\nDatos asistenciales.\nMedico: Dra. Elisa Santiago Muñoz. NC 477001414. Residente de 4° año en Cardiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 20/12/2015\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 5674YKX\nModelo: Tesla Model 3\nVIN: VSO6043KCEI761020\n\nInforme clinico del paciente:\nPaciente usuario de drogas de 77 años de edad.
# 943  Datos del paciente.\nNombre: Aurora Romero Calderon\nDNI: 62560371A\nFecha de nacimiento: 06/07/1970\nGenero: F\nDomicilio: Calle de Bravo Murillo 50\nCiudad: Zamora, Navarra, Navarra\nCodigo postal: 31837\nEmail: romero.calderon@gmail.com\nTelefono fijo: +34 948 61 52 06\nFAX: +34 948 23 28 07\nNHC: 5821545\n\nDatos asistenciales.\nMedico: Dr. Joaquin Rios Aparicio. NC 892652926. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 26/01/1971\nHospital: Hospital Universitario de Gran Canaria Dr. Negrin\nMatricula del coche: 1742QDS\nModelo: Toyota RAV4\nVIN: VST77587KVE251216\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 meses de edad, acompañado de su abuelo. Se realizo un expediente con URL http://example-pharma.org//55764505E. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es UQ667MDC769. Se registro una sesion de firma biometrica, el codigo obtenido para revisarla es MI782XWY930.
# 955                                                             Datos del paciente.\nNombre: Martin Perez Guerrero\nDNI: 84570471T\nFecha de nacimiento: 24/04/2017\nGenero: Hombre\nDomicilio: Calle de la Alameda 29, 7W\nCiudad: Puertollano, Alava, Pais Vasco\nCodigo postal: 01642\nEmail: martin-perez@outlook.com\nTelefono fijo: +34 945 65 07 27\nTelefono movil: +34 645 55 00 77\nNHC: 7848584\nNASS: 906597168013\nCondicion de riesgo: Tecnico de Radiologia\n\nDatos asistenciales.\nMedico: Dra. Matilde Marti Costa. NC 721589568. Investigadora Clinica en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 36026136\nHospital: Complejo Hospitalario Universitario de Cartagena\nMatricula del coche: 6575GOA\nModelo: Chevrolet Silverado\nVIN: VSH746CZU8X648016\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su padre. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es QJ824IVC466.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                anonymized
# 16                                                                     Datos del paciente.\nNombre: Sonia Gimenez Mateo\nDNI: 28458568R\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle de Amor de Dios 28\nCiudad: Malaga, Region de Murcia, Region de Murcia\nCodigo postal: 30174\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 78\nTelefono movil: +34 6XFECHAX 48\nNHC: 3502518\nNASS: 148472849379\n\nDatos asistenciales.\nMedico: Dra. Remedios Torres Gutierrez. NC 729610890. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario de Basurto\nMatricula del coche: 4884RKT\nModelo: Toyota RAV4\nVIN: XPATENTEXM506F437481\n\nInforme clinico del paciente:\nPaciente de ascendencia gitana de 7 años de edad, acompañado de su hermana. Se registro una sesion de reconocimiento facial, el codigo obtenido para revisarla es FZ253TPZ757. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es OS931MNR959.
# 33                                                                                                                                                           Datos del paciente.\nNombre: Borja Silva Mateos\nDNI: 60347220G\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle de Ferraz 63\nCiudad: Santa Cruz de Tenerife, Teruel, Aragon\nCodigo postal: 44128\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 30\nTelefono movil: +34 6XFECHAX 51\nNHC: 6566985\nCondicion de riesgo: Tecnico de Laboratorio\n\nDatos asistenciales.\nMedico: Dr. Juan Jose Marquez Otero. NC 792000217. Residente de 4° año en Endocrinologia. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: XFECHAX\nEpisodio: 76196258\nHospital: Hospital Universitario La Paz\nMatricula del coche: 3109HGC\nModelo: Toyota Corolla\nVIN: XPATENTEXDQ75N979276\n\nInforme clinico del paciente:\nPaciente vegetariano de 16 años de edad, acompañado de su hija. Se registro una sesion de huella dactilar, el codigo obtenido para revisarla es YO026ZOB747.
# 76                                                                                       Datos del paciente.\nNombre: Carla Costa Tomas\nDNI: 41653699D\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle del Marques de Urquijo 17\nCiudad: Ciudad Real, Barcelona, Cataluña\nCodigo postal: 08314\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 17\nTelefono movil: +34 6XFECHAX 13\nNHC: 8506538\nCondicion de riesgo: Tecnico de Cuidados Auxiliares de Enfermeria\n\nDatos asistenciales.\nMedico: Dr. Marcos Hidalgo Navarro. NC 912637984. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nCentro de salud: Centro de Salud Pozuelo de Alarcon\nMatricula del coche: 4404KEF\nModelo: Jeep Wrangler\nVIN: XPATENTEXTH61G794235\n\nInforme clinico del paciente:\nPaciente de descendencia africana de 17 años de edad, acompañado de su madre. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es KB192NUG355.
# 129                                                                                                                                                                                                                                                           Datos del paciente.\nNombre: Arturo Marcos Ramos\nDNI: 62826618W\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle de Ancora 65, 1V\nCiudad: Orense, Barcelona, Cataluña\nCodigo postal: 08034\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 60\nFAX: +34 9XFECHAX 68\nNHC: 1361726\nCondicion de riesgo: Limpiador\n\nDatos asistenciales.\nMedico: Dra. Natalia Mendez Mesa. NC 615594360. Investigadora Clinica en Sindromes Raros. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 75291213\nCentro de salud: Centro de Salud Boadilla del Monte\nMatricula del coche: 4775NFN\nModelo: Toyota RAV4\nVIN: XPATENTEXGLV5O101241\n\nInforme clinico del paciente:\nPaciente no fumador de un año de edad, acompañado de su abuela.
# 331                                                                                                                                                                                    Datos del paciente.\nNombre: Natalia Padilla De la Fuente\nDNI: 93306180X\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle de Fuencarral 29, 10B\nCiudad: Aranda de Duero, Orense, Galicia\nCodigo postal: 32229\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 73\nTelefono movil: +34 7XFECHAX 84\nNHC: 5052916\nNASS: 097272229925\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dra. Maria Asuncion Crespo Guzman. NC 838560104. Especialista en Enfermedades Infecciosas. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 61727998\nCentro de salud: Centro de Salud San Blas\nMatricula del coche: 3650OVO\nModelo: Mazda CX-5\nVIN: XPATENTEXDR70V377478\n\nInforme clinico del paciente:\nPaciente vegano de 28 años de edad, acompañado de su hija.
# 489                                                                                                                                                                                                    Datos del paciente.\nNombre: Ismael De la Fuente Ferrer\nDNI: 11401440H\nFecha de nacimiento: XFECHAX\nGenero: Hombre\nDomicilio: Calle Mayor 83\nCiudad: Jaen, Santa Cruz de Tenerife, Canarias\nCodigo postal: 38674\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 30\nTelefono movil: +34 6XFECHAX 79\nNHC: 8362853\nNASS: 734963587204\nCondicion de riesgo: Trabajador de Mineria\n\nDatos asistenciales.\nMedico: Dr. Jorge Lara Rivera. NC 749350177. Residente de 2° año en Pediatria. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 31724173\nHospital: Hospital Regional Universitario de Malaga\nMatricula del coche: 6561POQ\nModelo: Toyota Corolla\nVIN: XPATENTEX8I9FS625848\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 68 años de edad, acompañado de su hermana.
# 602                                                                                                                                                                                                                                                   Datos del paciente.\nNombre: Angel Rivas Estevez\nDNI: 51081656J\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle de Fortuny 57, 8J\nCiudad: Torrelodones, Alava, Pais Vasco\nCodigo postal: 01674\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 89\nTelefono movil: +34 7XFECHAX 72\nNHC: 9847442\nNASS: 652100069553\nCondicion de riesgo: Fabricante\n\nDatos asistenciales.\nMedico: Dr. Nicolas Simon Varela. NC 805731645. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario Rio Hortega\nMatricula del coche: 7224LXS\nModelo: Ford F-150\nVIN: XPATENTEX6YPTL605726\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica oriental de un año de edad, acompañado de su abuela.
# 740                                                                                                                                                                                                   Datos del paciente.\nNombre: Izan Blazquez Iglesias\nDNI: 98239436L\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle de San Bernardo 26\nCiudad: Vilanova i la Geltru, Menorca, Islas Baleares\nCodigo postal: 07120\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 87\nTelefono movil: +34 7XFECHAX 03\nNHC: 9289479\nNASS: 029449249741\nCondicion de riesgo: Trabajador de Linea de Produccion\n\nDatos asistenciales.\nMedico: Dra. Fatima Heredia Montes. NC 488530099. Residente de 2° año en Pediatria. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario de Cabueñes\nMatricula del coche: 9908EGP\nModelo: Ram 1500\nVIN: XPATENTEX07PGV209796\n\nInforme clinico del paciente:\nPaciente de ascendencia africana del norte de 2 años de edad, acompañado de su padre.
# 773                                                                                                                                                                                                Datos del paciente.\nNombre: Mohammed Pardo Campos\nDNI: 42077094C\nFecha de nacimiento: XFECHAX\nGenero: Varon\nDomicilio: Calle del Marques de Cubas 20, 7B\nCiudad: Gandia, Granada, Andalucia\nCodigo postal: 18540\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 7XFECHAX 00\nNHC: 3987664\nNASS: 312744005702\nCondicion de riesgo: Dentista\n\nDatos asistenciales.\nMedico: Dr. Antonio Santana Flores. NC 934189127. Residente de 4° año en Medicina Interna. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 52568202\nHospital: Hospital Universitari de Bellvitge\nMatricula del coche: 5957SJL\nModelo: Chevrolet Silverado\nVIN: XPATENTEXIT3VZ794125\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 794                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Christian Calvo Molina\nDNI: 92126748H\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle de Bravo Murillo 58\nCiudad: Orense, Santa Cruz de Tenerife, Canarias\nCodigo postal: 38172\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 18\nTelefono movil: +34 6XFECHAX 68\nNHC: 8179427\nNASS: 209104432091\n\nDatos asistenciales.\nMedico: Dra. Magdalena Ibañez Arroyo. NC 428101765. Cardiologa de Unidad de Cuidados Intensivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 01691686\nHospital: Hospital Universitario Virgen del Rocio\nMatricula del coche: 3245ZMB\nModelo: Mazda CX-5\nVIN: XPATENTEXKFPTO158829\n\nInforme clinico del paciente:\nPaciente fumador de 38 años de edad, acompañado de su compañero de estudio.
# 871                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: Marcos Gil Ruiz\nDNI: 48351620P\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle de Genova 17\nCiudad: Alcala de Henares, Segovia, Castilla y Leon\nCodigo postal: 40774\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 72\nTelefono movil: +34 7XFECHAX 09\nNHC: 0499026\nNASS: 403898434393\nCondicion de riesgo: Ama de casa\n\nDatos asistenciales.\nMedico: Dra. Elisa Santiago Muñoz. NC 477001414. Residente de 4° año en Cardiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 5674YKX\nModelo: Tesla Model 3\nVIN: XPATENTEX3KCEI761020\n\nInforme clinico del paciente:\nPaciente usuario de drogas de 77 años de edad.
# 943  Datos del paciente.\nNombre: Aurora Romero Calderon\nDNI: 62560371A\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle de Bravo Murillo 50\nCiudad: Zamora, Navarra, Navarra\nCodigo postal: 31837\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 06\nFAX: +34 9XFECHAX 07\nNHC: 5821545\n\nDatos asistenciales.\nMedico: Dr. Joaquin Rios Aparicio. NC 892652926. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario de Gran Canaria Dr. Negrin\nMatricula del coche: 1742QDS\nModelo: Toyota RAV4\nVIN: XPATENTEX87KVE251216\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 meses de edad, acompañado de su abuelo. Se realizo un expediente con URL http://example-pharma.org//55764505E. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es UQ667MDC769. Se registro una sesion de firma biometrica, el codigo obtenido para revisarla es MI782XWY930.
# 955                                                            Datos del paciente.\nNombre: Martin Perez Guerrero\nDNI: 84570471T\nFecha de nacimiento: XFECHAX\nGenero: Hombre\nDomicilio: Calle de la Alameda 29, 7W\nCiudad: Puertollano, Alava, Pais Vasco\nCodigo postal: 01642\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 27\nTelefono movil: +34 6XFECHAX 77\nNHC: 7848584\nNASS: 906597168013\nCondicion de riesgo: Tecnico de Radiologia\n\nDatos asistenciales.\nMedico: Dra. Matilde Marti Costa. NC 721589568. Investigadora Clinica en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 36026136\nHospital: Complejo Hospitalario Universitario de Cartagena\nMatricula del coche: 6575GOA\nModelo: Chevrolet Silverado\nVIN: XPATENTEXCZU8X648016\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su padre. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es QJ824IVC466.

# %% [markdown]
# ### OTROS_NUM
#
# #### Historias clínicas

# %%
## Expresión regular para HISTORIA CLINICA
regexp_hc_prefix = r'\bh(\.?)c(\.?)\s*[:\.]?\s*'
regexp_hc_numbers = r'[0-9]{3,}'

clinic_history_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_hc_prefix,
    content_regex=regexp_hc_numbers,
    re_flags=re.IGNORECASE,
    category='XOTROS_NUMX',
    output_type=OUTPUT_TYPE,
)

print(clinic_history_anonymizer.anonymize("Atendido previamente hc 23411, control prenatal semana 27"))
print(clinic_history_anonymizer.anonymize("Atendido previamente h.c. 23411, control prenatal semana 27"))
print(clinic_history_anonymizer.anonymize("Atendido  previamente hc h.c.: 23411 control prenatal semana 27"))
print(clinic_history_anonymizer.anonymize("Refiere extravio hc sin sintomatologia tel 27384234"))
# Out:
# Atendido previamente hc  XOTROS_NUMX, control prenatal semana 27
# Atendido previamente h.c.  XOTROS_NUMX, control prenatal semana 27
# Atendido  previamente hc h.c.:  XOTROS_NUMX control prenatal semana 27
# Refiere extravio hc sin sintomatologia tel 27384234

# %%
documents['anonymized'] = documents['anonymized'].apply(clinic_history_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XOTROS_NUMX', case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### DIRECCIÓN

# %%
streets = pd.read_csv("datasets/diccionario_calles_editadas.csv", sep=';', index_col=None)
streets.head(5)
# Out:
#   categoria          nombre provincia_nombre     Token0      Token1 Token2  \
# 0       PJE  pje estudiante         La Rioja        pje  estudiante    NaN
# 1     CALLE      20 de mayo         La Rioja         20          de   mayo
# 2     CALLE      1 de enero         La Rioja          1          de  enero
# 3     CALLE     10 de julio         La Rioja         10          de  julio
# 4     CALLE       aconcagua         La Rioja  aconcagua         NaN    NaN
#
#   Token3 Token4 Token5 Token6
# 0    NaN    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN
# 2    NaN    NaN    NaN    NaN
# 3    NaN    NaN    NaN    NaN
# 4    NaN    NaN    NaN    NaN

# %%
# Sanitize street names
street_names = [remove_accents(name).strip()
                for name in streets.nombre
                if not re.search(ILLEGAL_CHAR_REGEX, name)]
regexp_address_prefix = r'\b(calle|avenida|av\.?|pasaje|pje\.?|parcela|manzana|tira|bloque|casa|lote|barrio)\s*[:]?\s*'
# Nombre de calles o barrios incluyendo cualquier numero posterior
regexp_streets = '(' + '|'.join(street_names) + ')(\s+([0-9]{1,6}))?'

address_w_names_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_address_prefix,
    content_regex=regexp_streets,
    re_flags=re.IGNORECASE,
    category='XDIRECCIONX',
    output_type=OUTPUT_TYPE,
)

# Ejemplos
print(address_w_names_anonymizer.anonymize("Vive en av. antartida argentina 1470, se indica medicacion"))
print(address_w_names_anonymizer.anonymize("Direccion: calle: 10 de julio, Barrio: alfonsina storini con hermanos"))
print(address_w_names_anonymizer.anonymize("Vive en Barrio barrioquenoexiste con hermanos"))
print(address_w_names_anonymizer.anonymize("Vive en manzana 3 lote 9 barrio 10 de julio."))
# Out:
# Vive en av.  XDIRECCIONX, se indica medicacion
# Direccion: calle:  XDIRECCIONX, Barrio:  XDIRECCIONX con hermanos
# Vive en Barrio barrioquenoexiste con hermanos
# Vive en manzana 3 lote 9 barrio  XDIRECCIONX.
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_63444/2484243500.py:7: SyntaxWarning: invalid escape sequence '\s'
#   regexp_streets = '(' + '|'.join(street_names) + ')(\s+([0-9]{1,6}))?'

# %%
regexp_address_prefix = r'\b(calle|avenida|pasaje|pje\.?|parcela|manzana|tira|bloque|casa|lote|barrio)\s*[:]?\s*'
# Palabra o numero
regexp_address_content = r'\b([0-9]{1,6}|[a-zA-Z]+)\b'

address_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_address_prefix,
    content_regex=regexp_address_content,
    re_flags=re.IGNORECASE,
    category='XDIRECCIONX',
    output_type=OUTPUT_TYPE,
)

# Ejemplos
print(address_anonymizer.anonymize("Vive en avenida antartida argentina 1470, se indica medicacion"))
print(address_anonymizer.anonymize("Direccion: calle: 10 de julio, Barrio: alfonsina storini con hermanos"))
print(address_anonymizer.anonymize("Vive en Barrio barrioquenoexiste con hermanos"))
print(address_anonymizer.anonymize("Vive en manzana 3 lote 9 barrio 10 de julio."))
# Out:
# Vive en avenida  XDIRECCIONX argentina 1470, se indica medicacion
# Direccion: calle:  XDIRECCIONX de julio, Barrio:  XDIRECCIONX storini con hermanos
# Vive en Barrio  XDIRECCIONX con hermanos
# Vive en manzana  XDIRECCIONX lote  XDIRECCIONX barrio  XDIRECCIONX de julio.

# %%
documents['anonymized'] = documents['anonymized'].apply(address_w_names_anonymizer.anonymize)
documents['anonymized'] = documents['anonymized'].apply(address_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XDIRECCIONX', case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             original  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGénero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCódigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTeléfono fijo: +34 972 65 06 71\nTeléfono móvil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondición de riesgo: Trabajador de Sanitización\n\nDatos asistenciales.\nMédico: Dra. Emma Vicente Santos. NC 588434040. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartín\n\nInforme clínico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGénero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragón\nCódigo postal: 44075\nEmail: manuela@uca.es\nTeléfono fijo: +34 978 49 11 69\nTeléfono móvil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMédico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clínico del paciente:\nPaciente judío de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGénero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCódigo postal: 07533\nEmail: alejandro@ciberned.es\nTeléfono fijo: +34 971 59 71 11\nTeléfono móvil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondición de riesgo: Soldador\n\nDatos asistenciales.\nMédico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepción Sánchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGénero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellón, Comunidad Valenciana\nCódigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTeléfono fijo: +34 964 68 03 70\nTeléfono móvil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMédico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clínico en Enfermedades Digestivas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clínico del paciente:\nPaciente de ascendencia indígena sudamericana de 13 años de edad, acompañado de su madre. Se realizó un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco López\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGénero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCódigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTeléfono fijo: +34 913 43 68 26\nTeléfono móvil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMédico: Dra. Remedios Casas Martínez. NC 002225764. Residente de 3° año en Oftalmología. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Málaga Oeste\n\nInforme clínico del paciente:\nPaciente exfumador de 59 años de edad. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: María Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGénero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCódigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTeléfono fijo: +34 926 82 07 12\nTeléfono móvil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondición de riesgo: Soldado\n\nDatos asistenciales.\nMédico: Dra. Sofía Zamora Bermudez. NC 674953567. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de León\nMatrícula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGénero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Úbeda, Salamanca, Castilla y León\nCódigo postal: 37590\nEmail: montoya@ciberehd.org\nTeléfono fijo: +34 923 00 92 67\nTeléfono móvil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondición de riesgo: Pintor de Construcción\n\nDatos asistenciales.\nMédico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcalá de Henares\nMatrícula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clínico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.239.21, con dirección MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Méndez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGénero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCódigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTeléfono fijo: +34 942 14 64 21\nTeléfono móvil: +34 742 35 80 90\nNHC: 8508366\nCondición de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMédico: Dr. César Vega Alonso. NC 585819417. Residente de 5° año en Neurología. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática de 88 años de edad, acompañado de su hijo. El servidor para envío de información desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         preprocessed  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 960 66 89 48\nTelefono movil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGenero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTelefono fijo: +34 972 65 06 71\nTelefono movil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGenero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: manuela@uca.es\nTelefono fijo: +34 978 49 11 69\nTelefono movil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGenero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: alejandro@ciberned.es\nTelefono fijo: +34 971 59 71 11\nTelefono movil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGenero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTelefono fijo: +34 964 68 03 70\nTelefono movil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGenero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTelefono fijo: +34 913 43 68 26\nTelefono movil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGenero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTelefono fijo: +34 926 82 07 12\nTelefono movil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGenero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: montoya@ciberehd.org\nTelefono fijo: +34 923 00 92 67\nTelefono movil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGenero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTelefono fijo: +34 942 14 64 21\nTelefono movil: +34 742 35 80 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    anonymized
# 0                                                                                                                                                                                                       Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 48\nTelefono movil: +34 6XFECHAX 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                          Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 6XFECHAX 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                             Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle  XDIRECCIONX los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 71\nTelefono movil: +34 7XFECHAX 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                               Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 69\nTelefono movil: +34 6XFECHAX 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: XFECHAX\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                      Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 11\nTelefono movil: +34 6XFECHAX 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 995                                                                                                                                    Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle  XDIRECCIONX Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 70\nTelefono movil: +34 6XFECHAX 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                                       Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: XFECHAX\nGenero: M\nDomicilio: Calle  XDIRECCIONX Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 26\nTelefono movil: +34 6XFECHAX 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                               Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 12\nTelefono movil: +34 6XFECHAX 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: XFECHAX\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 67\nTelefono movil: +34 6XFECHAX 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                              Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle  XDIRECCIONX Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 21\nTelefono movil: +34 7XFECHAX 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### EFECTOR
#
# Se siguen dos estrategias
# - CAPS y Hospitales por diccionario con trigger words
# - Siglas más usuales (HMN, HMyN, etc)
#
# #### CAPS

# %%
caps = pd.read_csv("datasets/diccionario_caps.csv", sep=';', index_col=None)
caps.head(2)
# Out:
#              Nombre Token0 Token1  Token2 Token3 Token4 Token5 Token6
# 0   caps 20 de mayo   caps     20      de   mayo    NaN    NaN    NaN
# 1  caps agua blanca   caps   agua  blanca    NaN    NaN    NaN    NaN

# %%
# Sanitize caps names
caps_names = [remove_accents(name).replace('caps', '').strip()
                for name in caps.Nombre
                if not re.search(ILLEGAL_CHAR_REGEX, name)]

regexp_caps_prefix = r'(CAPS|CPS)\s*[:\.]?'
regexp_caps_names = r'\b(' + '|'.join(caps_names) + r')\b'

caps_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_caps_prefix,
    content_regex=regexp_caps_names,
    re_flags=re.IGNORECASE,
    category='XCAPSX',
    output_type=OUTPUT_TYPE,
)

print(caps_anonymizer.anonymize("Atendido previamente en caps 20 de mayo, se indica medicacion"))
print(caps_anonymizer.anonymize("Atendido previamente en caps: agua blanca"))
print(caps_anonymizer.anonymize("Atendido previamente en cps: Agua Blanca"))
print(caps_anonymizer.anonymize("Atendido previamente en caps noexiste"))
# Out:
# Atendido previamente en caps  XCAPSX, se indica medicacion
# Atendido previamente en caps: XCAPSX
# Atendido previamente en cps: XCAPSX
# Atendido previamente en caps noexiste

# %%
documents['anonymized'] = documents['anonymized'].apply(caps_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XCAPSX', case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# #### Hospitales

# %%
hospitals = pd.read_csv("datasets/diccionario_hospitales.csv", sep=';', index_col=None)
hospitals.head(2)
# Out:
#                                                 Nombre    Token0    Token1  \
# 0  hospital de la madre y el niño (la rioja) - capital  hospital        de
# 1                                    hospital campanas  hospital  campanas
#
#   Token2 Token3 Token4 Token5 Token6 Token7  Token8 Token9  Token10
# 0     la  madre      y     el   niño    (la  rioja)      -  capital
# 1    NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN      NaN

# %%
# Sanitize hospital names
hospitals_names = [
    remove_accents(name).replace('hospital', '').split('-')[0].split('(')[0].strip()
    for name in hospitals.Nombre
]
hospitals_names = [
    name for name in hospitals_names
    if not re.search(ILLEGAL_CHAR_REGEX, name)
]

regexp_hospital_prefix = r'Hospital|Hosp\.?|H(\.)?\s*[:\.]?'
regexp_hospital_names = r'\b(' + '|'.join(hospitals_names) + r')\b'
regexp_hospital_names = regexp_hospital_names.replace('.', '\.?')

hospital_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_hospital_prefix,
    content_regex=regexp_hospital_names,
    re_flags=re.IGNORECASE,
    category='XHOSPX',
    output_type=OUTPUT_TYPE,
)

print(hospital_anonymizer.anonymize("Atendido previamente en hospital segundo b. romero, se indica medicacion"))
print(hospital_anonymizer.anonymize("Atendido previamente en hospital segundo b romero, se indica medicacion"))
print(hospital_anonymizer.anonymize("Atendido previamente en hosp villa castelli"))
print(hospital_anonymizer.anonymize("Atendido previamente en H  Villa Castelli"))
print(hospital_anonymizer.anonymize("Atendido previamente en hosp por la maniana"))
# Out:
# Atendido previamente en hospital XHOSPX, se indica medicacion
# Atendido previamente en hospital XHOSPX, se indica medicacion
# Atendido previamente en hosp XHOSPX
# Atendido previamente en H   XHOSPX
# Atendido previamente en hosp por la maniana
# <>:13: SyntaxWarning: invalid escape sequence '\.'
# <>:13: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_63444/1765221295.py:13: SyntaxWarning: invalid escape sequence '\.'
#   regexp_hospital_names = regexp_hospital_names.replace('.', '\.?')

# %%
documents['anonymized'] = documents['anonymized'].apply(hospital_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XHOSPX', case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### INSTITUCIÓN

# %%
schools = pd.read_csv("datasets/diccionario_est_educativos.csv", sep=';', index_col=None)
schools.head(2)
# Out:
#                                              Nombre  Tipo Numeración  \
# 0                              esc.n°230 bajo hondo  esc.      n°230
# 1  esc.n°353 batallon de ing. de construcciones 141  esc.      n°353
#
#                             Nombre_limpio    Token0 Token1 Token2 Token3  \
# 0                              bajo hondo      bajo  hondo    NaN    NaN
# 1  batallon de ing. de construcciones 141  batallon     de   ing.     de
#
#            Token4 Token5 Token6 Token7 Token8 Token9 Token10 Token11 Token12  \
# 0             NaN    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 1  construcciones    141    NaN    NaN    NaN    NaN     NaN     NaN     NaN
#
#   Token13 Token14
# 0     NaN     NaN
# 1     NaN     NaN

# %%
# Sanitize school names
# Remove content in ()
school_names = [
    re.sub(r'\(.*?\)', '', name).replace('(', '').replace(')', '').strip()
    for name in schools.Nombre_limpio if isinstance(name, str)
]
school_names = set([
    remove_accents(name)
    for name in school_names if len(name) > 1 and not re.search(ILLEGAL_CHAR_REGEX, name)
])

regexp_school_main = r'escuela|esc\.|esc|colegio|jardin|infantes|instituto'
regexp_school_detail = r'primari[ao]|normal|secundari[ao]|privad[ao]|maternal|especial'
regexp_school_number = r'(\sn\s?\.?\°?)?\s*[0-9]+'
regexp_school_prefix = rf'({regexp_school_main})(?:\s+(?:{regexp_school_detail}))?'

regexp_school_names = '|'.join(school_names)
regexp_school_names = regexp_school_names.replace('.', '\.?')
regexp_school_names = rf'({regexp_school_number}\s?)?({regexp_school_names})'

# Anonimiza el nombre de los establecimientos
school_name_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_school_prefix,
    content_regex=regexp_school_names,
    re_flags=re.IGNORECASE,
    category='XINSTITUCIONX',
    output_type=OUTPUT_TYPE,
)

print(school_name_anonymizer.anonymize("Asiste a jardin maternal rincon de luz."))
print(school_name_anonymizer.anonymize("Asiste a colegio bajo hondo."))
print(school_name_anonymizer.anonymize("Asiste a colegio secundario bajo hondo."))
print(school_name_anonymizer.anonymize("Asiste a esc normal dr. jose santos salinas por la tarde"))
print(school_name_anonymizer.anonymize("Asiste a esc normal inexistente"))
print(school_name_anonymizer.anonymize("Asiste a esc n 345 munic.beatriz de la v.de costa medina"))
print(school_name_anonymizer.anonymize("Asiste a Esc. n° 345 para el paicor"))
# Out:
# Asiste a jardin maternal XINSTITUCIONX.
# Asiste a colegio XINSTITUCIONX.
# Asiste a colegio secundario XINSTITUCIONX.
# Asiste a esc XINSTITUCIONX por la tarde
# Asiste a esc normal inexistente
# Asiste a esc XINSTITUCIONX
# Asiste a Esc. n° 345 para el paicor
# <>:18: SyntaxWarning: invalid escape sequence '\.'
# <>:18: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_63444/1147442673.py:18: SyntaxWarning: invalid escape sequence '\.'
#   regexp_school_names = regexp_school_names.replace('.', '\.?')

# %%
# Anonimiza solo el numero
school_number_anonymizer = PrefixRegexAnnonimizer(
    prefix_regex=regexp_school_prefix,
    content_regex=regexp_school_number,
    re_flags=re.IGNORECASE,
    category='XINSTITUCIONX',
    output_type=OUTPUT_TYPE,
)

print(school_number_anonymizer.anonymize("Asiste a esc normal inexistente"))
print(school_number_anonymizer.anonymize("Asiste a esc n 345 munic.beatriz de la v.de costa medina"))
print(school_number_anonymizer.anonymize("Asiste a Esc. n° 345 para el paicor"))
# Out:
# Asiste a esc normal inexistente
# Asiste a esc XINSTITUCIONX munic.beatriz de la v.de costa medina
# Asiste a Esc. XINSTITUCIONX para el paicor

# %%
documents['anonymized'] = documents['anonymized'].apply(school_name_anonymizer.anonymize)
documents['anonymized'] = documents['anonymized'].apply(school_number_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XINSTITUCIONX', case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# #### Grados

# %%
# regexp_grado = re.compile(r'^grado$', re.IGNORECASE)
# regexp_grado_letras = re.compile(r'^primer$|^segundo$|^tercer$|^cuarto$|^quinto$|^sexto$|^septimo$', re.IGNORECASE)
# regexp_grado_combinado = re.compile(r'[0-9]{1}[a-z]{1,3}|[0-9]{1}º', re.IGNORECASE)
# regexp_grado_exclusión = re.compile(r'obesidad|quemadura|evoluci[oóò]n', re.IGNORECASE)

# def deidentificar_grado(texto_a_deidentificar):
#     lista_texto_a_deidentificar=texto_a_deidentificar.split(' ')
    
#     ## Iteración entre tokens de la lista del texto a deidentificar
#     for j, token in enumerate(lista_texto_a_deidentificar):
    
#         # Detecta si el token actual es grado
#         if regexp_grado.search(lista_texto_a_deidentificar[j]):
#             #Excluyo grados de obesidad y quemaduras
#             if not regexp_grado_exclusión.search(lista_texto_a_deidentificar[j-3]) or regexp_grado_exclusión.search(lista_texto_a_deidentificar[j-2]):
#                 if regexp_grado_letras.search(lista_texto_a_deidentificar[j-1]) or regexp_grado_combinado.search(lista_texto_a_deidentificar[j-1]):
#                 # Reemplazar el token actual por el patrón correspondiente
#                     if output_tipo==1:
#                         lista_texto_a_deidentificar[j] = '<'+ lista_texto_a_deidentificar[j] +'>'
#                         lista_texto_a_deidentificar[j-1] = '<'+ lista_texto_a_deidentificar[j-1] +'>'
#                     if output_tipo==2:
#                         lista_texto_a_deidentificar[j] = 'XXXX'
#                         lista_texto_a_deidentificar[j-1] = 'XXXX'
#                     if output_tipo==3:
#                         lista_texto_a_deidentificar[j] = 'XGRADOX'
#                         lista_texto_a_deidentificar[j-1] = 'XGRADOX'
    
#     # Generar el texto deidentificado concatenando todos los tokens ya revisados (y modificados si corrrespondiera)
#     return ' '.join(lista_texto_a_deidentificar)
    
# textos_a_deidentificar['texto_anonimizado'] = textos_a_deidentificar['texto_anonimizado'].apply(deidentificar_grado)

# %% [markdown]
# #### Turnos

# %%
## Expresión regular para TURNOS
regexp_shcool_turn = r'\b(turno mañana|turno tarde|TT|TM)\b'

shcool_turn_anonymizer = RegexAnnonimizer(
    content_regex=regexp_shcool_turn,
    category='XTURNOX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
)

print(shcool_turn_anonymizer.anonymize("Asiste a esc en turno tarde"))
print(shcool_turn_anonymizer.anonymize("Asiste a esc sexto grado TT por la mañana,"))
print(shcool_turn_anonymizer.anonymize("Asiste a esc sexto grado turno mañana."))
# Out:
# Asiste a esc en XTURNOX
# Asiste a esc sexto grado XTURNOX por la mañana,
# Asiste a esc sexto grado XTURNOX.

# %%
documents['anonymized'] = documents['anonymized'].apply(school_name_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XTURNOX', case=False)]
# Out:
# Empty DataFrame
# Columns: [original, preprocessed, anonymized]
# Index: []

# %% [markdown]
# ### ZONA

# %%
neighborhood = pd.read_csv("datasets/diccionario_barrios_populares.csv", sep=';')
province = pd.read_csv("datasets/diccionario_provincias.csv", sep=';')
city = pd.read_csv("datasets/diccionario_localidades.csv", sep=';')
county = pd.read_csv("datasets/diccionario_municipios.csv", sep=';')

county.head()
# Out:
#           ciudad     Token0  Token1 Token2 Token3 Token4
# 0      aimogasta  aimogasta     NaN    NaN    NaN    NaN
# 1         arauco     arauco     NaN    NaN    NaN    NaN
# 2         aminga     aminga     NaN    NaN    NaN    NaN
# 3  castro barros     castro  barros    NaN    NaN    NaN
# 4       chamical   chamical     NaN    NaN    NaN    NaN

# %%
location_names = (
    neighborhood['nombre'].values.tolist() + county['ciudad'].values.tolist() +
    city['nombre'].values.tolist() + province['provincia_nombre'].values.tolist()
)

location_names = set([
    remove_accents(name)
    for name in location_names if len(name) > 1 and not re.search(ILLEGAL_CHAR_REGEX, name)
])

regexp_locations = r'\b(' + '|'.join(location_names) + r')\b'

location_anonymizer = RegexAnnonimizer(
    content_regex=regexp_locations,
    category='XZONAX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
)

print(location_anonymizer.anonymize("Paciente se traslada desde Chamical para consulta"))
print(location_anonymizer.anonymize("Paciente se traslada desde CASTRO BARROS, para consulta"))
# Out:
# Paciente se traslada desde XZONAX para consulta
# Paciente se traslada desde XZONAX, para consulta

# %%
documents['anonymized'] = documents['anonymized'].apply(location_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XZONAX', case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        original  \
# 1    Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                       Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGénero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCódigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTeléfono fijo: +34 972 65 06 71\nTeléfono móvil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondición de riesgo: Trabajador de Sanitización\n\nDatos asistenciales.\nMédico: Dra. Emma Vicente Santos. NC 588434040. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartín\n\nInforme clínico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                             Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGénero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragón\nCódigo postal: 44075\nEmail: manuela@uca.es\nTeléfono fijo: +34 978 49 11 69\nTeléfono móvil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMédico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clínico del paciente:\nPaciente judío de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                             Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGénero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCódigo postal: 07533\nEmail: alejandro@ciberned.es\nTeléfono fijo: +34 971 59 71 11\nTeléfono móvil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondición de riesgo: Soldador\n\nDatos asistenciales.\nMédico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 7 años de edad, acompañado de su abuela.
# 5                                                                                                               Datos del paciente.\nNombre: Eric Gómez Miranda\nDNI: 42454786Y\nFecha de nacimiento: 27/07/2011\nGénero: Masculino\nDomicilio: Calle Mayor 52, 1G\nCiudad: Denia, Granada, Andalucía\nCódigo postal: 18120\nEmail: z0nADoFh@ciberer.es\nTeléfono fijo: +34 958 85 44 29\nFAX: +34 958 35 32 63\nNHC: 2587788\nNASS: 740061735290\nCondición de riesgo: Pintor de Construcción\n\nDatos asistenciales.\nMédico: Dra. Esperanza Plaza Espinosa. NC 965989298. Investigadora Clínica en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 01/01/2013\nEpisodio: 21132443\nCentro de salud: Centro de Salud Majadahonda\n\nInforme clínico del paciente:\nPaciente vegano de un año de edad, acompañado de su hermano. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es KR005NQB160.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 978                                                  Datos del paciente.\nNombre: María Josefa Núñez Zamora\nDNI: 80846408M\nFecha de nacimiento: 23/11/1927\nGénero: F\nDomicilio: Calle Mayor 80\nCiudad: Burgos, Región de Murcia, Región de Murcia\nCódigo postal: 30684\nEmail: mariajosefa.nunezzamora@isciii.es\nTeléfono fijo: +34 968 26 94 08\nTeléfono móvil: +34 768 84 78 40\nNHC: 4177813\nNASS: 117556076503\nCondición de riesgo: Trabajador de Laboratorio\n\nDatos asistenciales.\nMédico: Dra. Ana Isabel Domínguez Gil. NC 837036567. Cardióloga de Unidad de Cuidados Intensivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 17/08/1975\nHospital: Hospital Universitario de Crúces\nMatrícula del coche: 1090JFQ\nModelo: Ford Mustang\nVIN: VSY27JP1BJD366945\n\nInforme clínico del paciente:\nPaciente vegetariano de 47 años de edad. Se registró una sesión de huella dactilar, el código obtenido para revisarla es KT511AEO403.
# 990                                                                                                                                                           Datos del paciente.\nNombre: José Ramón Segura Exposito\nDNI: 91227227G\nFecha de nacimiento: 21/10/1956\nGénero: V\nDomicilio: Calle de San Ildefonso 44, 3U\nCiudad: Ibiza, La Rioja, La Rioja\nCódigo postal: 26255\nEmail: joseramon_exposito@udc.es\nTeléfono fijo: +34 941 17 04 22\nTeléfono móvil: +34 641 49 46 85\nNHC: 7607301\nCondición de riesgo: Ama de casa\n\nDatos asistenciales.\nMédico: Dra. Alba Menendez Vidal. NC 674912935. Investigadora Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 22/07/1964\nEpisodio: 96179842\nCentro de salud: Centro de Salud Málaga Sur\n\nInforme clínico del paciente:\nPaciente refugiado de 7 años de edad, acompañado de su abuela. Se realizó un expediente con URL http://example-dermatology.org//50515210P.
# 991                                                                                                              Datos del paciente.\nNombre: Ana María Cruz Casado\nDNI: 63351952Q\nFecha de nacimiento: 15/09/1962\nGénero: F\nDomicilio: Calle de Menorca 13, 5S\nCiudad: Alcázar de San Juan, Zamora, Castilla y León\nCódigo postal: 49922\nEmail: cruz1111@outlook.com\nTeléfono fijo: +34 980 67 91 71\nTeléfono móvil: +34 680 52 32 98\nNHC: 6584399\nNASS: 654472216287\nCondición de riesgo: Técnico de Radiología\n\nDatos asistenciales.\nMédico: Dr. Marco Cano Ortiz. NC 074644894. Residente de 4° año en Endocrinología. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 18/12/1969\nEpisodio: 53534753\nCentro de salud: Centro de Salud Centro\n\nInforme clínico del paciente:\nPaciente de tez blanca de 7 años de edad, acompañado de su tío. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es TH262XMH799.
# 993                                                                    Datos del paciente.\nNombre: Aurora Padilla Aguilar\nDNI: 98220467W\nFecha de nacimiento: 16/09/1963\nGénero: Femenino\nDomicilio: Calle del Fúcar 54, 4I\nCiudad: Ermua, Córdoba, Andalucía\nCódigo postal: 14127\nEmail: aurorapadilla-aguilar@protonmail.com\nTeléfono fijo: +34 957 37 85 03\nTeléfono móvil: +34 757 60 53 11\nNHC: 9182435\nCondición de riesgo: Albañil\n\nDatos asistenciales.\nMédico: Dra. María Ángeles Marín Montoya. NC 864247234. Residente de 4° año en Cardiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/08/1988\nEpisodio: 68943682\nCentro de salud: Centro de Salud Alcalá de Henares\n\nInforme clínico del paciente:\nPaciente no fumador de 24 años de edad, acompañado de su abuela. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.194.35, con dirección MAC 57:56:C9:8E:80:20.
# 997                                                                                            Datos del paciente.\nNombre: María Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGénero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCódigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTeléfono fijo: +34 926 82 07 12\nTeléfono móvil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondición de riesgo: Soldado\n\nDatos asistenciales.\nMédico: Dra. Sofía Zamora Bermudez. NC 674953567. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de León\nMatrícula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    preprocessed  \
# 1    Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                       Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGenero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTelefono fijo: +34 972 65 06 71\nTelefono movil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                             Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGenero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: manuela@uca.es\nTelefono fijo: +34 978 49 11 69\nTelefono movil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                             Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGenero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: alejandro@ciberned.es\nTelefono fijo: +34 971 59 71 11\nTelefono movil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# 5                                                                                                               Datos del paciente.\nNombre: Eric Gomez Miranda\nDNI: 42454786Y\nFecha de nacimiento: 27/07/2011\nGenero: Masculino\nDomicilio: Calle Mayor 52, 1G\nCiudad: Denia, Granada, Andalucia\nCodigo postal: 18120\nEmail: z0nADoFh@ciberer.es\nTelefono fijo: +34 958 85 44 29\nFAX: +34 958 35 32 63\nNHC: 2587788\nNASS: 740061735290\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Esperanza Plaza Espinosa. NC 965989298. Investigadora Clinica en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 01/01/2013\nEpisodio: 21132443\nCentro de salud: Centro de Salud Majadahonda\n\nInforme clinico del paciente:\nPaciente vegano de un año de edad, acompañado de su hermano. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es KR005NQB160.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 978                                                  Datos del paciente.\nNombre: Maria Josefa Nuñez Zamora\nDNI: 80846408M\nFecha de nacimiento: 23/11/1927\nGenero: F\nDomicilio: Calle Mayor 80\nCiudad: Burgos, Region de Murcia, Region de Murcia\nCodigo postal: 30684\nEmail: mariajosefa.nunezzamora@isciii.es\nTelefono fijo: +34 968 26 94 08\nTelefono movil: +34 768 84 78 40\nNHC: 4177813\nNASS: 117556076503\nCondicion de riesgo: Trabajador de Laboratorio\n\nDatos asistenciales.\nMedico: Dra. Ana Isabel Dominguez Gil. NC 837036567. Cardiologa de Unidad de Cuidados Intensivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 17/08/1975\nHospital: Hospital Universitario de Cruces\nMatricula del coche: 1090JFQ\nModelo: Ford Mustang\nVIN: VSY27JP1BJD366945\n\nInforme clinico del paciente:\nPaciente vegetariano de 47 años de edad. Se registro una sesion de huella dactilar, el codigo obtenido para revisarla es KT511AEO403.
# 990                                                                                                                                                           Datos del paciente.\nNombre: Jose Ramon Segura Exposito\nDNI: 91227227G\nFecha de nacimiento: 21/10/1956\nGenero: V\nDomicilio: Calle de San Ildefonso 44, 3U\nCiudad: Ibiza, La Rioja, La Rioja\nCodigo postal: 26255\nEmail: joseramon_exposito@udc.es\nTelefono fijo: +34 941 17 04 22\nTelefono movil: +34 641 49 46 85\nNHC: 7607301\nCondicion de riesgo: Ama de casa\n\nDatos asistenciales.\nMedico: Dra. Alba Menendez Vidal. NC 674912935. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 22/07/1964\nEpisodio: 96179842\nCentro de salud: Centro de Salud Malaga Sur\n\nInforme clinico del paciente:\nPaciente refugiado de 7 años de edad, acompañado de su abuela. Se realizo un expediente con URL http://example-dermatology.org//50515210P.
# 991                                                                                                              Datos del paciente.\nNombre: Ana Maria Cruz Casado\nDNI: 63351952Q\nFecha de nacimiento: 15/09/1962\nGenero: F\nDomicilio: Calle de Menorca 13, 5S\nCiudad: Alcazar de San Juan, Zamora, Castilla y Leon\nCodigo postal: 49922\nEmail: cruz1111@outlook.com\nTelefono fijo: +34 980 67 91 71\nTelefono movil: +34 680 52 32 98\nNHC: 6584399\nNASS: 654472216287\nCondicion de riesgo: Tecnico de Radiologia\n\nDatos asistenciales.\nMedico: Dr. Marco Cano Ortiz. NC 074644894. Residente de 4° año en Endocrinologia. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 18/12/1969\nEpisodio: 53534753\nCentro de salud: Centro de Salud Centro\n\nInforme clinico del paciente:\nPaciente de tez blanca de 7 años de edad, acompañado de su tio. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es TH262XMH799.
# 993                                                                    Datos del paciente.\nNombre: Aurora Padilla Aguilar\nDNI: 98220467W\nFecha de nacimiento: 16/09/1963\nGenero: Femenino\nDomicilio: Calle del Fucar 54, 4I\nCiudad: Ermua, Cordoba, Andalucia\nCodigo postal: 14127\nEmail: aurorapadilla-aguilar@protonmail.com\nTelefono fijo: +34 957 37 85 03\nTelefono movil: +34 757 60 53 11\nNHC: 9182435\nCondicion de riesgo: Albañil\n\nDatos asistenciales.\nMedico: Dra. Maria Angeles Marin Montoya. NC 864247234. Residente de 4° año en Cardiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/08/1988\nEpisodio: 68943682\nCentro de salud: Centro de Salud Alcala de Henares\n\nInforme clinico del paciente:\nPaciente no fumador de 24 años de edad, acompañado de su abuela. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.194.35, con direccion MAC 57:56:C9:8E:80:20.
# 997                                                                                            Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGenero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTelefono fijo: +34 926 82 07 12\nTelefono movil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         anonymized
# 1    Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX Arganzuela 18\nCiudad: Gijon, XZONAX, XZONAX\nCodigo postal: 26167\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 6XFECHAX 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                   Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle  XDIRECCIONX los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 71\nTelefono movil: +34 7XFECHAX 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 69\nTelefono movil: +34 6XFECHAX 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. XZONAX. España.\nFecha de ingreso: XFECHAX\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                            Datos del paciente.\nNombre: Alejandro XZONAX Galvez\nDNI: 61787147Q\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 11\nTelefono movil: +34 6XFECHAX 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# 5                                                                                                               Datos del paciente.\nNombre: Eric Gomez XZONAX\nDNI: 42454786Y\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle  XDIRECCIONX 52, 1G\nCiudad: Denia, Granada, Andalucia\nCodigo postal: 18120\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 29\nFAX: +34 9XFECHAX 63\nNHC: 2587788\nNASS: 740061735290\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Esperanza Plaza Espinosa. NC 965989298. Investigadora Clinica en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 21132443\nCentro de salud: Centro de Salud Majadahonda\n\nInforme clinico del paciente:\nPaciente vegano de un año de edad, acompañado de su hermano. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es KR005NQB160.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 978                                                          Datos del paciente.\nNombre: Maria Josefa Nuñez Zamora\nDNI: 80846408M\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX 80\nCiudad: Burgos, Region de Murcia, Region de Murcia\nCodigo postal: 30684\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 08\nTelefono movil: +34 7XFECHAX 40\nNHC: 4177813\nNASS: 117556076503\nCondicion de riesgo: Trabajador de Laboratorio\n\nDatos asistenciales.\nMedico: Dra. Ana Isabel Dominguez Gil. NC 837036567. Cardiologa de Unidad de Cuidados Intensivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. Madrid. España.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario de Cruces\nMatricula del coche: 1090JFQ\nModelo: Ford Mustang\nVIN: VSY27JP1BJD366945\n\nInforme clinico del paciente:\nPaciente vegetariano de 47 años de edad. Se registro una sesion de huella dactilar, el codigo obtenido para revisarla es KT511AEO403.
# 990                                                                                                                                                       Datos del paciente.\nNombre: Jose Ramon Segura Exposito\nDNI: 91227227G\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle  XDIRECCIONX San Ildefonso 44, 3U\nCiudad: Ibiza, XZONAX, XZONAX\nCodigo postal: 26255\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 22\nTelefono movil: +34 6XFECHAX 85\nNHC: 7607301\nCondicion de riesgo: Ama de casa\n\n XDIRECCIONX asistenciales.\nMedico: Dra. Alba Menendez Vidal. NC 674912935. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 96179842\nCentro de salud: Centro de Salud Malaga Sur\n\nInforme clinico del paciente:\nPaciente refugiado de 7 años de edad, acompañado de su abuela. Se realizo un expediente con URL http://example-dermatology.org//50515210P.
# 991                                                                                                               Datos del paciente.\nNombre: Ana Maria Cruz Casado\nDNI: 63351952Q\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX Menorca 13, 5S\nCiudad: Alcazar de XZONAX, Zamora, Castilla y Leon\nCodigo postal: 49922\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 71\nTelefono movil: +34 6XFECHAX 98\nNHC: 6584399\nNASS: 654472216287\nCondicion de riesgo: Tecnico de Radiologia\n\nDatos asistenciales.\nMedico: Dr. Marco Cano Ortiz. NC 074644894. Residente de 4° año en Endocrinologia. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. XZONAX. España.\nFecha de ingreso: XFECHAX\nEpisodio: 53534753\nCentro de salud: Centro de Salud Centro\n\nInforme clinico del paciente:\nPaciente de tez blanca de 7 años de edad, acompañado de su tio. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es TH262XMH799.
# 993                                                                                   Datos del paciente.\nNombre: Aurora Padilla Aguilar\nDNI: 98220467W\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle  XDIRECCIONX Fucar 54, 4I\nCiudad: Ermua, XZONAX, Andalucia\nCodigo postal: 14127\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 03\nTelefono movil: +34 7XFECHAX 11\nNHC: 9182435\nCondicion de riesgo: Albañil\n\nDatos asistenciales.\nMedico: Dra. Maria Angeles Marin Montoya. NC 864247234. Residente de 4° año en Cardiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: XFECHAX\nEpisodio: 68943682\nCentro de salud: Centro de Salud Alcala de Henares\n\nInforme clinico del paciente:\nPaciente no fumador de 24 años de edad, acompañado de su abuela. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.194.35, con direccion MAC 57:56:C9:8E:80:20.
# 997                                                                                                      Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 12\nTelefono movil: +34 6XFECHAX 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. XZONAX. España.\nFecha de ingreso: XFECHAX\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
#
# [333 rows x 3 columns]

# %% [markdown]
# ### PAÍS
#
# Preparación del listado de paises a detectar:

# %%
countries = pd.read_csv("datasets/diccionario_paises.csv", sep=';', index_col=None)

# Filtro algunas entradas teniendo en cuenta que su uso como país es muy infrecuente en el nuestro.
p1 = re.compile(
    'Nueva|Reunion|San Martin|Islas Cocos \(Keeling\)|india|malta|montenegro|guadalupe|mauricio|laos|'
    'eritrea|iran|polonia|portugal|camboya|islas malvinas|antartida|argentina',
    re.IGNORECASE)

countries = countries[~countries['nombre'].str.contains(p1)]
countries.tail()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\('
# <>:5: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipykernel_63444/737399818.py:5: SyntaxWarning: invalid escape sequence '\('
#   'Nueva|Reunion|San Martin|Islas Cocos \(Keeling\)|india|malta|montenegro|guadalupe|mauricio|laos|'
#               nombre    Token0 Token1  Token2 Token3 Token4 Token5 Token6  \
# 243  wallis y futuna    wallis      y  futuna    NaN    NaN    NaN    NaN
# 244            yemen     yemen    NaN     NaN    NaN    NaN    NaN    NaN
# 245           yibuti    yibuti    NaN     NaN    NaN    NaN    NaN    NaN
# 246           zambia    zambia    NaN     NaN    NaN    NaN    NaN    NaN
# 247         zimbabue  zimbabue    NaN     NaN    NaN    NaN    NaN    NaN
#
#     Token7
# 243    NaN
# 244    NaN
# 245    NaN
# 246    NaN
# 247    NaN

# %%
country_names = set([
    remove_accents(name).strip()
    for name in countries.nombre if len(name) > 1 and not re.search(ILLEGAL_CHAR_REGEX, name)
])

regexp_countries = r'\b(' + r'|'.join(country_names) + r')\b'

country_anonymizer = RegexAnnonimizer(
    content_regex=regexp_countries,
    category='XPAISX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
)

print(country_anonymizer.anonymize("Paciente se traslada desde ZAMBIA para consulta"))
print(country_anonymizer.anonymize("Paciente se traslada desde wallis y futuna, para consulta"))
# Out:
# Paciente se traslada desde XPAISX para consulta
# Paciente se traslada desde XPAISX, para consulta

# %%
documents['anonymized'] = documents['anonymized'].apply(country_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XPAISX', case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             original  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGénero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCódigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTeléfono fijo: +34 972 65 06 71\nTeléfono móvil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondición de riesgo: Trabajador de Sanitización\n\nDatos asistenciales.\nMédico: Dra. Emma Vicente Santos. NC 588434040. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartín\n\nInforme clínico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGénero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragón\nCódigo postal: 44075\nEmail: manuela@uca.es\nTeléfono fijo: +34 978 49 11 69\nTeléfono móvil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMédico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clínico del paciente:\nPaciente judío de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGénero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCódigo postal: 07533\nEmail: alejandro@ciberned.es\nTeléfono fijo: +34 971 59 71 11\nTeléfono móvil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondición de riesgo: Soldador\n\nDatos asistenciales.\nMédico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepción Sánchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGénero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellón, Comunidad Valenciana\nCódigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTeléfono fijo: +34 964 68 03 70\nTeléfono móvil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMédico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clínico en Enfermedades Digestivas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clínico del paciente:\nPaciente de ascendencia indígena sudamericana de 13 años de edad, acompañado de su madre. Se realizó un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco López\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGénero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCódigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTeléfono fijo: +34 913 43 68 26\nTeléfono móvil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMédico: Dra. Remedios Casas Martínez. NC 002225764. Residente de 3° año en Oftalmología. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Málaga Oeste\n\nInforme clínico del paciente:\nPaciente exfumador de 59 años de edad. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: María Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGénero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCódigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTeléfono fijo: +34 926 82 07 12\nTeléfono móvil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondición de riesgo: Soldado\n\nDatos asistenciales.\nMédico: Dra. Sofía Zamora Bermudez. NC 674953567. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de León\nMatrícula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGénero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Úbeda, Salamanca, Castilla y León\nCódigo postal: 37590\nEmail: montoya@ciberehd.org\nTeléfono fijo: +34 923 00 92 67\nTeléfono móvil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondición de riesgo: Pintor de Construcción\n\nDatos asistenciales.\nMédico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcalá de Henares\nMatrícula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clínico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.239.21, con dirección MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Méndez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGénero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCódigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTeléfono fijo: +34 942 14 64 21\nTeléfono móvil: +34 742 35 80 90\nNHC: 8508366\nCondición de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMédico: Dr. César Vega Alonso. NC 585819417. Residente de 5° año en Neurología. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática de 88 años de edad, acompañado de su hijo. El servidor para envío de información desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         preprocessed  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 960 66 89 48\nTelefono movil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGenero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTelefono fijo: +34 972 65 06 71\nTelefono movil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGenero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: manuela@uca.es\nTelefono fijo: +34 978 49 11 69\nTelefono movil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGenero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: alejandro@ciberned.es\nTelefono fijo: +34 971 59 71 11\nTelefono movil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGenero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTelefono fijo: +34 964 68 03 70\nTelefono movil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGenero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTelefono fijo: +34 913 43 68 26\nTelefono movil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGenero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTelefono fijo: +34 926 82 07 12\nTelefono movil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGenero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: montoya@ciberehd.org\nTelefono fijo: +34 923 00 92 67\nTelefono movil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGenero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTelefono fijo: +34 942 14 64 21\nTelefono movil: +34 742 35 80 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    anonymized
# 0                                                                                                                                                                                                       Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 48\nTelefono movil: +34 6XFECHAX 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. XPAISX.\nFecha de ingreso: XFECHAX\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                               Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX Arganzuela 18\nCiudad: Gijon, XZONAX, XZONAX\nCodigo postal: 26167\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 6XFECHAX 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. Madrid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                              Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle  XDIRECCIONX los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 71\nTelefono movil: +34 7XFECHAX 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. Madrid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                 Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 69\nTelefono movil: +34 6XFECHAX 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. XZONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                       Datos del paciente.\nNombre: Alejandro XZONAX Galvez\nDNI: 61787147Q\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 11\nTelefono movil: +34 6XFECHAX 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 995                                                                                                                                    Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle  XDIRECCIONX Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 70\nTelefono movil: +34 6XFECHAX 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                                       Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: XFECHAX\nGenero: M\nDomicilio: Calle  XDIRECCIONX Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 26\nTelefono movil: +34 6XFECHAX 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y Cajal, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                                 Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 12\nTelefono movil: +34 6XFECHAX 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX Pidal, s/n. 14004. XZONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 67\nTelefono movil: +34 6XFECHAX 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y Cajal, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                              Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle  XDIRECCIONX Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 21\nTelefono movil: +34 7XFECHAX 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida  XDIRECCIONX de Lemos 3-5. 28029. Madrid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### PERSONA
#
# Chequea token a token si:
#
# - ~~comienza con mayúscual y sigue con minúsculas~~
# - es un nombre,
# - es un apellido

# %%
## Lista de nombres en minúscula, sin números, con al menos 3 letras, sin stop Words y con frecuencia mayor a 5000.
first_names = pd.read_csv("datasets/nombres_editados.csv", sep=';', index_col = None)['nombre_limpio'].to_list()
last_names = pd.read_csv("datasets/apellidos_unicos.csv", sep=';', index_col = None)['apellido'].to_list()
names = [
    remove_accents(name).strip()
    for name in first_names + last_names
    if isinstance(name, str) and len(name) > 1 and not re.search(ILLEGAL_CHAR_REGEX, name)
]
names[:5]
# Out:
# ['aaron', 'abel', 'abelardo', 'abigail', 'abraham']

# %%
len(set(names))
# Out:
# 75911

# %%
# Exclude common noun names from list
noun_names = [
    'papa', 'tamaño', 'salud', 'hospital', 'niño', 'medico', 'toma', 'fecha', 'rodilla', 'vigil',
    'abajo', 'alegre', 'abusar', 'cola', 'cancela', 'grande', 'cortes', 'saliva', 'sola', 
    'areas', 'bajo', 'bien', 'blando', 'bota', 'buena', 'pareja', 'claro', 'claros', 'colica', 
    'cornea', 'cristalino', 'agua', 'corto', 'tiempo', 'grado', 'dieta', 'entrada', 'esposo', 
    'izquierdo', 'genera', 'general', 'genero', 'grados', 'haber', 'hierro', 'tres', 'igual', 
    'indico', 'plano', 'ligero', 'mañana', 'medica', 'medio', 'mucha', 'nacer', 'noto', 
    'parejas', 'pares', 'parto', 'pene', 'peso', 'piernas', 'requiere', 'semana', 'vaginal', 
    'varon', 'vino', 'nacimiento', 'hitos', 'menor', 'cordon', 'cuello', 'guardia', 'muñeca',
    'factor', 'chagas', 'sano', 'camino', 'manera', 'signo', 'come', 'solo', 'sola', 'cera',
    'tapon', 'cabeza', 'base', 'lenta', 'patron', 'borde', 'abuela', 'alli', 'alto', 'amigo',
    'anillo', 'aporta', 'area', 'arriba', 'bajar', 'balon', 'barrio', 'beber', 'boca',
    'brindo', 'bueno', 'busca', 'calle', 'calores', 'campo', 'cara', 'cargo', 'casa',
    'casi', 'caso', 'causa', 'cayo', 'cece', 'cena', 'chica', 'chico', 'constante',
    'cuadro', 'cuesta', 'debi', 'debia', 'deseo', 'deseo', 'DESEO', 'dias', 'dios',
    'done', 'dura', 'duro', 'escalera', 'estudia', 'figura', 'foco', 'Fondo', 'fosas',
    'fuertes', 'gato', 'gotas', 'guarda', 'hacen', 'haga', 'Jardin', 'labo', 'lado', 'lava',
    'legal', 'ligo', 'mala', 'mando', 'mano', 'mares', 'matar', 'mayor', 'medicina',
    'mesas', 'mori', 'mover', 'nace', 'nota', 'nuevo', 'pala', 'panico', 'pared', 'paro',
    'placer', 'presentado', 'presta', 'primo', 'publico', 'quiero', 'quizas', 'raiz',
    'redes', 'respeto', 'riesgo', 'rojo', 'rota', 'ruta', 'saber', 'sabia', 'sale',
    'sangra', 'segundo', 'segura', 'seis', 'severo', 'sobrino', 'soma', 'sule', 'teme',
    'terceros', 'tira', 'tirado', 'torno', 'trabajo', 'tranquilo', 'valor', 'vaya',
    'vender', 'vida', 'vital', 'vive', 'vivian', 'vuelo', 'comer', 'fuerte', 'doble', 'sorda',
    'numero', 'dolores', 'rostro', 'paterno', 'colon', 'diab', 'corte', 'crema',
    'bazo', 'camara', 'rabia', 'fuma', 'calcio', 'indice', 'timpano', 'mandato', 'escuela',
    'venia', 'vecino', 'terreno', 'sordo', 'salia', 'sala', 'saco', 'regalo', 'reales',
    'real', 'rato', 'rama', 'puerta', 'plata', 'pase', 'molares', 'llano', 'feto',
    'espinal', 'decia', 'cosa', 'carta', 'carne', 'cabello', 'brusco', 'bordes', 'bases',
    'baño', 'baba', 'avanza', 'amor', 'labio', 'maligno', 'teta'
]

names = set([name for name in names if name not in noun_names])
len(set(names))
# Out:
# 75654

# %%
regexp_names = r'\b({})\b'.format('|'.join(names))

name_anonymizer = RegexAnnonimizer(
    content_regex=regexp_names,
    category='XPERSONAX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
    verbose=True
)

print(name_anonymizer.anonymize("Paciente con tumor de gran tamaño medico con ibuprofeno."))
print(name_anonymizer.anonymize("Caida del cordon umbilical."))
print(name_anonymizer.anonymize("Acude a consulta con hermano Abel."))
# Out:
# Paciente con tumor de gran tamaño medico con ibuprofeno.
# Caida del cordon umbilical.
# Replacing Abel
# Acude a consulta con hermano XPERSONAX.

# %%
documents['anonymized'] = documents['anonymized'].apply(name_anonymizer.anonymize)
# Out:
# Replacing Maria
# Replacing Soledad
# Replacing Moreno
# Replacing Roca
# Replacing Almagro
# Replacing Ciudad
# Replacing Valencia
# Replacing NASS
# Replacing Juan
# Replacing Ramon
# Replacing Benito
# Replacing Vicente
# Replacing Lemos
# Replacing Madrid
# Replacing Victoria
# Replacing Plaza
# Replacing Roca
# Replacing Ciudad
# Replacing Gijon
# Replacing NASS
# Replacing Eric
# Replacing Alarcon
# Replacing Pascual
# Replacing Madrid
# Replacing Malaga
# Replacing coche
# Replacing Mercedes
# Replacing Benz
# Replacing iris
# Replacing Iñigo
# Replacing Escobar
# Replacing Rivero
# Replacing Ciudad
# Replacing NASS
# Replacing Emma
# Replacing Vicente
# Replacing Santos
# Replacing Madrid
# Replacing Manuela
# Replacing Morales
# Replacing Cabrera
# Replacing Ciudad
# Replacing Elda
# Replacing Teruel
# Replacing Aragon
# Replacing Susana
# Replacing Carmona
# Replacing Pidal
# Replacing Alejandro
# Replacing Galvez
# Replacing Luna
# Replacing Ciudad
# Replacing Palma
# Replacing Islas
# Replacing NASS
# Replacing Omar
# Replacing Guerrero
# Replacing Maldonado
# Replacing Lemos
# Replacing Madrid
# Replacing Eric
# Replacing Gomez
# Replacing Ciudad
# Replacing NASS
# Replacing Pintor
# Replacing Esperanza
# Replacing Plaza
# Replacing Espinosa
# Replacing Lemos
# Replacing Madrid
# Replacing Alfonso
# Replacing Pacheco
# Replacing Rivero
# Replacing Ferraz
# Replacing Ciudad
# Replacing Islas
# Replacing Maria
# Replacing Nieves
# Replacing Fuente
# Replacing Arias
# Replacing Lemos
# Replacing Madrid
# Replacing Puente
# Replacing coche
# Replacing Jordi
# Replacing Iglesias
# Replacing Luque
# Replacing Leon
# Replacing Ciudad
# Replacing Alava
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Adolfo
# Replacing Herrero
# Replacing Lemos
# Replacing Madrid
# Replacing Principe
# Replacing Medina
# Replacing Alvarez
# Replacing Narvaez
# Replacing Ciudad
# Replacing Aranda
# Replacing Duero
# Replacing Tarragona
# Replacing NASS
# Replacing Maria
# Replacing Belen
# Replacing Navarro
# Replacing Alvarez
# Replacing Madrid
# Replacing Villalba
# Replacing Maria
# Replacing Arias
# Replacing Nuñez
# Replacing Ciudad
# Replacing Burgos
# Replacing Segovia
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Morales
# Replacing Marin
# Replacing Madrid
# Replacing Emilio
# Replacing Guillen
# Replacing Ibañez
# Replacing Nuncio
# Replacing Ciudad
# Replacing Vicente
# Replacing Cadiz
# Replacing NASS
# Replacing Ruben
# Replacing Costa
# Replacing Luque
# Replacing Pidal
# Replacing Adrian
# Replacing Zamora
# Replacing Paredes
# Replacing Covarrubias
# Replacing Ciudad
# Replacing Caceres
# Replacing NASS
# Replacing Julian
# Replacing Navarro
# Replacing Duran
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing Jose
# Replacing Luis
# Replacing Diez
# Replacing Marquez
# Replacing Esquerdo
# Replacing Ciudad
# Replacing Alcala
# Replacing Henares
# Replacing Castilla
# Replacing Leon
# Replacing Maria
# Replacing Esther
# Replacing Abad
# Replacing Roca
# Replacing Lemos
# Replacing Madrid
# Replacing Prieto
# Replacing Gutierrez
# Replacing Rollo
# Replacing Ciudad
# Replacing Castellon
# Replacing Alvarez
# Replacing Aparicio
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Costa
# Replacing Marin
# Replacing Genova
# Replacing Ciudad
# Replacing Alcobendas
# Replacing Francisca
# Replacing Marquez
# Replacing Salazar
# Replacing Madrid
# Replacing Villalba
# Replacing coche
# Replacing Ramon
# Replacing Ramos
# Replacing Mateos
# Replacing Ciudad
# Replacing Malaga
# Replacing NASS
# Replacing Luis
# Replacing Miguel
# Replacing Salazar
# Replacing Maldonado
# Replacing Cajal
# Replacing coche
# Replacing blanca
# Replacing Sonia
# Replacing Gimenez
# Replacing Mateo
# Replacing Ciudad
# Replacing Malaga
# Replacing Murcia
# Replacing Murcia
# Replacing NASS
# Replacing Torres
# Replacing Gutierrez
# Replacing Pidal
# Replacing Basurto
# Replacing coche
# Replacing iris
# Replacing Christian
# Replacing Diaz
# Replacing Rivas
# Replacing Almagro
# Replacing Ciudad
# Replacing Sebastian
# Replacing Navarra
# Replacing Navarra
# Replacing NASS
# Replacing Alex
# Replacing Santiago
# Replacing Montes
# Replacing Madrid
# Replacing Alcala
# Replacing Henares
# Replacing Ricardo
# Replacing Simon
# Replacing Jardines
# Replacing Ciudad
# Replacing Sevilla
# Replacing NASS
# Replacing German
# Replacing Escobar
# Replacing Redondo
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing blanca
# Replacing Aurora
# Replacing Rico
# Replacing Moya
# Replacing Valverde
# Replacing Ciudad
# Replacing Lorca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Vanessa
# Replacing Ferrer
# Replacing Iglesias
# Replacing Madrid
# Replacing Sevilla
# Replacing Margarita
# Replacing Velasco
# Replacing Alarcon
# Replacing Luna
# Replacing Ciudad
# Replacing Valencia
# Replacing Santiago
# Replacing Torres
# Replacing Carrasco
# Replacing Cajal
# Replacing coche
# Replacing Matilde
# Replacing Alvarez
# Replacing Santa
# Replacing Isabel
# Replacing Ciudad
# Replacing Cadiz
# Replacing Rafael
# Replacing Roca
# Replacing Heredia
# Replacing Cajal
# Replacing Macarena
# Replacing coche
# Replacing Ford
# Replacing Abel
# Replacing Romero
# Replacing Robles
# Replacing Ciudad
# Replacing Gijon
# Replacing Vizcaya
# Replacing Pais
# Replacing Vasco
# Replacing Rodrigo
# Replacing Morales
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Antonio
# Replacing Jesus
# Replacing Romero
# Replacing Trujillo
# Replacing Ciudad
# Replacing Reus
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing Felix
# Replacing Marcos
# Replacing Marcos
# Replacing Lemos
# Replacing Madrid
# Replacing Torre
# Replacing Natalia
# Replacing Acosta
# Replacing Soto
# Replacing Marques
# Replacing Cubas
# Replacing Ciudad
# Replacing Lorca
# Replacing Mallorca
# Replacing Islas
# Replacing NASS
# Replacing Carlos
# Replacing Pascual
# Replacing Molina
# Replacing Lemos
# Replacing Madrid
# Replacing iris
# Replacing Christian
# Replacing Prieto
# Replacing Luque
# Replacing Juan
# Replacing Bravo
# Replacing Ciudad
# Replacing Aviles
# Replacing Toledo
# Replacing Castilla
# Replacing NASS
# Replacing Mora
# Replacing Gracia
# Replacing Lemos
# Replacing Madrid
# Replacing Santiago
# Replacing Alicia
# Replacing Hidalgo
# Replacing Rivera
# Replacing Sagasta
# Replacing Ciudad
# Replacing Caceres
# Replacing NASS
# Replacing Plaza
# Replacing Espinosa
# Replacing Cajal
# Replacing coche
# Replacing blanca
# Replacing Marcos
# Replacing Ferrer
# Replacing Suarez
# Replacing Ciudad
# Replacing Madrid
# Replacing Madrid
# Replacing NASS
# Replacing Maria
# Replacing Concepcion
# Replacing Lorenzo
# Replacing Castillo
# Replacing Lemos
# Replacing Madrid
# Replacing Puerto
# Replacing arabe
# Replacing Margarita
# Replacing Aguilar
# Replacing Mateo
# Replacing Ciudad
# Replacing Cadiz
# Replacing NASS
# Replacing Miguel
# Replacing Saez
# Replacing Andres
# Replacing Lemos
# Replacing Madrid
# Replacing Santiago
# Replacing Moreno
# Replacing Mora
# Replacing Ciudad
# Replacing Murcia
# Replacing Murcia
# Replacing NASS
# Replacing Rodrigo
# Replacing Pereira
# Replacing Moya
# Replacing Lemos
# Replacing Madrid
# Replacing Basurto
# Replacing blanca
# Replacing Domingo
# Replacing Andres
# Replacing Rueda
# Replacing Olivar
# Replacing Ciudad
# Replacing Caceres
# Replacing Palmas
# Replacing NASS
# Replacing Maria
# Replacing Guillen
# Replacing Gonzalez
# Replacing Lemos
# Replacing Madrid
# Replacing Omar
# Replacing Marti
# Replacing Montoya
# Replacing Ciudad
# Replacing Galicia
# Replacing NASS
# Replacing Flores
# Replacing Castillo
# Replacing Pidal
# Replacing Jose
# Replacing Carlos
# Replacing Gutierrez
# Replacing Arias
# Replacing Prado
# Replacing Ciudad
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Blanca
# Replacing Iglesias
# Replacing Redondo
# Replacing Pidal
# Replacing coche
# Replacing Borja
# Replacing Silva
# Replacing Mateos
# Replacing Ferraz
# Replacing Ciudad
# Replacing Teruel
# Replacing Aragon
# Replacing Juan
# Replacing Jose
# Replacing Marquez
# Replacing Otero
# Replacing Pidal
# Replacing Paz
# Replacing coche
# Replacing Jose
# Replacing Carlos
# Replacing Ramos
# Replacing Santiago
# Replacing Rueda
# Replacing Ciudad
# Replacing Estepa
# Replacing Zamora
# Replacing Castilla
# Replacing Leon
# Replacing Lara
# Replacing Salazar
# Replacing Torres
# Replacing Lemos
# Replacing Madrid
# Replacing Maria
# Replacing Carmen
# Replacing Rojas
# Replacing Roman
# Replacing Ciudad
# Replacing Ponferrada
# Replacing NASS
# Replacing Omar
# Replacing Ibañez
# Replacing Andres
# Replacing Lemos
# Replacing Madrid
# Replacing Puerto
# Replacing Sebastian
# Replacing Garcia
# Replacing Hernandez
# Replacing Segovia
# Replacing Ciudad
# Replacing Islas
# Replacing Ismael
# Replacing Espinosa
# Replacing Navarro
# Replacing Lemos
# Replacing Madrid
# Replacing iris
# Replacing Elvira
# Replacing Montes
# Replacing Martin
# Replacing Miguel
# Replacing Angel
# Replacing Ciudad
# Replacing Linares
# Replacing Huesca
# Replacing Aragon
# Replacing NASS
# Replacing Rebeca
# Replacing Pacheco
# Replacing Lemos
# Replacing Madrid
# Replacing firma
# Replacing Eva
# Replacing Galvez
# Replacing Fuentes
# Replacing Ciudad
# Replacing Islas
# Replacing NASS
# Replacing Borja
# Replacing Gimenez
# Replacing Castro
# Replacing Madrid
# Replacing Contreras
# Replacing Gallardo
# Replacing Marques
# Replacing Cubas
# Replacing Ciudad
# Replacing Gloria
# Replacing Martin
# Replacing Casas
# Replacing Lemos
# Replacing Madrid
# Replacing Reina
# Replacing Sofia
# Replacing coche
# Replacing Jordi
# Replacing Crespo
# Replacing Martinez
# Replacing Narvaez
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Jaen
# Replacing NASS
# Replacing Anna
# Replacing Marin
# Replacing Parra
# Replacing Pidal
# Replacing Ronda
# Replacing Maria
# Replacing Paz
# Replacing Castillo
# Replacing Miguel
# Replacing Zurbano
# Replacing Ciudad
# Replacing Alcala
# Replacing Henares
# Replacing Barcelona
# Replacing Patricia
# Replacing Iglesias
# Replacing Carrillo
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing Vanessa
# Replacing Fernandez
# Replacing Hidalgo
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Noemi
# Replacing Santos
# Replacing Valero
# Replacing Lemos
# Replacing Madrid
# Replacing Valencia
# Replacing coche
# Replacing Carolina
# Replacing Muñoz
# Replacing Calderon
# Replacing Ciudad
# Replacing Vicente
# Replacing NASS
# Replacing Victor
# Replacing Paredes
# Replacing Escobar
# Replacing Pidal
# Replacing Alcala
# Replacing Henares
# Replacing coche
# Replacing Matilde
# Replacing Parra
# Replacing Delgado
# Replacing Ciudad
# Replacing Cuenca
# Replacing Castilla
# Replacing NASS
# Replacing Minero
# Replacing Maria
# Replacing Concepcion
# Replacing Santos
# Replacing Morales
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing Jorge
# Replacing Estevez
# Replacing Carrasco
# Replacing Alameda
# Replacing Ciudad
# Replacing Estepa
# Replacing NASS
# Replacing Lorena
# Replacing Rodriguez
# Replacing Maldonado
# Replacing Lemos
# Replacing Madrid
# Replacing Eva
# Replacing Vera
# Replacing Mateos
# Replacing Ciudad
# Replacing NASS
# Replacing Miguel
# Replacing Serra
# Replacing Lemos
# Replacing Madrid
# Replacing Olga
# Replacing Alarcon
# Replacing Ciudad
# Replacing Zaragoza
# Replacing NASS
# Replacing Emilio
# Replacing Jimenez
# Replacing Alvarez
# Replacing Pidal
# Replacing Lidia
# Replacing Pereira
# Replacing Gomez
# Replacing Ciudad
# Replacing Salamanca
# Replacing Malaga
# Replacing NASS
# Replacing Isabel
# Replacing Bermudez
# Replacing Fuentes
# Replacing Madrid
# Replacing arabe
# Replacing firma
# Replacing Jorge
# Replacing Montero
# Replacing Ramos
# Replacing Fortuny
# Replacing Ciudad
# Replacing Albacete
# Replacing Castilla
# Replacing Manuel
# Replacing Vidal
# Replacing Suarez
# Replacing Pidal
# Replacing Principe
# Replacing coche
# Replacing Ford
# Replacing Maria
# Replacing Vila
# Replacing Lopez
# Replacing Bravo
# Replacing Murillo
# Replacing Ciudad
# Replacing Navarra
# Replacing Navarra
# Replacing NASS
# Replacing Adrian
# Replacing Paredes
# Replacing Herrera
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ignacio
# Replacing Nuñez
# Replacing Rivas
# Replacing Alberto
# Replacing Aguilera
# Replacing Ciudad
# Replacing Jaen
# Replacing NASS
# Replacing Sonia
# Replacing Velasco
# Replacing Lemos
# Replacing Madrid
# Replacing Ramon
# Replacing Hurtado
# Replacing Exposito
# Replacing Fortuny
# Replacing Ciudad
# Replacing Malaga
# Replacing Soria
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Valeria
# Replacing Rubio
# Replacing Santana
# Replacing Pidal
# Replacing Eva
# Replacing Maria
# Replacing Herrero
# Replacing Rueda
# Replacing Ciudad
# Replacing Torrejon
# Replacing Andrea
# Replacing Ortiz
# Replacing Cajal
# Replacing Juan
# Replacing Arias
# Replacing Sierra
# Replacing Santa
# Replacing Engracia
# Replacing Ciudad
# Replacing Huesca
# Replacing Aragon
# Replacing NASS
# Replacing Juan
# Replacing Luis
# Replacing Villar
# Replacing Rico
# Replacing Madrid
# Replacing coche
# Replacing Irene
# Replacing Jurado
# Replacing Rollo
# Replacing Ciudad
# Replacing NASS
# Replacing Javier
# Replacing Gonzalez
# Replacing Galvez
# Replacing Pidal
# Replacing coche
# Replacing Juan
# Replacing Pedro
# Replacing Conde
# Replacing Marti
# Replacing Ciudad
# Replacing Jaen
# Replacing Eric
# Replacing Aguilar
# Replacing Garrido
# Replacing Lemos
# Replacing Madrid
# Replacing Cruces
# Replacing coche
# Replacing iris
# Replacing Isabel
# Replacing Maria
# Replacing Vega
# Replacing Benito
# Replacing Zurbano
# Replacing Ciudad
# Replacing Leon
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Matilde
# Replacing Acosta
# Replacing Lopez
# Replacing Madrid
# Replacing Anna
# Replacing Aparicio
# Replacing Gonzalez
# Replacing Duque
# Replacing Alba
# Replacing Ciudad
# Replacing NASS
# Replacing Luis
# Replacing Rueda
# Replacing Galan
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing Gonzalo
# Replacing Caballero
# Replacing Carrillo
# Replacing Ferraz
# Replacing Ciudad
# Replacing Toledo
# Replacing Castilla
# Replacing NASS
# Replacing Ruben
# Replacing Alonso
# Replacing Rubio
# Replacing Lemos
# Replacing Madrid
# Replacing Rosa
# Replacing Maria
# Replacing Costa
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Valencia
# Replacing Marco
# Replacing Crespo
# Replacing Merino
# Replacing Lemos
# Replacing Madrid
# Replacing firma
# Replacing iris
# Replacing Sergi
# Replacing Roman
# Replacing Escobar
# Replacing Santa
# Replacing Ana
# Replacing Ciudad
# Replacing Zamora
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Lorena
# Replacing Hurtado
# Replacing Parra
# Replacing Lemos
# Replacing Madrid
# Replacing Jimenez
# Replacing Diaz
# Replacing Miriam
# Replacing Contreras
# Replacing Escudero
# Replacing Duque
# Replacing Alba
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Maria
# Replacing Antonia
# Replacing Lopez
# Replacing Robles
# Replacing Lemos
# Replacing Madrid
# Replacing Morales
# Replacing Meseguer
# Replacing coche
# Replacing Ford
# Replacing Villanueva
# Replacing Tomas
# Replacing Ciudad
# Replacing Jaca
# Replacing NASS
# Replacing Lorenzo
# Replacing Vila
# Replacing Ramos
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing iris
# Replacing Araceli
# Replacing Marti
# Replacing Rios
# Replacing Rosas
# Replacing Ciudad
# Replacing Ciudad
# Replacing Castilla
# Replacing NASS
# Replacing Nicolas
# Replacing Marquez
# Replacing Campos
# Replacing Cajal
# Replacing Ana
# Replacing Maria
# Replacing Calvo
# Replacing Peña
# Replacing Reina
# Replacing Ciudad
# Replacing Islas
# Replacing Domingo
# Replacing Costa
# Replacing Manzano
# Replacing Lemos
# Replacing Madrid
# Replacing Santa
# Replacing Creu
# Replacing Sant
# Replacing coche
# Replacing Jose
# Replacing Ramon
# Replacing Castaño
# Replacing Zamora
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Lugo
# Replacing Galicia
# Replacing NASS
# Replacing Ivan
# Replacing Escobar
# Replacing Soriano
# Replacing Pidal
# Replacing Leonor
# Replacing Parra
# Replacing Arias
# Replacing O'Donnell
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Albert
# Replacing Jurado
# Replacing Prieto
# Replacing Lemos
# Replacing Madrid
# Replacing Arturo
# Replacing Jimenez
# Replacing Narvaez
# Replacing Ciudad
# Replacing Teruel
# Replacing Jonathan
# Replacing Garrido
# Replacing Robles
# Replacing Madrid
# Replacing coche
# Replacing firma
# Replacing Sebastian
# Replacing Costa
# Replacing Vargas
# Replacing Ciudad
# Replacing Segovia
# Replacing NASS
# Replacing Eduardo
# Replacing Salazar
# Replacing Plaza
# Replacing Lemos
# Replacing Madrid
# Replacing Santa
# Replacing Creu
# Replacing Sant
# Replacing coche
# Replacing Jose
# Replacing Luis
# Replacing Molina
# Replacing Otero
# Replacing Jesus
# Replacing Maria
# Replacing Ciudad
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Cristian
# Replacing Aparicio
# Replacing Alonso
# Replacing Lemos
# Replacing Madrid
# Replacing Leonor
# Replacing coche
# Replacing Nicolas
# Replacing Flores
# Replacing Eduardo
# Replacing Dato
# Replacing Ciudad
# Replacing Tarragona
# Replacing Soria
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Joel
# Replacing Rueda
# Replacing Ferrer
# Replacing Madrid
# Replacing Barcelona
# Replacing Daniela
# Replacing Reyes
# Replacing Ibañez
# Replacing Millan
# Replacing Ciudad
# Replacing Avila
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Roldan
# Replacing Plaza
# Replacing Madrid
# Replacing Macarena
# Replacing coche
# Replacing iris
# Replacing Martina
# Replacing Moreno
# Replacing Paredes
# Replacing Ciudad
# Replacing NASS
# Replacing Carpintero
# Replacing Maria
# Replacing Escudero
# Replacing Lemos
# Replacing Madrid
# Replacing Monte
# Replacing coche
# Replacing blanca
# Replacing Andrea
# Replacing Pereira
# Replacing Luque
# Replacing Duque
# Replacing Alba
# Replacing Ciudad
# Replacing Leon
# Replacing Avila
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Lorena
# Replacing Prieto
# Replacing Cano
# Replacing Lemos
# Replacing Madrid
# Replacing Alberto
# Replacing Alarcon
# Replacing Serra
# Replacing Leon
# Replacing Ciudad
# Replacing NASS
# Replacing Jose
# Replacing Luis
# Replacing Andres
# Replacing Jurado
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing iris
# Replacing Carla
# Replacing Costa
# Replacing Tomas
# Replacing Marques
# Replacing Urquijo
# Replacing Ciudad
# Replacing Ciudad
# Replacing Barcelona
# Replacing Marcos
# Replacing Hidalgo
# Replacing Navarro
# Replacing Lemos
# Replacing Madrid
# Replacing Pozuelo
# Replacing Alarcon
# Replacing coche
# Replacing Agustin
# Replacing Soler
# Replacing Molina
# Replacing Pedro
# Replacing Ciudad
# Replacing Vilanova
# Replacing Galicia
# Replacing NASS
# Replacing Maria
# Replacing Antonia
# Replacing Rios
# Replacing Gallego
# Replacing Lemos
# Replacing Madrid
# Replacing firma
# Replacing Yolanda
# Replacing Paredes
# Replacing Avila
# Replacing Velazquez
# Replacing Ciudad
# Replacing Galicia
# Replacing NASS
# Replacing Gutierrez
# Replacing Guerrero
# Replacing Lemos
# Replacing Madrid
# Replacing Negrin
# Replacing Marc
# Replacing Vicente
# Replacing Plaza
# Replacing Ciudad
# Replacing NASS
# Replacing Maria
# Replacing Jose
# Replacing Ortiz
# Replacing Pidal
# Replacing coche
# Replacing iris
# Replacing Rebeca
# Replacing Miguel
# Replacing Gallego
# Replacing Jardines
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Mora
# Replacing Blazquez
# Replacing Lemos
# Replacing Madrid
# Replacing Maria
# Replacing Abad
# Replacing Ciudad
# Replacing Bejar
# Replacing Galicia
# Replacing NASS
# Replacing Mateo
# Replacing Diez
# Replacing Mateos
# Replacing Lemos
# Replacing Madrid
# Replacing Alvaro
# Replacing Rivas
# Replacing Villar
# Replacing Goya
# Replacing Ciudad
# Replacing Galicia
# Replacing Pintor
# Replacing Santiago
# Replacing Pacheco
# Replacing Valero
# Replacing Pidal
# Replacing Concepcion
# Replacing Manzano
# Replacing Iglesias
# Replacing Ciudad
# Replacing Salamanca
# Replacing Islas
# Replacing Lourdes
# Replacing Franco
# Replacing Rivera
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Clara
# Replacing Soto
# Replacing Ferrer
# Replacing Luna
# Replacing Ciudad
# Replacing Santander
# Replacing NASS
# Replacing Paredes
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing coche
# Replacing blanca
# Replacing Jose
# Replacing Francisco
# Replacing Soto
# Replacing Medina
# Replacing Ramon
# Replacing Cruz
# Replacing Ciudad
# Replacing Alcala
# Replacing Henares
# Replacing Victor
# Replacing Gallego
# Replacing Dominguez
# Replacing Madrid
# Replacing Ronda
# Replacing Bruno
# Replacing Nieto
# Replacing Lorenzo
# Replacing Ciudad
# Replacing Ciudad
# Replacing Andrea
# Replacing Suarez
# Replacing Nieto
# Replacing Lemos
# Replacing Madrid
# Replacing blanca
# Replacing Victor
# Replacing Estevez
# Replacing Conde
# Replacing Santo
# Replacing Ciudad
# Replacing Tarragona
# Replacing NASS
# Replacing Vanessa
# Replacing Sanchez
# Replacing Rivera
# Replacing Lemos
# Replacing Madrid
# Replacing Ciudad
# Replacing coche
# Replacing Roca
# Replacing Acosta
# Replacing Ciudad
# Replacing Liria
# Replacing Lugo
# Replacing Galicia
# Replacing NASS
# Replacing Jose
# Replacing Ignacio
# Replacing Dominguez
# Replacing Mateos
# Replacing Madrid
# Replacing Collado
# Replacing Villalba
# Replacing coche
# Replacing Elena
# Replacing Calderon
# Replacing Peña
# Replacing Ciudad
# Replacing Castellon
# Replacing NASS
# Replacing Juan
# Replacing Ramon
# Replacing Carmona
# Replacing Morales
# Replacing Cajal
# Replacing Rocio
# Replacing coche
# Replacing Christian
# Replacing Santamaria
# Replacing Ferrer
# Replacing Segovia
# Replacing Ciudad
# Replacing Burgos
# Replacing Islas
# Replacing NASS
# Replacing Mora
# Replacing Navarro
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing iris
# Replacing Ana
# Replacing Maria
# Replacing Rojas
# Replacing Caballero
# Replacing Ciudad
# Replacing Alava
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Herrera
# Replacing Lozano
# Replacing Lemos
# Replacing Madrid
# Replacing Leon
# Replacing Christian
# Replacing Moreno
# Replacing Dominguez
# Replacing Ciudad
# Replacing Avila
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Catalina
# Replacing Crespo
# Replacing Marquez
# Replacing Madrid
# Replacing Marques
# Replacing blanca
# Replacing Andres
# Replacing Ciudad
# Replacing Madrid
# Replacing Madrid
# Replacing NASS
# Replacing Angel
# Replacing Ramirez
# Replacing Simon
# Replacing Pidal
# Replacing Jose
# Replacing Franco
# Replacing Arias
# Replacing Ciudad
# Replacing Talavera
# Replacing Reina
# Replacing Ciudad
# Replacing Castilla
# Replacing NASS
# Replacing Ramon
# Replacing Heredia
# Replacing Rojas
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ana
# Replacing Maria
# Replacing Aguilar
# Replacing Fortuny
# Replacing Ciudad
# Replacing Segovia
# Replacing Murcia
# Replacing Murcia
# Replacing NASS
# Replacing Mercedes
# Replacing Ferrer
# Replacing Zamora
# Replacing Pidal
# Replacing Basurto
# Replacing Adrian
# Replacing Gracia
# Replacing Jurado
# Replacing Ciudad
# Replacing Galicia
# Replacing Pedro
# Replacing Jose
# Replacing Valero
# Replacing Romero
# Replacing Madrid
# Replacing Puente
# Replacing coche
# Replacing blanca
# Replacing Valentin
# Replacing Galvez
# Replacing Mateo
# Replacing Ciudad
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing Magdalena
# Replacing Santiago
# Replacing Robles
# Replacing Lemos
# Replacing Madrid
# Replacing Leonor
# Replacing coche
# Replacing Sebastian
# Replacing Espinosa
# Replacing Flores
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Carla
# Replacing Roman
# Replacing Marti
# Replacing Lemos
# Replacing Madrid
# Replacing Leon
# Replacing Cano
# Replacing Salas
# Replacing Ciudad
# Replacing Albacete
# Replacing Soria
# Replacing Castilla
# Replacing Leon
# Replacing Vicente
# Replacing Molina
# Replacing Estevez
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing iris
# Replacing Anna
# Replacing Torres
# Replacing Jimenez
# Replacing Ciudad
# Replacing Soria
# Replacing Castilla
# Replacing Leon
# Replacing Vanessa
# Replacing Paredes
# Replacing Ramos
# Replacing Lemos
# Replacing Madrid
# Replacing Monte
# Replacing Emilio
# Replacing Castillo
# Replacing Gomez
# Replacing Cruces
# Replacing Ciudad
# Replacing Cadiz
# Replacing NASS
# Replacing Rocio
# Replacing Martin
# Replacing Hernandez
# Replacing Lemos
# Replacing Madrid
# Replacing Leon
# Replacing Mikel
# Replacing Vila
# Replacing Lozano
# Replacing Ciudad
# Replacing Salamanca
# Replacing Vizcaya
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Alejandro
# Replacing Macias
# Replacing Delgado
# Replacing Lemos
# Replacing Madrid
# Replacing Cruces
# Replacing Hector
# Replacing Miguel
# Replacing Castro
# Replacing Marques
# Replacing Cubas
# Replacing Ciudad
# Replacing Alvaro
# Replacing Bernal
# Replacing Vazquez
# Replacing Lemos
# Replacing Madrid
# Replacing Torrejon
# Replacing coche
# Replacing Mohamed
# Replacing Maldonado
# Replacing Castro
# Replacing Esquerdo
# Replacing Ciudad
# Replacing NASS
# Replacing Mora
# Replacing Benito
# Replacing Pidal
# Replacing coche
# Replacing Antonio
# Replacing Jesus
# Replacing Navarro
# Replacing Soriano
# Replacing Vega
# Replacing Ciudad
# Replacing Vizcaya
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Sofia
# Replacing Moya
# Replacing Navarro
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Carlos
# Replacing Luque
# Replacing Diez
# Replacing Zurbano
# Replacing Ciudad
# Replacing Parla
# Replacing Valencia
# Replacing Jonathan
# Replacing Calvo
# Replacing Montes
# Replacing Lemos
# Replacing Madrid
# Replacing Macarena
# Replacing coche
# Replacing Angela
# Replacing Vargas
# Replacing Pacheco
# Replacing Toledo
# Replacing Ciudad
# Replacing Leon
# Replacing Castilla
# Replacing Leon
# Replacing Paula
# Replacing Calderon
# Replacing Sanchez
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Mercedes
# Replacing Benz
# Replacing firma
# Replacing Esteban
# Replacing Costa
# Replacing Leon
# Replacing Bernardo
# Replacing Ciudad
# Replacing NASS
# Replacing Aparicio
# Replacing Gallego
# Replacing Madrid
# Replacing Marques
# Replacing coche
# Replacing Ford
# Replacing Victor
# Replacing Manuel
# Replacing Saez
# Replacing Exposito
# Replacing Narvaez
# Replacing Ciudad
# Replacing Toledo
# Replacing NASS
# Replacing Adam
# Replacing Garcia
# Replacing Pardo
# Replacing Lemos
# Replacing Madrid
# Replacing Conde
# Replacing Casal
# Replacing Moises
# Replacing Roldan
# Replacing Garrido
# Replacing Miguel
# Replacing Angel
# Replacing Ciudad
# Replacing Lugo
# Replacing Zaragoza
# Replacing Aragon
# Replacing NASS
# Replacing Aaron
# Replacing Heredia
# Replacing Vega
# Replacing Madrid
# Replacing Villalba
# Replacing coche
# Replacing Ford
# Replacing Blanca
# Replacing Carrillo
# Replacing Garrido
# Replacing Ciudad
# Replacing Salamanca
# Replacing Sebastian
# Replacing Vera
# Replacing Garrido
# Replacing Madrid
# Replacing Blanca
# Replacing Andres
# Replacing Rios
# Replacing Jesus
# Replacing Maria
# Replacing Ciudad
# Replacing Cadiz
# Replacing NASS
# Replacing Victor
# Replacing Castro
# Replacing Mateos
# Replacing Pidal
# Replacing coche
# Replacing blanca
# Replacing Diego
# Replacing Arias
# Replacing Lozano
# Replacing Velazquez
# Replacing Ciudad
# Replacing Teruel
# Replacing Aragon
# Replacing NASS
# Replacing Abel
# Replacing Salazar
# Replacing Lemos
# Replacing Madrid
# Replacing Leonor
# Replacing coche
# Replacing Anna
# Replacing Rojas
# Replacing Palacios
# Replacing Olivar
# Replacing Ciudad
# Replacing Aranda
# Replacing Duero
# Replacing NASS
# Replacing Maria
# Replacing Quintana
# Replacing Castaño
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing Carolina
# Replacing Santos
# Replacing Calderon
# Replacing Ciudad
# Replacing Linares
# Replacing Caceres
# Replacing Andres
# Replacing Camacho
# Replacing Gonzalez
# Replacing Madrid
# Replacing blanca
# Replacing Adolfo
# Replacing Aguilera
# Replacing Suarez
# Replacing Ciudad
# Replacing Cristian
# Replacing Vidal
# Replacing Maldonado
# Replacing Lemos
# Replacing Madrid
# Replacing Adrian
# Replacing Flores
# Replacing Escudero
# Replacing Ciudad
# Replacing Fernando
# Replacing Jose
# Replacing Manuel
# Replacing Ferrer
# Replacing Pascual
# Replacing Lemos
# Replacing Madrid
# Replacing Reina
# Replacing Sofia
# Replacing blanca
# Replacing firma
# Replacing Marcos
# Replacing Cabrera
# Replacing Marques
# Replacing Urquijo
# Replacing Ciudad
# Replacing Talavera
# Replacing Reina
# Replacing Castellon
# Replacing NASS
# Replacing Natalia
# Replacing Gonzalez
# Replacing Lemos
# Replacing Madrid
# Replacing Torrejon
# Replacing arabe
# Replacing Gerard
# Replacing Guerrero
# Replacing Martin
# Replacing Jardines
# Replacing Ciudad
# Replacing Castellon
# Replacing NASS
# Replacing Carpintero
# Replacing Jaime
# Replacing Abad
# Replacing Suarez
# Replacing Lemos
# Replacing Madrid
# Replacing Reina
# Replacing Sofia
# Replacing coche
# Replacing Ford
# Replacing blanca
# Replacing Borja
# Replacing Esteban
# Replacing Ciudad
# Replacing Valencia
# Replacing Jesus
# Replacing Espinosa
# Replacing Carrillo
# Replacing Lemos
# Replacing Madrid
# Replacing Guerra
# Replacing Fortuny
# Replacing Ciudad
# Replacing Galicia
# Replacing NASS
# Replacing Maria
# Replacing Angeles
# Replacing Galvez
# Replacing Lemos
# Replacing Madrid
# Replacing Otero
# Replacing Estevez
# Replacing Ribera
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Catalina
# Replacing Merino
# Replacing Iglesias
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Roberto
# Replacing Marcos
# Replacing Tomas
# Replacing Bernardo
# Replacing Ciudad
# Replacing Jaca
# Replacing NASS
# Replacing Francisco
# Replacing Jose
# Replacing Caballero
# Replacing Ramirez
# Replacing Lemos
# Replacing Madrid
# Replacing Julia
# Replacing Blanco
# Replacing Padilla
# Replacing Ciudad
# Replacing Ponferrada
# Replacing NASS
# Replacing Natalia
# Replacing Marin
# Replacing Esteban
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing firma
# Replacing Fuente
# Replacing Carrillo
# Replacing Ciudad
# Replacing Lugo
# Replacing Galicia
# Replacing Fatima
# Replacing Gonzalez
# Replacing Lemos
# Replacing Madrid
# Replacing Elena
# Replacing Silva
# Replacing Rico
# Replacing Rios
# Replacing Rosas
# Replacing Ciudad
# Replacing Palmas
# Replacing NASS
# Replacing Victor
# Replacing Rivera
# Replacing Cano
# Replacing Madrid
# Replacing Valencia
# Replacing iris
# Replacing Agustin
# Replacing Rivero
# Replacing Leon
# Replacing Ciudad
# Replacing Sevilla
# Replacing NASS
# Replacing Hector
# Replacing Padilla
# Replacing Ortega
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Bruno
# Replacing Andres
# Replacing Santa
# Replacing Engracia
# Replacing Ciudad
# Replacing Islas
# Replacing NASS
# Replacing Tomas
# Replacing Ferrer
# Replacing Calvo
# Replacing Lemos
# Replacing Madrid
# Replacing Arturo
# Replacing Marcos
# Replacing Ramos
# Replacing Ciudad
# Replacing Barcelona
# Replacing Natalia
# Replacing Mendez
# Replacing Mesa
# Replacing Lemos
# Replacing Madrid
# Replacing Monte
# Replacing coche
# Replacing Santamaria
# Replacing Abad
# Replacing Leon
# Replacing Ciudad
# Replacing Parla
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Flores
# Replacing Mateos
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing coche
# Replacing Ford
# Replacing Juan
# Replacing Escobar
# Replacing Valero
# Replacing Vega
# Replacing Ciudad
# Replacing Islas
# Replacing NASS
# Replacing Olga
# Replacing Roca
# Replacing Rico
# Replacing Lemos
# Replacing Madrid
# Replacing Alcala
# Replacing Henares
# Replacing coche
# Replacing Ford
# Replacing Maria
# Replacing Isabel
# Replacing Marti
# Replacing Guerra
# Replacing Ciudad
# Replacing Jaca
# Replacing Valencia
# Replacing Christian
# Replacing Manzano
# Replacing Alonso
# Replacing Cajal
# Replacing coche
# Replacing blanca
# Replacing Antonio
# Replacing Jose
# Replacing Alarcon
# Replacing Arroyo
# Replacing Cruces
# Replacing Ciudad
# Replacing Aviles
# Replacing Albacete
# Replacing Castilla
# Replacing NASS
# Replacing Diego
# Replacing Roman
# Replacing Torres
# Replacing Lemos
# Replacing Madrid
# Replacing Gregorio
# Replacing Heredia
# Replacing Gutierrez
# Replacing Ciudad
# Replacing Parla
# Replacing Ciudad
# Replacing Castilla
# Replacing NASS
# Replacing Bermudez
# Replacing Santana
# Replacing Lemos
# Replacing Madrid
# Replacing Carlos
# Replacing coche
# Replacing Maria
# Replacing Asuncion
# Replacing Vicente
# Replacing Suarez
# Replacing Rollo
# Replacing Ciudad
# Replacing Eibar
# Replacing NASS
# Replacing Sofia
# Replacing Vargas
# Replacing Mateos
# Replacing Lemos
# Replacing Madrid
# Replacing Antonia
# Replacing Vicente
# Replacing Marcos
# Replacing Meson
# Replacing Paredes
# Replacing Ciudad
# Replacing Ciudad
# Replacing Castilla
# Replacing NASS
# Replacing Antonio
# Replacing Jose
# Replacing Hurtado
# Replacing Lemos
# Replacing Madrid
# Replacing Paz
# Replacing coche
# Replacing firma
# Replacing iris
# Replacing Francisco
# Replacing Diez
# Replacing Mora
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing Carla
# Replacing Merino
# Replacing Lopez
# Replacing Madrid
# Replacing Juan
# Replacing Ramon
# Replacing Moya
# Replacing Benitez
# Replacing Ciudad
# Replacing Jaca
# Replacing Palmas
# Replacing NASS
# Replacing Juan
# Replacing Luis
# Replacing Gallego
# Replacing Garrido
# Replacing Lemos
# Replacing Madrid
# Replacing Moises
# Replacing Miguel
# Replacing Ramos
# Replacing Huertas
# Replacing Ciudad
# Replacing Albacete
# Replacing NASS
# Replacing Maria
# Replacing Lourdes
# Replacing Serra
# Replacing Arias
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing Veronica
# Replacing Varela
# Replacing Goya
# Replacing Ciudad
# Replacing Avila
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Jesus
# Replacing Maria
# Replacing Castro
# Replacing Saez
# Replacing Lemos
# Replacing Madrid
# Replacing Barcelona
# Replacing Eric
# Replacing Rueda
# Replacing Rivero
# Replacing Ciudad
# Replacing Alcala
# Replacing Henares
# Replacing Barcelona
# Replacing NASS
# Replacing Santiago
# Replacing Maldonado
# Replacing Soto
# Replacing Madrid
# Replacing Leon
# Replacing coche
# Replacing firma
# Replacing Ivan
# Replacing Estevez
# Replacing Eduardo
# Replacing Dato
# Replacing Ciudad
# Replacing Salamanca
# Replacing NASS
# Replacing Laura
# Replacing Garrido
# Replacing Lemos
# Replacing Madrid
# Replacing Basurto
# Replacing coche
# Replacing Hurtado
# Replacing Parra
# Replacing Santa
# Replacing Ana
# Replacing Ciudad
# Replacing Toledo
# Replacing Toledo
# Replacing Castilla
# Replacing NASS
# Replacing Carpintero
# Replacing Anna
# Replacing Campos
# Replacing Pidal
# Replacing Torrejon
# Replacing Bruno
# Replacing Vera
# Replacing Santamaria
# Replacing Esquerdo
# Replacing Ciudad
# Replacing Barcelona
# Replacing NASS
# Replacing Cabrera
# Replacing Alonso
# Replacing Pidal
# Replacing Manuela
# Replacing Acosta
# Replacing Santana
# Replacing Santa
# Replacing Ana
# Replacing Ciudad
# Replacing Navarra
# Replacing Navarra
# Replacing NASS
# Replacing Jose
# Replacing Valero
# Replacing Marquez
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing firma
# Replacing Olga
# Replacing Casas
# Replacing Marti
# Replacing Jardines
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Bruno
# Replacing Fernandez
# Replacing Pascual
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing Javier
# Replacing Montoya
# Replacing Saez
# Replacing Ciudad
# Replacing NASS
# Replacing Luis
# Replacing Miguel
# Replacing Aguilar
# Replacing Molina
# Replacing Madrid
# Replacing firma
# Replacing Jorge
# Replacing Costa
# Replacing Flores
# Replacing Olivar
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Vizcaya
# Replacing Pais
# Replacing Vasco
# Replacing Rosa
# Replacing Crespo
# Replacing Montero
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing blanca
# Replacing Francisco
# Replacing Jose
# Replacing Arias
# Replacing Crespo
# Replacing Ciudad
# Replacing Liria
# Replacing Barcelona
# Replacing Ramon
# Replacing Bermudez
# Replacing Diez
# Replacing Lemos
# Replacing Madrid
# Replacing Elisa
# Replacing Martin
# Replacing Torres
# Replacing Ciudad
# Replacing Segovia
# Replacing Castilla
# Replacing Leon
# Replacing Andres
# Replacing Blazquez
# Replacing Franco
# Replacing Pidal
# Replacing Natalia
# Replacing Jurado
# Replacing Ferrer
# Replacing Primavera
# Replacing Ciudad
# Replacing Castellon
# Replacing Plana
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Lorena
# Replacing Villanueva
# Replacing Ortiz
# Replacing Lemos
# Replacing Madrid
# Replacing iris
# Replacing Christian
# Replacing Serrano
# Replacing Macias
# Replacing Ciudad
# Replacing Madrid
# Replacing Madrid
# Replacing NASS
# Replacing Carla
# Replacing Herrero
# Replacing Vazquez
# Replacing Cajal
# Replacing Jesus
# Replacing Maria
# Replacing Blazquez
# Replacing Vargas
# Replacing Ciudad
# Replacing Zamora
# Replacing Dario
# Replacing Padilla
# Replacing Santiago
# Replacing Pidal
# Replacing coche
# Replacing Miguel
# Replacing Gallardo
# Replacing Vila
# Replacing Meson
# Replacing Paredes
# Replacing Ciudad
# Replacing Liria
# Replacing Toledo
# Replacing Castilla
# Replacing NASS
# Replacing Mariano
# Replacing Santos
# Replacing Calderon
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Carlos
# Replacing firma
# Replacing Ruben
# Replacing Cruz
# Replacing Nuñez
# Replacing Luna
# Replacing Ciudad
# Replacing Torrejon
# Replacing Maria
# Replacing Concepcion
# Replacing Prieto
# Replacing Escudero
# Replacing Lemos
# Replacing Madrid
# Replacing firma
# Replacing iris
# Replacing Josefina
# Replacing Esteban
# Replacing Esteban
# Replacing Ciudad
# Replacing Sebastian
# Replacing Galicia
# Replacing NASS
# Replacing Juan
# Replacing Ramon
# Replacing Vera
# Replacing Vargas
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Fernando
# Replacing Ferrer
# Replacing Gimenez
# Replacing Rios
# Replacing Rosas
# Replacing Ciudad
# Replacing Vigo
# Replacing Islas
# Replacing NASS
# Replacing Sergi
# Replacing Quintana
# Replacing Silva
# Replacing Lemos
# Replacing Madrid
# Replacing Paz
# Replacing Lidia
# Replacing Rivas
# Replacing Gonzalez
# Replacing Leon
# Replacing Ciudad
# Replacing Gloria
# Replacing Hernandez
# Replacing Pardo
# Replacing Lemos
# Replacing Madrid
# Replacing blanca
# Replacing Beatriz
# Replacing Cabrera
# Replacing Menendez
# Replacing Santa
# Replacing Engracia
# Replacing Ciudad
# Replacing Islas
# Replacing NASS
# Replacing Maria
# Replacing Carmen
# Replacing Maldonado
# Replacing Villanueva
# Replacing Cajal
# Replacing Puerto
# Replacing coche
# Replacing Juana
# Replacing Trujillo
# Replacing Fuentes
# Replacing Ciudad
# Replacing Aranda
# Replacing Duero
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Esther
# Replacing Casas
# Replacing Rubio
# Replacing Pidal
# Replacing coche
# Replacing blanca
# Replacing Rubio
# Replacing Plaza
# Replacing Ribera
# Replacing Ciudad
# Replacing Leon
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Marco
# Replacing Casado
# Replacing Lemos
# Replacing Madrid
# Replacing Antonio
# Replacing Jesus
# Replacing Ramos
# Replacing Castro
# Replacing Narvaez
# Replacing Ciudad
# Replacing Malaga
# Replacing NASS
# Replacing Susana
# Replacing Diaz
# Replacing Paredes
# Replacing Madrid
# Replacing Principe
# Replacing Maria
# Replacing Isabel
# Replacing Pascual
# Replacing Dominguez
# Replacing Ciudad
# Replacing Murcia
# Replacing Murcia
# Replacing Murcia
# Replacing NASS
# Replacing Minero
# Replacing Virginia
# Replacing Pacheco
# Replacing Soto
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Maria
# Replacing Pilar
# Replacing Montoya
# Replacing Sanz
# Replacing Prado
# Replacing Ciudad
# Replacing NASS
# Replacing Adriana
# Replacing Rivero
# Replacing Silva
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing blanca
# Replacing firma
# Replacing Ariadna
# Replacing Benitez
# Replacing Carrasco
# Replacing Ciudad
# Replacing NASS
# Replacing Martin
# Replacing Rubio
# Replacing Rivero
# Replacing Madrid
# Replacing Ronda
# Replacing Emilio
# Replacing Rivas
# Replacing Mateo
# Replacing Ciudad
# Replacing Leon
# Replacing Castilla
# Replacing Leon
# Replacing Carmona
# Replacing Peña
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing coche
# Replacing Exposito
# Replacing Carrillo
# Replacing Ciudad
# Replacing Vilanova
# Replacing Islas
# Replacing Salvador
# Replacing Cruz
# Replacing Franco
# Replacing Lemos
# Replacing Madrid
# Replacing Negrin
# Replacing coche
# Replacing Sofia
# Replacing Pacheco
# Replacing Benito
# Replacing Ciudad
# Replacing NASS
# Replacing Maria
# Replacing Soledad
# Replacing Rivas
# Replacing Trujillo
# Replacing Lemos
# Replacing Madrid
# Replacing Cruces
# Replacing Flores
# Replacing Montero
# Replacing Leon
# Replacing Ciudad
# Replacing Linares
# Replacing Teruel
# Replacing Aragon
# Replacing NASS
# Replacing Adrian
# Replacing Andres
# Replacing Mateo
# Replacing Cajal
# Replacing Negrin
# Replacing Vicente
# Replacing Vera
# Replacing Romero
# Replacing Ciudad
# Replacing Aviles
# Replacing Islas
# Replacing Gregorio
# Replacing Arias
# Replacing Silva
# Replacing Cajal
# Replacing Torrejon
# Replacing coche
# Replacing blanca
# Replacing Eva
# Replacing Maria
# Replacing Serrano
# Replacing Palacios
# Replacing Ciudad
# Replacing Fernando
# Replacing Vizcaya
# Replacing Pais
# Replacing Vasco
# Replacing Pintor
# Replacing Sergio
# Replacing Gutierrez
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing Ariadna
# Replacing Mendez
# Replacing Moya
# Replacing Bernardo
# Replacing Ciudad
# Replacing Abel
# Replacing Guerra
# Replacing Alarcon
# Replacing Lemos
# Replacing Madrid
# Replacing Latina
# Replacing coche
# Replacing Jose
# Replacing Ignacio
# Replacing Rios
# Replacing Perez
# Replacing Primavera
# Replacing Ciudad
# Replacing Alcazar
# Replacing Sevilla
# Replacing Adrian
# Replacing Alarcon
# Replacing Lemos
# Replacing Madrid
# Replacing Elena
# Replacing Perez
# Replacing Morales
# Replacing Santa
# Replacing Engracia
# Replacing Ciudad
# Replacing Aranda
# Replacing Duero
# Replacing Zamora
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Pintor
# Replacing Andrea
# Replacing Reyes
# Replacing Blazquez
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Jaume
# Replacing Crespo
# Replacing Gonzalez
# Replacing Rios
# Replacing Rosas
# Replacing Ciudad
# Replacing Ronda
# Replacing Segovia
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Carlos
# Replacing Casas
# Replacing Rios
# Replacing Madrid
# Replacing Conde
# Replacing Casal
# Replacing arabe
# Replacing Elisa
# Replacing Bermudez
# Replacing Santana
# Replacing Alameda
# Replacing Ciudad
# Replacing Estepa
# Replacing NASS
# Replacing Monica
# Replacing Medina
# Replacing Rubio
# Replacing Lemos
# Replacing Madrid
# Replacing Leonor
# Replacing blanca
# Replacing Martina
# Replacing Herrero
# Replacing Manzano
# Replacing Alberto
# Replacing Aguilera
# Replacing Ciudad
# Replacing Torrejon
# Replacing Castilla
# Replacing Leon
# Replacing Ismael
# Replacing Ramos
# Replacing Abad
# Replacing Lemos
# Replacing Madrid
# Replacing Vall
# Replacing Rafael
# Replacing Suarez
# Replacing Sierra
# Replacing Ribera
# Replacing Ciudad
# Replacing Sebastian
# Replacing Islas
# Replacing NASS
# Replacing Francisco
# Replacing Varela
# Replacing Gracia
# Replacing Lemos
# Replacing Madrid
# Replacing Torrejon
# Replacing coche
# Replacing Miriam
# Replacing Mesa
# Replacing Rivas
# Replacing Ciudad
# Replacing Alava
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Minero
# Replacing Trujillo
# Replacing Varela
# Replacing Cajal
# Replacing Miguel
# Replacing Angel
# Replacing Casado
# Replacing Leon
# Replacing Leon
# Replacing Ciudad
# Replacing Galicia
# Replacing NASS
# Replacing Marina
# Replacing Alonso
# Replacing Calderon
# Replacing Lemos
# Replacing Madrid
# Replacing Santamaria
# Replacing Esteban
# Replacing Zurbano
# Replacing Ciudad
# Replacing Islas
# Replacing Pedro
# Replacing Jose
# Replacing Serrano
# Replacing Moreno
# Replacing Lemos
# Replacing Madrid
# Replacing Luz
# Replacing blanca
# Replacing Cristian
# Replacing Castaño
# Replacing Montoya
# Replacing Ciudad
# Replacing Aviles
# Replacing Segovia
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Ivan
# Replacing Casado
# Replacing Lemos
# Replacing Madrid
# Replacing Ahmed
# Replacing Benitez
# Replacing Aranda
# Replacing Alcala
# Replacing Ciudad
# Replacing Teruel
# Replacing Caceres
# Replacing Maria
# Replacing Concepcion
# Replacing Sanchez
# Replacing Calvo
# Replacing Lemos
# Replacing Madrid
# Replacing Ronda
# Replacing Juan
# Replacing Miguel
# Replacing Velasco
# Replacing Velasco
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing Hector
# Replacing Gallego
# Replacing Silva
# Replacing Cajal
# Replacing prima
# Replacing Maria
# Replacing Antonia
# Replacing Casas
# Replacing Mateo
# Replacing Marques
# Replacing Cubas
# Replacing Ciudad
# Replacing Castellon
# Replacing Minero
# Replacing Maria
# Replacing Varela
# Replacing Lemos
# Replacing Madrid
# Replacing Josefa
# Replacing Ramirez
# Replacing Bernardo
# Replacing Ciudad
# Replacing Talavera
# Replacing Reina
# Replacing Ciudad
# Replacing Castilla
# Replacing Lozano
# Replacing Vera
# Replacing Lemos
# Replacing Madrid
# Replacing Parla
# Replacing coche
# Replacing Mercedes
# Replacing Benz
# Replacing Ismael
# Replacing Serra
# Replacing Rivero
# Replacing Ciudad
# Replacing Silvia
# Replacing Miguel
# Replacing Guzman
# Replacing Pidal
# Replacing Malaga
# Replacing coche
# Replacing Blanco
# Replacing Moya
# Replacing Esquerdo
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Maria
# Replacing Galan
# Replacing Rojas
# Replacing Lemos
# Replacing Madrid
# Replacing Jimenez
# Replacing Diaz
# Replacing iris
# Replacing Sofia
# Replacing Casas
# Replacing Hernandez
# Replacing Huertas
# Replacing Ciudad
# Replacing Caceres
# Replacing Zaragoza
# Replacing Aragon
# Replacing NASS
# Replacing Maria
# Replacing Jesus
# Replacing Fuente
# Replacing Lozano
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing coche
# Replacing Albert
# Replacing Maldonado
# Replacing Cano
# Replacing Fortuny
# Replacing Ciudad
# Replacing Cadiz
# Replacing Sevilla
# Replacing NASS
# Replacing Garcia
# Replacing Ortega
# Replacing Lemos
# Replacing Madrid
# Replacing Villaverde
# Replacing coche
# Replacing firma
# Replacing Rosa
# Replacing Maria
# Replacing Cano
# Replacing Vera
# Replacing Piga
# Replacing Ciudad
# Replacing Aranda
# Replacing Duero
# Replacing Toledo
# Replacing Castilla
# Replacing NASS
# Replacing Tomas
# Replacing Salas
# Replacing Lemos
# Replacing Madrid
# Replacing Reina
# Replacing Sofia
# Replacing Trujillo
# Replacing Beltran
# Replacing Alcala
# Replacing Ciudad
# Replacing Ciudad
# Replacing Castilla
# Replacing Raquel
# Replacing Crespo
# Replacing Mendez
# Replacing Lemos
# Replacing Madrid
# Replacing Pozuelo
# Replacing Alarcon
# Replacing Enrique
# Replacing Sanchez
# Replacing Vila
# Replacing Zurbano
# Replacing Ciudad
# Replacing Albacete
# Replacing Castilla
# Replacing NASS
# Replacing Gloria
# Replacing Vega
# Replacing Gutierrez
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Mercedes
# Replacing Benz
# Replacing Fernando
# Replacing Ramos
# Replacing Aparicio
# Replacing Ayala
# Replacing Ciudad
# Replacing Alcobendas
# Replacing Lugo
# Replacing Galicia
# Replacing NASS
# Replacing Esteban
# Replacing Santos
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Castillo
# Replacing Garrido
# Replacing Alameda
# Replacing Ciudad
# Replacing NASS
# Replacing Veronica
# Replacing Mateos
# Replacing Fuente
# Replacing Lemos
# Replacing Madrid
# Replacing Barcelona
# Replacing blanca
# Replacing Manuel
# Replacing Jesus
# Replacing Casado
# Replacing Villanueva
# Replacing Esquerdo
# Replacing Ciudad
# Replacing Burgos
# Replacing Valeria
# Replacing Mateos
# Replacing Diaz
# Replacing Madrid
# Replacing Arnau
# Replacing Montero
# Replacing Varela
# Replacing Narvaez
# Replacing Ciudad
# Replacing NASS
# Replacing Maria
# Replacing Jesus
# Replacing Escudero
# Replacing Padilla
# Replacing Madrid
# Replacing Collado
# Replacing Villalba
# Replacing Esperanza
# Replacing Castro
# Replacing Nieto
# Replacing Reina
# Replacing Ciudad
# Replacing Ronda
# Replacing Zaragoza
# Replacing Aragon
# Replacing NASS
# Replacing Ivan
# Replacing Fuentes
# Replacing Pastor
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing coche
# Replacing Dario
# Replacing Acosta
# Replacing Rivas
# Replacing Ciudad
# Replacing Sebastian
# Replacing NASS
# Replacing Juan
# Replacing Ramon
# Replacing Medina
# Replacing Herrera
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Valentin
# Replacing Montes
# Replacing Mateos
# Replacing Ciudad
# Replacing Linares
# Replacing Palmas
# Replacing NASS
# Replacing Rosa
# Replacing Maria
# Replacing Camacho
# Replacing Abad
# Replacing Lemos
# Replacing Madrid
# Replacing firma
# Replacing Domingo
# Replacing Marcos
# Replacing Ramirez
# Replacing Ciudad
# Replacing Gijon
# Replacing NASS
# Replacing Jonathan
# Replacing Montoya
# Replacing Hidalgo
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing Maria
# Replacing Mercedes
# Replacing Marcos
# Replacing Aranda
# Replacing Narvaez
# Replacing Ciudad
# Replacing Galicia
# Replacing Fatima
# Replacing Carrasco
# Replacing Lemos
# Replacing Madrid
# Replacing Marques
# Replacing coche
# Replacing blanca
# Replacing Ivan
# Replacing Gallardo
# Replacing Navarro
# Replacing Juan
# Replacing Bravo
# Replacing Ciudad
# Replacing Vigo
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Maria
# Replacing Teresa
# Replacing Rivera
# Replacing Campos
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing coche
# Replacing blanca
# Replacing Concepcion
# Replacing Gallego
# Replacing Merino
# Replacing Luna
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Zaragoza
# Replacing Aragon
# Replacing NASS
# Replacing Gabriel
# Replacing Ortega
# Replacing Marin
# Replacing Lemos
# Replacing Madrid
# Replacing Angeles
# Replacing Guerra
# Replacing Ciudad
# Replacing Zamora
# Replacing Castilla
# Replacing Leon
# Replacing Pintor
# Replacing Manuela
# Replacing Avila
# Replacing Ortiz
# Replacing Cajal
# Replacing Morales
# Replacing Meseguer
# Replacing blanca
# Replacing Eduardo
# Replacing Dato
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Emilio
# Replacing Luque
# Replacing Soler
# Replacing Lemos
# Replacing Madrid
# Replacing Sergi
# Replacing Saez
# Replacing Gimenez
# Replacing Vega
# Replacing Ciudad
# Replacing Cuenca
# Replacing Castilla
# Replacing NASS
# Replacing Hector
# Replacing Benitez
# Replacing Rivero
# Replacing Lemos
# Replacing Madrid
# Replacing Luz
# Replacing coche
# Replacing iris
# Replacing Agustin
# Replacing Vidal
# Replacing Zamora
# Replacing Bernardo
# Replacing Ciudad
# Replacing Leon
# Replacing Castilla
# Replacing Leon
# Replacing Mateo
# Replacing Macias
# Replacing Blazquez
# Replacing Lemos
# Replacing Madrid
# Replacing Milagros
# Replacing Aranda
# Replacing Benito
# Replacing Luna
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Tomas
# Replacing Sanchez
# Replacing Luna
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing firma
# Replacing Miguel
# Replacing Pacheco
# Replacing Castaño
# Replacing Prado
# Replacing Ciudad
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Carpintero
# Replacing Maria
# Replacing Esther
# Replacing Santamaria
# Replacing Ferrer
# Replacing Pidal
# Replacing Santa
# Replacing Creu
# Replacing Sant
# Replacing coche
# Replacing Paloma
# Replacing Carrillo
# Replacing Rueda
# Replacing Ciudad
# Replacing Ciudad
# ...
# Replacing Ciudad
# Replacing Sevilla
# Replacing NASS
# Replacing Belen
# Replacing Rivera
# Replacing Calvo
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Patricia
# Replacing Aparicio
# Replacing Carrillo
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Bernal
# Replacing Parra
# Replacing Cajal
# Replacing coche
# Replacing Roberto
# Replacing Plaza
# Replacing Robles
# Replacing Ciudad
# Replacing Islas
# Replacing NASS
# Replacing Rivero
# Replacing Soler
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing Lidia
# Replacing Aparicio
# Replacing Costa
# Replacing Valverde
# Replacing Ciudad
# Replacing Leon
# Replacing German
# Replacing Montoya
# Replacing Lorenzo
# Replacing Lemos
# Replacing Madrid
# Replacing Galan
# Replacing Santos
# Replacing Ciudad
# Replacing Islas
# Replacing NASS
# Replacing Francisco
# Replacing Manuel
# Replacing Pardo
# Replacing Carmona
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing blanca
# Replacing Herrero
# Replacing Ciudad
# Replacing Teruel
# Replacing Aragon
# Replacing Pintor
# Replacing Fernando
# Replacing Escudero
# Replacing Jimenez
# Replacing Cajal
# Replacing Tamara
# Replacing Galan
# Replacing Bravo
# Replacing Ciudad
# Replacing Gandia
# Replacing Alava
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Beatriz
# Replacing Marquez
# Replacing Delgado
# Replacing Lemos
# Replacing Madrid
# Replacing Salamanca
# Replacing Maria
# Replacing Plaza
# Replacing Parra
# Replacing Jesus
# Replacing Maria
# Replacing Ciudad
# Replacing Burgos
# Replacing Castellon
# Replacing NASS
# Replacing Raquel
# Replacing Marin
# Replacing Guzman
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Carlos
# Replacing coche
# Replacing Maria
# Replacing Pilar
# Replacing Mateo
# Replacing Soriano
# Replacing Ciudad
# Replacing Caceres
# Replacing Albacete
# Replacing Castilla
# Replacing NASS
# Replacing Luisa
# Replacing Escobar
# Replacing Dominguez
# Replacing Lemos
# Replacing Madrid
# Replacing Olga
# Replacing Benito
# Replacing Torres
# Replacing Ciudad
# Replacing Sebastian
# Replacing NASS
# Replacing Ignacio
# Replacing Fuente
# Replacing Silva
# Replacing Pidal
# Replacing David
# Replacing Blanco
# Replacing Santos
# Replacing Jardines
# Replacing Ciudad
# Replacing Lugo
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Maria
# Replacing Teresa
# Replacing Gonzalez
# Replacing Escobar
# Replacing Madrid
# Replacing Collado
# Replacing Villalba
# Replacing iris
# Replacing Benitez
# Replacing Espinosa
# Replacing Ferraz
# Replacing Ciudad
# Replacing Vicente
# Replacing Galicia
# Replacing Angel
# Replacing Ortega
# Replacing Estevez
# Replacing Pidal
# Replacing Villalba
# Replacing coche
# Replacing Borja
# Replacing Montero
# Replacing Conde
# Replacing Segovia
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Cuenca
# Replacing Castilla
# Replacing Jose
# Replacing Maria
# Replacing Molina
# Replacing Montero
# Replacing Cajal
# Replacing Juan
# Replacing Manuel
# Replacing Ortega
# Replacing Pereira
# Replacing Cruces
# Replacing Ciudad
# Replacing Tarragona
# Replacing NASS
# Replacing Angel
# Replacing Jurado
# Replacing Campos
# Replacing Lemos
# Replacing Madrid
# Replacing firma
# Replacing Aurora
# Replacing Romero
# Replacing Calderon
# Replacing Bravo
# Replacing Murillo
# Replacing Ciudad
# Replacing Zamora
# Replacing Navarra
# Replacing Navarra
# Replacing Joaquin
# Replacing Rios
# Replacing Aparicio
# Replacing Lemos
# Replacing Madrid
# Replacing Negrin
# Replacing coche
# Replacing firma
# Replacing Valeria
# Replacing Flores
# Replacing Soler
# Replacing Ciudad
# Replacing Fernando
# Replacing Pais
# Replacing Vasco
# Replacing Magdalena
# Replacing Jurado
# Replacing Lemos
# Replacing Madrid
# Replacing Vall
# Replacing coche
# Replacing Maria
# Replacing Luisa
# Replacing Navarro
# Replacing Rivas
# Replacing Ciudad
# Replacing Teruel
# Replacing NASS
# Replacing Maria
# Replacing Rosario
# Replacing Vazquez
# Replacing Paredes
# Replacing Lemos
# Replacing Madrid
# Replacing Malaga
# Replacing prima
# Replacing firma
# Replacing Carlos
# Replacing Tomas
# Replacing Roman
# Replacing Covarrubias
# Replacing Ciudad
# Replacing Lugo
# Replacing Galicia
# Replacing NASS
# Replacing Isabel
# Replacing Delgado
# Replacing Guerra
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing coche
# Replacing Ford
# Replacing Moises
# Replacing Hidalgo
# Replacing Vicente
# Replacing Sagasta
# Replacing Ciudad
# Replacing Alcobendas
# Replacing Islas
# Replacing Santiago
# Replacing Roldan
# Replacing Arroyo
# Replacing Pidal
# Replacing Silvia
# Replacing Rubio
# Replacing Muñoz
# Replacing Pedro
# Replacing Ciudad
# Replacing Galicia
# Replacing NASS
# Replacing Francisco
# Replacing Jose
# Replacing Benitez
# Replacing Gimenez
# Replacing Cajal
# Replacing Torrejon
# Replacing Roman
# Replacing Montero
# Replacing Santa
# Replacing Engracia
# Replacing Ciudad
# Replacing Eibar
# Replacing Zaragoza
# Replacing Aragon
# Replacing Prieto
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing Serra
# Replacing Roca
# Replacing Ciudad
# Replacing Lugo
# Replacing Mallorca
# Replacing Islas
# Replacing NASS
# Replacing Tamara
# Replacing Rodriguez
# Replacing Marcos
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing blanca
# Replacing Merino
# Replacing Bernal
# Replacing Ciudad
# Replacing Castellon
# Replacing NASS
# Replacing Nicolas
# Replacing Lara
# Replacing Quintana
# Replacing Pidal
# Replacing Maria
# Replacing Nieves
# Replacing Ruiz
# Replacing Ciudad
# Replacing NASS
# Replacing Maria
# Replacing Angeles
# Replacing Galvez
# Replacing Castro
# Replacing Lemos
# Replacing Madrid
# Replacing iris
# Replacing Claudia
# Replacing Galvez
# Replacing Casado
# Replacing Ciudad
# Replacing Islas
# Replacing Angel
# Replacing Aparicio
# Replacing Aranda
# Replacing Lemos
# Replacing Madrid
# Replacing Basurto
# Replacing coche
# Replacing Valentina
# Replacing Castillo
# Replacing Soto
# Replacing Zurbano
# Replacing Ciudad
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Ana
# Replacing Belen
# Replacing Bernal
# Replacing Pacheco
# Replacing Lemos
# Replacing Madrid
# Replacing Latina
# Replacing firma
# Replacing Martin
# Replacing Perez
# Replacing Guerrero
# Replacing Alameda
# Replacing Ciudad
# Replacing Alava
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Matilde
# Replacing Marti
# Replacing Costa
# Replacing Lemos
# Replacing Madrid
# Replacing Cartagena
# Replacing coche
# Replacing Estefania
# Replacing Serra
# Replacing Martin
# Replacing Ciudad
# Replacing Caceres
# Replacing NASS
# Replacing Juan
# Replacing Trujillo
# Replacing Martin
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Carlos
# Replacing iris
# Replacing Hector
# Replacing Reyes
# Replacing Marcos
# Replacing Ciudad
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Alfonso
# Replacing Gomez
# Replacing Muñoz
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Tomas
# Replacing Campos
# Replacing Pascual
# Replacing Leon
# Replacing Ciudad
# Replacing Vigo
# Replacing NASS
# Replacing Pintor
# Replacing Robles
# Replacing Ortega
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Ford
# Replacing firma
# Replacing Gregorio
# Replacing Dominguez
# Replacing Sanz
# Replacing Paz
# Replacing Ciudad
# Replacing Parla
# Replacing Islas
# Replacing NASS
# Replacing Aaron
# Replacing Alonso
# Replacing Cajal
# Replacing Malaga
# Replacing coche
# Replacing firma
# Replacing Albert
# Replacing Gallardo
# Replacing Morales
# Replacing Huertas
# Replacing Ciudad
# Replacing Elda
# Replacing Miguel
# Replacing Angel
# Replacing Hernandez
# Replacing Martinez
# Replacing Pidal
# Replacing Macarena
# Replacing firma
# Replacing Marin
# Replacing Rojas
# Replacing Vega
# Replacing Ciudad
# Replacing Madrid
# Replacing Madrid
# Replacing Maria
# Replacing Paz
# Replacing Jurado
# Replacing Beltran
# Replacing Cajal
# Replacing Adolfo
# Replacing Parra
# Replacing Arias
# Replacing Ciudad
# Replacing Ponferrada
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Juan
# Replacing Ramon
# Replacing Duran
# Replacing Gutierrez
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Carlos
# Replacing Carlos
# Replacing Bravo
# Replacing Beltran
# Replacing Esquerdo
# Replacing Ciudad
# Replacing Albacete
# Replacing Castilla
# Replacing NASS
# Replacing Herrero
# Replacing Suarez
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Pedro
# Replacing Parra
# Replacing Marin
# Replacing Claudio
# Replacing Coello
# Replacing Ciudad
# Replacing Gijon
# Replacing Galicia
# Replacing NASS
# Replacing Maria
# Replacing Cristina
# Replacing Fernandez
# Replacing Cruz
# Replacing Lemos
# Replacing Madrid
# Replacing Zamora
# Replacing Salazar
# Replacing Covarrubias
# Replacing Ciudad
# Replacing Carrillo
# Replacing Silva
# Replacing Lemos
# Replacing Madrid
# Replacing Reina
# Replacing Sofia
# Replacing Jose
# Replacing Vicente
# Replacing Sanchez
# Replacing Vazquez
# Replacing Millan
# Replacing Ciudad
# Replacing Jaen
# Replacing Avila
# Replacing Castilla
# Replacing Leon
# Replacing Fatima
# Replacing Dominguez
# Replacing Madrid
# Replacing Maria
# Replacing Teresa
# Replacing Serra
# Replacing Pacheco
# Replacing Ciudad
# Replacing Caceres
# Replacing NASS
# Replacing Marcos
# Replacing Mendez
# Replacing Vega
# Replacing Lemos
# Replacing Madrid
# Replacing Cruces
# Replacing blanca
# Replacing Santos
# Replacing Menendez
# Replacing Pedro
# Replacing Ciudad
# Replacing Segovia
# Replacing Castilla
# Replacing Leon
# Replacing Maria
# Replacing Rosario
# Replacing Andres
# Replacing Lemos
# Replacing Madrid
# Replacing Juan
# Replacing Carlos
# Replacing coche
# Replacing Andres
# Replacing Camacho
# Replacing Soler
# Replacing Ciudad
# Replacing Madrid
# Replacing Madrid
# Replacing NASS
# Replacing Adriana
# Replacing Villar
# Replacing Vera
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Audi
# Replacing Abel
# Replacing Otero
# Replacing Silva
# Replacing Ciudad
# Replacing NASS
# Replacing Mariano
# Replacing Roldan
# Replacing Lorenzo
# Replacing Cajal
# Replacing Collado
# Replacing Villalba
# Replacing iris
# Replacing Cristina
# Replacing Serrano
# Replacing Marcos
# Replacing Ciudad
# Replacing Fernando
# Replacing Toledo
# Replacing Castilla
# Replacing NASS
# Replacing Arturo
# Replacing Rojas
# Replacing Vazquez
# Replacing Lemos
# Replacing Madrid
# Replacing Lidia
# Replacing Avila
# Replacing Mateo
# Replacing Ciudad
# Replacing Castellon
# Replacing Plana
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Trujillo
# Replacing Lemos
# Replacing Madrid
# Replacing Parla
# Replacing Hector
# Replacing Velasco
# Replacing Marquez
# Replacing Ciudad
# Replacing Madrid
# Replacing Madrid
# Replacing NASS
# Replacing Susana
# Replacing Pereira
# Replacing Guzman
# Replacing Lemos
# Replacing Madrid
# Replacing David
# Replacing Gimenez
# Replacing Rivas
# Replacing Olivar
# Replacing Ciudad
# Replacing Ignacio
# Replacing Herrera
# Replacing Cajal
# Replacing Lugo
# Replacing Ahmed
# Replacing Macias
# Replacing Jimenez
# Replacing Eduardo
# Replacing Dato
# Replacing Ciudad
# Replacing Jaca
# Replacing Islas
# Replacing NASS
# Replacing Andrea
# Replacing Martinez
# Replacing Pastor
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing Manuel
# Replacing Jesus
# Replacing Diez
# Replacing Guillen
# Replacing Almagro
# Replacing Ciudad
# Replacing Gandia
# Replacing NASS
# Replacing Pintor
# Replacing Lourdes
# Replacing Otero
# Replacing Peña
# Replacing Madrid
# Replacing Leon
# Replacing coche
# Replacing Ford
# Replacing Claudia
# Replacing Serrano
# Replacing Parra
# Replacing Infantas
# Replacing Ciudad
# Replacing Castellon
# Replacing Manuel
# Replacing Varela
# Replacing Torres
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing firma
# Replacing Maria
# Replacing Josefa
# Replacing Nuñez
# Replacing Zamora
# Replacing Ciudad
# Replacing Burgos
# Replacing Murcia
# Replacing Murcia
# Replacing NASS
# Replacing Ana
# Replacing Isabel
# Replacing Dominguez
# Replacing Madrid
# Replacing Cruces
# Replacing coche
# Replacing Ford
# Replacing Joaquin
# Replacing Nieto
# Replacing Gallego
# Replacing Santa
# Replacing Ana
# Replacing Ciudad
# Replacing Reus
# Replacing Sevilla
# Replacing NASS
# Replacing Paula
# Replacing Cabrera
# Replacing Muñoz
# Replacing Lemos
# Replacing Madrid
# Replacing Alcala
# Replacing Henares
# Replacing Adam
# Replacing Simon
# Replacing Villanueva
# Replacing Santa
# Replacing Ana
# Replacing Ciudad
# Replacing Vizcaya
# Replacing Pais
# Replacing Vasco
# Replacing NASS
# Replacing Hurtado
# Replacing Merino
# Replacing Cajal
# Replacing Ochoa
# Replacing coche
# Replacing Maria
# Replacing Carmen
# Replacing Arias
# Replacing Ribera
# Replacing Ciudad
# Replacing Aranda
# Replacing Duero
# Replacing Mallorca
# Replacing Islas
# Replacing NASS
# Replacing Lidia
# Replacing Bermudez
# Replacing Vargas
# Replacing Lemos
# Replacing Madrid
# Replacing Latina
# Replacing Paloma
# Replacing Ibañez
# Replacing Saez
# Replacing Ciudad
# Replacing Vilanova
# Replacing Castilla
# Replacing Maria
# Replacing Hernandez
# Replacing Medina
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing blanca
# Replacing Belen
# Replacing Ferrer
# Replacing Gomez
# Replacing Ciudad
# Replacing Zaragoza
# Replacing Jaen
# Replacing NASS
# Replacing Rebeca
# Replacing Silva
# Replacing Jimenez
# Replacing Lemos
# Replacing Madrid
# Replacing Cartagena
# Replacing Maria
# Replacing Vazquez
# Replacing Gallego
# Replacing Ciudad
# Replacing Jaca
# Replacing Jaen
# Replacing Maria
# Replacing Soledad
# Replacing Alvarez
# Replacing Vega
# Replacing Lemos
# Replacing Madrid
# Replacing Principe
# Replacing Angeles
# Replacing Camacho
# Replacing Esquerdo
# Replacing Ciudad
# Replacing Ciudad
# Replacing NASS
# Replacing Raul
# Replacing Andres
# Replacing Casas
# Replacing Cajal
# Replacing Ramon
# Replacing Cajal
# Replacing Robles
# Replacing Rivera
# Replacing Ciudad
# Replacing Sevilla
# Replacing Jonathan
# Replacing Salas
# Replacing Salas
# Replacing Lemos
# Replacing Madrid
# Replacing Torre
# Replacing blanca
# Replacing Jaume
# Replacing Vicente
# Replacing Velasco
# Replacing Zurbano
# Replacing Ciudad
# Replacing Malaga
# Replacing NASS
# Replacing Elisa
# Replacing Martinez
# Replacing Pascual
# Replacing Lemos
# Replacing Madrid
# Replacing Lugo
# Replacing Maria
# Replacing Lourdes
# Replacing Villanueva
# Replacing Fernandez
# Replacing Cruces
# Replacing Ciudad
# Replacing Linares
# Replacing Zamora
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Vazquez
# Replacing Gracia
# Replacing Lemos
# Replacing Madrid
# Replacing Sevilla
# Replacing firma
# Replacing Clara
# Replacing Vazquez
# Replacing Carrasco
# Replacing Rollo
# Replacing Ciudad
# Replacing Zamora
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Moises
# Replacing Hernandez
# Replacing Camacho
# Replacing Lemos
# Replacing Madrid
# Replacing Jose
# Replacing Ramon
# Replacing Exposito
# Replacing Ciudad
# Replacing Alba
# Replacing Menendez
# Replacing Vidal
# Replacing Cajal
# Replacing Malaga
# Replacing Ana
# Replacing Maria
# Replacing Cruz
# Replacing Casado
# Replacing Ciudad
# Replacing Alcazar
# Replacing Zamora
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Marco
# Replacing Cano
# Replacing Ortiz
# Replacing Pidal
# Replacing blanca
# Replacing iris
# Replacing Maria
# Replacing Elena
# Replacing Santamaria
# Replacing Rivero
# Replacing Ciudad
# Replacing Valencia
# Replacing Elisa
# Replacing Vazquez
# Replacing Abad
# Replacing Cajal
# Replacing Macarena
# Replacing Aurora
# Replacing Padilla
# Replacing Aguilar
# Replacing Ciudad
# Replacing Maria
# Replacing Angeles
# Replacing Marin
# Replacing Montoya
# Replacing Lemos
# Replacing Madrid
# Replacing Alcala
# Replacing Henares
# Replacing Miriam
# Replacing Salas
# Replacing Pascual
# Replacing Covarrubias
# Replacing Ciudad
# Replacing NASS
# Replacing Samuel
# Replacing Hidalgo
# Replacing Aparicio
# Replacing Lemos
# Replacing Madrid
# Replacing coche
# Replacing Mercedes
# Replacing Benz
# Replacing Concepcion
# Replacing Sanchez
# Replacing Arias
# Replacing Nuncio
# Replacing Ciudad
# Replacing Castellon
# Replacing NASS
# Replacing Ricardo
# Replacing Pacheco
# Replacing Lemos
# Replacing Madrid
# Replacing Silvia
# Replacing Carrasco
# Replacing Lopez
# Replacing Bravo
# Replacing Murillo
# Replacing Ciudad
# Replacing Vicente
# Replacing Madrid
# Replacing Madrid
# Replacing NASS
# Replacing Casas
# Replacing Martinez
# Replacing Cajal
# Replacing Malaga
# Replacing Maria
# Replacing Rosario
# Replacing Herrera
# Replacing Garrido
# Replacing Santa
# Replacing Ana
# Replacing Ciudad
# Replacing Salamanca
# Replacing Ciudad
# Replacing Castilla
# Replacing NASS
# Replacing Sofia
# Replacing Zamora
# Replacing Bermudez
# Replacing Pidal
# Replacing Leon
# Replacing coche
# Replacing Oliver
# Replacing Abad
# Replacing Montoya
# Replacing Ciudad
# Replacing Ubeda
# Replacing Salamanca
# Replacing Castilla
# Replacing Leon
# Replacing NASS
# Replacing Pintor
# Replacing Adriana
# Replacing Redondo
# Replacing Santos
# Replacing Cajal
# Replacing Alcala
# Replacing Henares
# Replacing coche
# Replacing Fernando
# Replacing Mendez
# Replacing Diez
# Replacing Ciudad
# Replacing Cesar
# Replacing Vega
# Replacing Alonso
# Replacing Lemos
# Replacing Madrid

# %%
documents[documents['anonymized'].str.contains('XPERSONAX', case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             original  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: María Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGénero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCódigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTeléfono fijo: +34 960 66 89 48\nTeléfono móvil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondición de riesgo: Científico de Investigación\n\nDatos asistenciales.\nMédico: Dr. Juan Ramón Benito Vicente. NC 097900390. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clínico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGénero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijón, La Rioja, La Rioja\nCódigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTeléfono fijo: +34 941 29 92 15\nTeléfono móvil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondición de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMédico: Dr. Eric Alarcon Pascual. NC 646335336. Neurólogo Investigador en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Málaga Oeste\nMatrícula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clínico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tía. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGénero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCódigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTeléfono fijo: +34 972 65 06 71\nTeléfono móvil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondición de riesgo: Trabajador de Sanitización\n\nDatos asistenciales.\nMédico: Dra. Emma Vicente Santos. NC 588434040. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartín\n\nInforme clínico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGénero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragón\nCódigo postal: 44075\nEmail: manuela@uca.es\nTeléfono fijo: +34 978 49 11 69\nTeléfono móvil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMédico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clínico del paciente:\nPaciente judío de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGénero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCódigo postal: 07533\nEmail: alejandro@ciberned.es\nTeléfono fijo: +34 971 59 71 11\nTeléfono móvil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondición de riesgo: Soldador\n\nDatos asistenciales.\nMédico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepción Sánchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGénero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellón, Comunidad Valenciana\nCódigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTeléfono fijo: +34 964 68 03 70\nTeléfono móvil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMédico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clínico en Enfermedades Digestivas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clínico del paciente:\nPaciente de ascendencia indígena sudamericana de 13 años de edad, acompañado de su madre. Se realizó un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco López\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGénero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCódigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTeléfono fijo: +34 913 43 68 26\nTeléfono móvil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMédico: Dra. Remedios Casas Martínez. NC 002225764. Residente de 3° año en Oftalmología. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Málaga Oeste\n\nInforme clínico del paciente:\nPaciente exfumador de 59 años de edad. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: María Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGénero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCódigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTeléfono fijo: +34 926 82 07 12\nTeléfono móvil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondición de riesgo: Soldado\n\nDatos asistenciales.\nMédico: Dra. Sofía Zamora Bermudez. NC 674953567. Investigadora Clínica en Medicina Interna. Instituto Maimónides de Investigación Biomédica de Córdoba (IMIBIC). Avenida Menéndez Pidal, s/n. 14004. Córdoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de León\nMatrícula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGénero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Úbeda, Salamanca, Castilla y León\nCódigo postal: 37590\nEmail: montoya@ciberehd.org\nTeléfono fijo: +34 923 00 92 67\nTeléfono móvil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondición de riesgo: Pintor de Construcción\n\nDatos asistenciales.\nMédico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcalá de Henares\nMatrícula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clínico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.239.21, con dirección MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Méndez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGénero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCódigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTeléfono fijo: +34 942 14 64 21\nTeléfono móvil: +34 742 35 80 90\nNHC: 8508366\nCondición de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMédico: Dr. César Vega Alonso. NC 585819417. Residente de 5° año en Neurología. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática de 88 años de edad, acompañado de su hijo. El servidor para envío de información desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         preprocessed  \
# 0                                                                                                                                                                                                Datos del paciente.\nNombre: Maria Soledad Moreno Roca\nDNI: 23556552K\nFecha de nacimiento: 09/01/1941\nGenero: Mujer\nDomicilio: Calle de Almagro 80\nCiudad: Denia, Valencia, Comunidad Valenciana\nCodigo postal: 46571\nEmail: mariasoledad_roca@ucm.es\nTelefono fijo: +34 960 66 89 48\nTelefono movil: +34 660 57 14 97\nNHC: 2409425\nNASS: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. Juan Ramon Benito Vicente. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 05/06/1996\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                         Datos del paciente.\nNombre: Victoria Plaza Roca\nDNI: 75398682J\nFecha de nacimiento: 27/09/2014\nGenero: F\nDomicilio: Calle de Arganzuela 18\nCiudad: Gijon, La Rioja, La Rioja\nCodigo postal: 26167\nEmail: victoria_roca@ciberer.es\nTelefono fijo: +34 941 29 92 15\nTelefono movil: +34 641 97 74 21\nNHC: 1980495\nNASS: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. Eric Alarcon Pascual. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 21/10/2021\nEpisodio: 24822158\nCentro de salud: Centro de Salud Malaga Oeste\nMatricula del coche: 5267NPH\nModelo: Mercedes-Benz C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del iris, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                            Datos del paciente.\nNombre: Iñigo Escobar Rivero\nDNI: 97790373P\nFecha de nacimiento: 08/09/1944\nGenero: Masculino\nDomicilio: Calle de los Embajadores 88\nCiudad: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: inigo-escobar@imibic.org\nTelefono fijo: +34 972 65 06 71\nTelefono movil: +34 772 38 57 17\nNHC: 8245120\nNASS: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. Emma Vicente Santos. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Cordoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 24/02/1975\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Manuela Morales Cabrera\nDNI: 67539363R\nFecha de nacimiento: 11/01/1989\nGenero: Mujer\nDomicilio: Calle de Embajadores 61, 6X\nCiudad: Elda, Teruel, Aragon\nCodigo postal: 44075\nEmail: manuela@uca.es\nTelefono fijo: +34 978 49 11 69\nTelefono movil: +34 678 44 45 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. Susana Carmona Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 09/03/2025\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                  Datos del paciente.\nNombre: Alejandro Mendoza Galvez\nDNI: 61787147Q\nFecha de nacimiento: 04/12/1958\nGenero: H\nDomicilio: Calle de la Luna 65\nCiudad: Palma, Ibiza, Islas Baleares\nCodigo postal: 07533\nEmail: alejandro@ciberned.es\nTelefono fijo: +34 971 59 71 11\nTelefono movil: +34 671 86 66 04\nNHC: 8587216\nNASS: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. Omar Guerrero Maldonado. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/09/1966\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 995                                                                                                                Datos del paciente.\nNombre: Concepcion Sanchez Arias\nDNI: 63635019E\nFecha de nacimiento: 03/02/1949\nGenero: Femenino\nDomicilio: Calle del Nuncio 16\nCiudad: Guadix, Castellon, Comunidad Valenciana\nCodigo postal: 12646\nEmail: concepcion.sanchez.arias1330@aol.com\nTelefono fijo: +34 964 68 03 70\nTelefono movil: +34 664 54 58 16\nNHC: 2353890\nNASS: 300045530855\n\nDatos asistenciales.\nMedico: Dr. Ricardo Pacheco Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 09/02/1962\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                               Datos del paciente.\nNombre: Silvia Carrasco Lopez\nDNI: 73772873M\nFecha de nacimiento: 03/02/1947\nGenero: M\nDomicilio: Calle de Bravo Murillo 69\nCiudad: San Vicente del Raspeig, Madrid, Madrid\nCodigo postal: 28907\nEmail: silvia.carrasco195@gmail.com\nTelefono fijo: +34 913 43 68 26\nTelefono movil: +34 615 72 09 54\nNHC: 5151310\nNASS: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios Casas Martinez. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 20/07/2006\nEpisodio: 03975462\nCentro de salud: Centro de Salud Malaga Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                 Datos del paciente.\nNombre: Maria Rosario Herrera Garrido\nDNI: 41285166M\nFecha de nacimiento: 18/05/2012\nGenero: Mujer\nDomicilio: Calle de Santa Ana 46\nCiudad: Salamanca, Ciudad Real, Castilla-La Mancha\nCodigo postal: 13729\nEmail: mariarosariogarrido@hotmail.com\nTelefono fijo: +34 926 82 07 12\nTelefono movil: +34 626 67 72 55\nNHC: 6375672\nNASS: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. Sofia Zamora Bermudez. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de Cordoba (IMIBIC). Avenida Menendez Pidal, s/n. 14004. Cordoba. España.\nFecha de ingreso: 19/07/2018\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de Leon\nMatricula del coche: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: Oliver Abad Montoya\nDNI: 59660306P\nFecha de nacimiento: 04/02/1966\nGenero: H\nDomicilio: Calle de la Princesa 96\nCiudad: Ubeda, Salamanca, Castilla y Leon\nCodigo postal: 37590\nEmail: montoya@ciberehd.org\nTelefono fijo: +34 923 00 92 67\nTelefono movil: +34 623 81 70 60\nNHC: 0395567\nNASS: 855689108455\nCondicion de riesgo: Pintor de Construccion\n\nDatos asistenciales.\nMedico: Dra. Adriana Redondo Santos. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida Ramon y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/04/1984\nEpisodio: 32673391\nCentro de salud: Centro de Salud Alcala de Henares\nMatricula del coche: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                         Datos del paciente.\nNombre: Fernando Mendez Diez\nDNI: 51881861W\nFecha de nacimiento: 15/07/1933\nGenero: V\nDomicilio: Calle de Piamonte 89, 2Q\nCiudad: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: fernandodiez@yahoo.com\nTelefono fijo: +34 942 14 64 21\nTelefono movil: +34 742 35 80 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. Cesar Vega Alonso. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/03/2022\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               anonymized
# 0                                                                                                                                                                                                                                Datos del paciente.\nNombre: XPERSONAX\nDNI: 23556552K\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX XPERSONAX 80\nXPERSONAX: Denia, XPERSONAX, Comunidad Valenciana\nCodigo postal: 46571\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 48\nTelefono movil: +34 6XFECHAX 97\nNHC: 2409425\nXPERSONAX: 468043486571\nCondicion de riesgo: Cientifico de Investigacion\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 097900390. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nCentro de salud: Centro de Salud Carabanchel\n\nInforme clinico del paciente:\nPaciente sobreviviente de violencia de 55 años de edad, acompañado de su madre.
# 1                              Datos del paciente.\nNombre: XPERSONAX\nDNI: 75398682J\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX Arganzuela 18\nXPERSONAX: XPERSONAX, XZONAX, XZONAX\nCodigo postal: 26167\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 15\nTelefono movil: +34 6XFECHAX 21\nNHC: 1980495\nXPERSONAX: 620412206059\nCondicion de riesgo: Operador de Maquinaria Pesada\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 646335336. Neurologo Investigador en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 24822158\nCentro de salud: Centro de Salud XPERSONAX Oeste\nMatricula del XPERSONAX: 5267NPH\nModelo: XPERSONAX-XPERSONAX C-Class\nVIN: VSL4HQZ1ZGI361218\n\nInforme clinico del paciente:\nPaciente de ascendencia australiana de 7 años de edad, acompañado de su tia. Se registro una sesion de escaneo del XPERSONAX, el codigo obtenido para revisarla es KJ369UZN325.
# 2                                                                                                                                                                                                                                                                   Datos del paciente.\nNombre: XPERSONAX\nDNI: 97790373P\nFecha de nacimiento: XFECHAX\nGenero: Masculino\nDomicilio: Calle  XDIRECCIONX los Embajadores 88\nXPERSONAX: Telde, Gerona, Cataluña\nCodigo postal: 17012\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 71\nTelefono movil: +34 7XFECHAX 17\nNHC: 8245120\nXPERSONAX: 724651062765\nCondicion de riesgo: Trabajador de Sanitizacion\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX. NC 588434040. Neurologa Investigadora en Trastornos Cognitivos. Instituto de Investigacion Sanitaria del Hospital 12 de XFECHAX (Imas12). Avenida  XDIRECCIONX XZONAX, s/n. 28041. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 00580872\nCentro de salud: Centro de Salud Chamartin\n\nInforme clinico del paciente:\nPaciente migrante de 30 años de edad.
# 3                                                                                                                                                                                                                                                                                                                             Datos del paciente.\nNombre: XPERSONAX\nDNI: 67539363R\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Embajadores 61, 6X\nXPERSONAX: XPERSONAX, XPERSONAX, XPERSONAX\nCodigo postal: 44075\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 69\nTelefono movil: +34 6XFECHAX 86\nNHC: 6194951\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX Rey. NC 610597653. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX XPERSONAX, s/n. 14004. XZONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 50535453\nCentro de salud: Centro de Salud Valdemoro\n\nInforme clinico del paciente:\nPaciente judio de 36 años de edad, acompañado de su amigo.
# 4                                                                                                                                                                                                 Datos del paciente.\nNombre: XPERSONAX XZONAX XPERSONAX\nDNI: 61787147Q\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la XPERSONAX 65\nXPERSONAX: XPERSONAX, Ibiza, XPERSONAX Baleares\nCodigo postal: 07533\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 11\nTelefono movil: +34 6XFECHAX 04\nNHC: 8587216\nXPERSONAX: 368106130992\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 298972407. Cardiologo Especialista en Electrofisiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 07261286\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia nordica o escandinava de 7 años de edad, acompañado de su abuela.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 995                                                                                                                                                  Datos del paciente.\nNombre: XPERSONAX\nDNI: 63635019E\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle  XDIRECCIONX XPERSONAX 16\nXPERSONAX: Guadix, XPERSONAX, Comunidad Valenciana\nCodigo postal: 12646\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 70\nTelefono movil: +34 6XFECHAX 16\nNHC: 2353890\nXPERSONAX: 300045530855\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX Rey. NC 158928507. Investigador Clinico en Enfermedades Digestivas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 21493589\nCentro de salud: Centro de Salud Barajas\n\nInforme clinico del paciente:\nPaciente de ascendencia indigena sudamericana de 13 años de edad, acompañado de su madre. Se realizo un expediente con URL http://example-hospital.org//65390546H.
# 996                                                                                                                                                                                                                Datos del paciente.\nNombre: XPERSONAX\nDNI: 73772873M\nFecha de nacimiento: XFECHAX\nGenero: M\nDomicilio: Calle  XDIRECCIONX XPERSONAX 69\nXPERSONAX: San XPERSONAX del Raspeig, XPERSONAX, XPERSONAX\nCodigo postal: 28907\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 26\nTelefono movil: +34 6XFECHAX 54\nNHC: 5151310\nXPERSONAX: 021771724443\n\nDatos asistenciales.\nMedico: Dra. Remedios XPERSONAX. NC 002225764. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y XPERSONAX, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 03975462\nCentro de salud: Centro de Salud XPERSONAX Oeste\n\nInforme clinico del paciente:\nPaciente exfumador de 59 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es NQ616NVL105.
# 997                                                                                                                                                   Datos del paciente.\nNombre: XPERSONAX\nDNI: 41285166M\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX XPERSONAX 46\nXPERSONAX: XPERSONAX, XPERSONAX Real, XPERSONAX-La Mancha\nCodigo postal: 13729\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 12\nTelefono movil: +34 6XFECHAX 55\nNHC: 6375672\nXPERSONAX: 458155862406\nCondicion de riesgo: Soldado\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX. NC 674953567. Investigadora Clinica en Medicina Interna. Instituto Maimonides de Investigacion Biomedica de XZONAX (IMIBIC). Avenida  XDIRECCIONX XPERSONAX, s/n. 14004. XZONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 36901283\nHospital: Complejo Asistencial Universitario de XPERSONAX\nMatricula del XPERSONAX: 7294RBK\nModelo: Honda CR-V\nVIN: VSJ4KULILXW135919\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 6 años de edad, acompañado de su madre.
# 998  Datos del paciente.\nNombre: XPERSONAX\nDNI: 59660306P\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la Princesa 96\nXPERSONAX: XPERSONAX, XPERSONAX, XPERSONAX y XPERSONAX\nCodigo postal: 37590\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 67\nTelefono movil: +34 6XFECHAX 60\nNHC: 0395567\nXPERSONAX: 855689108455\nCondicion de riesgo: XPERSONAX de Construccion\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX. NC 093560057. Investigadora Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y XPERSONAX, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 32673391\nCentro de salud: Centro de Salud XPERSONAX de XPERSONAX\nMatricula del XPERSONAX: 2787ODO\nModelo: Honda Civic\nVIN: VSWN31846HJ039414\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 18 años de edad, acompañado de su abuelo. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.239.21, con direccion MAC 00:ED:A8:79:88:14.
# 999                                                                                                                                                  Datos del paciente.\nNombre: XPERSONAX\nDNI: 51881861W\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle  XDIRECCIONX Piamonte 89, 2Q\nXPERSONAX: Totana, Cantabria, Cantabria\nCodigo postal: 39179\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 21\nTelefono movil: +34 7XFECHAX 90\nNHC: 8508366\nCondicion de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 585819417. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 58126454\nCentro de salud: Centro de Salud Moratalaz\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica de 88 años de edad, acompañado de su hijo. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-cardiology.com.
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### DRX

# %%
# ## Expresión regular para DRX

# # Distancia máxima tolerada entre el token trigger y el último que puede ser marcado como esa entidad.
# dist_token = 15

# # originales-------------------------------------------
# #titulos = '((?<=\.| )|^)dr(?=(a|\.| ))|doctor(a?)|((?<=\.| )|^)licenciad[a|o]|((?<=\.| )|^)lic(\.| ?)'
# #-------------------------------------------------------

# regexp_drx = re.compile(r'((?<=\.| )|^)dr(?=(a|\.| |$))|doctor(a?)|((?<=\.| )|^)licenciad[a|o]|((?<=\.| )|^)lic(\.| ?)',
#                         re.IGNORECASE)

# regexp_drx_mayusculas = re.compile(r'^[A-Z]{1}[a-z]+')

# def deidentificar_drx(texto_a_deidentificar):
#     # Genero la lista a partir del texto_preprocesado de esa fila
#     lista_texto_a_deidentificar = re.split('([\.,:\? -])',texto_a_deidentificar)
    
#     ## Iteración entre tokens de la lista del texto a deidentificar
#     drx_flag = False
#     for j,token in enumerate(lista_texto_a_deidentificar):
#         # A partir del segundo token
#         if j > 0:
#             # Si el token actual es precedido por dr/doc,etc
#             if regexp_drx.search(lista_texto_a_deidentificar[j-1]):
#                 drx_flag=True
#                 pos_token = j
#                 # Si el token actual comienza con mayúscula
# #                 if (lista_texto_a_deidentificar[j].lower() in lista_nombres) or regexp_drx_mayusculas.search(lista_texto_a_deidentificar[j]):
# #                 # Reemplazar el token actual por el patrón correspondiente
# #                     if output_tipo==1:
# #                         lista_texto_a_deidentificar[j] = '<'+ lista_texto_a_deidentificar[j] +'>'
# #                     if output_tipo==2:
# #                         lista_texto_a_deidentificar[j] = 'XXXX'
# #                     if output_tipo==3:
# #                         lista_texto_a_deidentificar[j] = '<DRX>'
#             # Si el token actual es un nombre o apellido
# #             if drx == True and (lista_texto_a_deidentificar[j].lower() in lista_nombres or regexp_drx_mayusculas.search(lista_texto_a_deidentificar[j])) and j-pos_token<dist_token:
#             if drx_flag == True and (lista_texto_a_deidentificar[j]=='XPERSONAX' and j-pos_token<dist_token):
#                     # Reemplazar el token actual por el patrón correspondiente
#                     if output_tipo==1:
#                         lista_texto_a_deidentificar[j] = '<'+ lista_texto_a_deidentificar[j] +'>'
#                     if output_tipo==2:
#                         lista_texto_a_deidentificar[j] = 'XXXX'
#                     if output_tipo==3:
#                         lista_texto_a_deidentificar[j] = 'XDRXX'    
# #             else:
# #                 drx_flag == False
    
#     # Generar el texto deidentificado concatenando todos los tokens ya revisados (y modificados si corrrespondiera)
#     return ''.join(lista_texto_a_deidentificar)
    
# textos_a_deidentificar['texto_anonimizado'] = textos_a_deidentificar['texto_anonimizado'].apply(deidentificar_drx)
# #     Aclarar por qué busco en listas (minus y mayus())

# %% [markdown]
# ### EPOF
#
# Enfermedades poco frecuentes

# %%
epof = pd.read_csv("./datasets/epof.csv", names=['enfermedad'], header=None)
lista_epof = epof['enfermedad'].to_list()
lista_epof[:10]
# Out:
# ['Abetalipoproteinemia',
#  'Abscesos asépticos sensibles a corticosteroides',
#  'Acalasia - microcefalia',
#  'Acalasia idiopática',
#  'Acalvaria',
#  'Acatalasemia',
#  'Accidente cerebrovascular isquémico pediátrico',
#  'Aceruloplasminemia',
#  'Acidemia isovalérica',
#  'Acidemia malónica y metilmalónica combinada']

# %%
epof_names = set([
    remove_accents(name).strip()
    for name in lista_epof if len(name) > 1 and not re.search(ILLEGAL_CHAR_REGEX, name)
])

regexp_epof = '|'.join(epof_names)

epof_anonymizer = RegexAnnonimizer(
    content_regex=regexp_epof,
    category='XEPoFX',
    re_flags=re.IGNORECASE,
    output_type=OUTPUT_TYPE,
)

print(epof_anonymizer.anonymize("Paciente presenta acalvaria aguda."))
print(epof_anonymizer.anonymize("Paciente presenta Acidemia malonica y metilmalonica combinada."))
# Out:
# Paciente presenta XEPoFX aguda.
# Paciente presenta XEPoFX.

# %%
documents['anonymized'] = documents['anonymized'].apply(epof_anonymizer.anonymize)

# %%
documents[documents['anonymized'].str.contains('XEPoFX', case=False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 original  \
# 42                                                                                                                                                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Vanessa Fernández Hidalgo\nDNI: 81323063P\nFecha de nacimiento: 06/10/1955\nGénero: M\nDomicilio: Calle de Amor de Dios 75, 4N\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52956\nEmail: vanessahidalgo536@gmail.com\nTeléfono fijo: +34 956 49 68 35\nTeléfono móvil: +34 756 27 78 89\nNHC: 0359081\nNASS: 066639713897\nCondición de riesgo: Conductor de Camión\n\nDatos asistenciales.\nMédico: Dra. Noemí Santos Valero. NC 493742703. Investigadora Principal en Parkinson. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 12/03/1984\nHospital: Hospital Clínic Universitario de Valencia\nMatrícula del coche: 1694JZP\nModelo: Ram 1500\nVIN: VSCYFG5QP0R652821\n\nInforme clínico del paciente:\nPaciente vegetariano de 28 años de edad.
# 62                                                                                                                                                                                                                                                                                                                                                                                               Datos del paciente.\nNombre: Miriam Contreras Escudero\nDNI: 80827695Z\nFecha de nacimiento: 09/05/2004\nGénero: M\nDomicilio: Calle del Duque de Alba 58\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52023\nEmail: LS0mn@uhu.es\nTeléfono fijo: +34 956 46 20 02\nTeléfono móvil: +34 656 90 48 64\nNHC: 5163263\nNASS: 781658362040\n\nDatos asistenciales.\nMédico: Dra. María Antonia López Robles. NC 049471038. Psiquiatra Especialista en Trastornos de Ansiedad. Instituto de Investigación Biomédica en Red de Salud Mental (CIBERSAM). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 28/02/2024\nHospital: Hospital General Universitario Morales Meseguer\nMatrícula del coche: 4463EXT\nModelo: Ford F-150\nVIN: VSLHNKB2R9G964314\n\nInforme clínico del paciente:\nPaciente fumador de 19 años de edad, acompañado de su compañero de trabajo.
# 80                                                                                                                                                                                                                 Datos del paciente.\nNombre: Rebeca Miguel Gallego\nDNI: 63116393T\nFecha de nacimiento: 23/05/1931\nGénero: Mujer\nDomicilio: Calle de los Jardines 63\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52076\nEmail: rebeca.gallego@ucm.es\nTeléfono fijo: +34 956 45 98 95\nTeléfono móvil: +34 756 94 94 29\nNHC: 1308614\nNASS: 159849869885\nCondición de riesgo: Conductor de Camión\n\nDatos asistenciales.\nMédico: Dra. Laia Mora Blazquez. NC 889514124. Residente de 4° año en Cardiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 26/05/1998\nEpisodio: 55830169\nHospital: Hospital Universitario de Fuenlabrada\n\nInforme clínico del paciente:\nPaciente usuario de drogas de 67 años de edad, acompañado de su padre. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.158.179, con dirección MAC C2:DC:65:68:94:73. Se realizó un expediente con URL http://example-cardiology.com//10205126J.
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: Bruno Nieto Lorenzo\nDNI: 40505628Y\nFecha de nacimiento: 09/09/1993\nGénero: V\nDomicilio: Calle de los Relatores 47\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52398\nEmail: bruno-nieto@isciii.es\nTeléfono fijo: +34 956 18 24 69\nTeléfono móvil: +34 756 88 11 96\nNHC: 1217030\nCondición de riesgo: Trabajador de la Construcción\n\nDatos asistenciales.\nMédico: Dra. Andrea Suárez Nieto. NC 019378803. Psiquiatra Especialista en Trastornos de Ansiedad. Instituto de Investigación Biomédica en Red de Salud Mental (CIBERSAM). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 17/02/1997\nCentro de salud: Centro de Salud Leganés\n\nInforme clínico del paciente:\nPaciente de tez blanca de 3 años de edad, acompañado de su padre.
# 98                                                                                                                                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: Sebastián Espinosa Flores\nDNI: 75812855W\nFecha de nacimiento: 29/04/1969\nGénero: H\nDomicilio: Calle de Arenal 3\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51940\nEmail: sebastian.espinosa-flores@ioba.med.uva.es\nTeléfono fijo: +34 951 17 35 28\nTeléfono móvil: +34 651 62 85 28\nNHC: 8846957\nNASS: 797769606499\nCondición de riesgo: Trabajador Industrial\n\nDatos asistenciales.\nMédico: Dra. Carla Román Marti. NC 694260634. Investigadora Principal en Parkinson. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 02/03/2008\nHospital: Complejo Asistencial Universitario de León\n\nInforme clínico del paciente:\nPaciente no fumador de 38 años de edad, acompañado de su madre.
# 209                                                                                                                        Datos del paciente.\nNombre: Milagros Aranda Benito\nDNI: 44975688Q\nFecha de nacimiento: 06/07/1966\nGénero: Femenino\nDomicilio: Calle de la Luna 24\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52190\nEmail: milagrosaranda.benito@ciberned.es\nTeléfono fijo: +34 956 04 99 72\nTeléfono móvil: +34 756 77 59 06\nNHC: 6589713\nNASS: 375116329149\nCondición de riesgo: Bombero\n\nDatos asistenciales.\nMédico: Dr. Tomás Sánchez Luna. NC 569383045. Cardiólogo Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 23/09/2005\nCentro de salud: Centro de Salud Centro\nMatrícula del coche: 2829TXZ\nModelo: Subaru Outback\nVIN: VSPT9KHK7WI495241\n\nInforme clínico del paciente:\nPaciente refugiado de 39 años de edad. Se realizó un expediente con URL http://example-nutrition.net//83288308Z. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es KV906CWG103. Se registró una sesión de firma biométrica, el código obtenido para revisarla es VN139ZEL949.
# 218                                                                                                                                                                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: Josefa Pacheco Segura\nDNI: 48618113T\nFecha de nacimiento: 04/11/2001\nGénero: F\nDomicilio: Calle de Génova 49\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52070\nEmail: pacheco.segura@protonmail.com\nTeléfono fijo: +34 956 96 54 88\nTeléfono móvil: +34 656 51 50 37\nNHC: 9819169\n\nDatos asistenciales.\nMédico: Dra. Mireia Gracia Pascual. NC 612881659. Investigadora Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 17/12/2018\nEpisodio: 89920251\nCentro de salud: Centro de Salud Ciudad Lineal\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 17 años de edad, acompañado de su madre. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es MD387AER506.
# 243                                                                                                                                                                                                                                                                     Datos del paciente.\nNombre: Óscar Beltran Trujillo\nDNI: 73543695E\nFecha de nacimiento: 01/12/1941\nGénero: Masculino\nDomicilio: Calle Gran Vía 65\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52135\nEmail: oscar.beltran_trujillo@uca.es\nTeléfono fijo: +34 956 78 51 27\nTeléfono móvil: +34 656 78 40 00\nNHC: 0664225\nNASS: 795699898019\nCondición de riesgo: Conductor de Camión\n\nDatos asistenciales.\nMédico: Dr. Jaume Estevez Vera. NC 801420829. Oftalmólogo Especialista en Retina y Vítreo. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 25/12/1979\nHospital: Hospital Regional Universitario de Málaga\nMatrícula del coche: 6235QWR\nModelo: Audi A4\nVIN: VSE6YXHQMVL979299\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática occidental de 38 años de edad, acompañado de su tía. Se registró una sesión de huella dactilar, el código obtenido para revisarla es LE324ZQX076.
# 284                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Datos del paciente.\nNombre: Ricardo Zamora Ortiz\nDNI: 60983530L\nFecha de nacimiento: 09/02/1971\nGénero: Hombre\nDomicilio: Calle de Arenal 95, 7C\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51558\nEmail: zamora_ortiz503@yahoo.com\nTeléfono fijo: +34 951 83 21 10\nTeléfono móvil: +34 651 40 79 61\nNHC: 6125325\nCondición de riesgo: Ingeniero de Minas\n\nDatos asistenciales.\nMédico: Dra. Anna Bernal Palacios. NC 511294970. Neuropsicóloga Clínica Investigadora. Instituto de Investigación Biomédica en Red de Salud Mental (CIBERSAM). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 16/07/1983\nHospital: Hospital Clínic Barcelona\n\nInforme clínico del paciente:\nPaciente no fumador de 12 años de edad, acompañado de su padre.
# 445                                                                                                                                                                                                                                                                                                                                                                                                                                                           Datos del paciente.\nNombre: María Ángeles Alarcon Mora\nDNI: 16931452W\nFecha de nacimiento: 07/01/2022\nGénero: F\nDomicilio: Calle del Carmen 92\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52034\nEmail: mariaangeles@gmail.com\nTeléfono fijo: +34 956 37 80 31\nFAX: +34 956 84 79 42\nNHC: 0968086\nNASS: 477276161848\n\nDatos asistenciales.\nMédico: Dra. Yolanda Suárez Mateos. NC 310874369. Investigadora Clínica en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 27/01/2022\nEpisodio: 54449904\nHospital: Hospital Universitario 12 de Octubre\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática del sudeste de 0 meses de edad, acompañado de su madre.
# 463                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Datos del paciente.\nNombre: Laia Redondo Abad\nDNI: 60400915V\nFecha de nacimiento: 26/08/1987\nGénero: M\nDomicilio: Calle del Doctor Esquerdo 34, 2H\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52049\nEmail: redondo459@icloud.com\nTeléfono fijo: +34 956 40 95 03\nFAX: +34 956 17 88 97\nNHC: 4100988\nCondición de riesgo: Bombero\n\nDatos asistenciales.\nMédico: Dra. Juana Castro Martínez. NC 368172197. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 17/08/2024\nEpisodio: 17863030\nHospital: Hospital Universitario Puerta de Hierro Majadahonda\n\nInforme clínico del paciente:\nPaciente de ascendencia norteamericana de 36 años de edad.
# 498  Datos del paciente.\nNombre: Xavier Herrera Aguilar\nDNI: 39360761X\nFecha de nacimiento: 27/10/1946\nGénero: V\nDomicilio: Calle de Tribulete 72\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51914\nEmail: xavier_herrera@outlook.com\nTeléfono fijo: +34 951 42 69 77\nTeléfono móvil: +34 651 27 66 91\nNHC: 6190610\nNASS: 642744127754\nCondición de riesgo: Plomero\n\nDatos asistenciales.\nMédico: Dr. Santiago Cortés Lorenzo. NC 203002972. Residente de 3° año en Gastroenterología. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 01/11/1964\nEpisodio: 13464367\nHospital: Hospital Universitario Fundación Alcorcón\nMatrícula del coche: 4563ZSN\nModelo: Chrysler Pacifica\nVIN: VSJ3CWR4Y8Q304398\n\nInforme clínico del paciente:\nPaciente de ascendencia nórdica o escandinava de 18 años de edad. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.110.124, con dirección MAC 46:F6:AB:D5:69:C6. Se registró una sesión de reconocimiento facial, el código obtenido para revisarla es AL671HAO335. Se registró una sesión de escaneo del iris, el código obtenido para revisarla es SB043TNM849.
# 510                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Datos del paciente.\nNombre: Margarita Mesa Montes\nDNI: 25029760X\nFecha de nacimiento: 15/10/1979\nGénero: M\nDomicilio: Calle de Bravo Murillo 36\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52345\nEmail: margarita.mesa@isciii.es\nTeléfono fijo: +34 956 79 83 84\nFAX: +34 956 12 08 62\nNHC: 4515471\nNASS: 822648843065\nCondición de riesgo: Soldado\n\nDatos asistenciales.\nMédico: Dr. Isaac Menendez Santamaria. NC 640556070. Investigador Principal en Parkinson. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 29/08/2023\nEpisodio: 25916759\nCentro de salud: Centro de Salud Majadahonda\n\nInforme clínico del paciente:\nPaciente vegetariano de 43 años de edad.
# 524                                                                                                                                                                                                                                                                                                   Datos del paciente.\nNombre: Mercedes Beltran Montoya\nDNI: 68322144T\nFecha de nacimiento: 22/08/1952\nGénero: Femenino\nDomicilio: Calle de los Embajadores 64\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52074\nEmail: mercedes.beltran@hotmail.com\nTeléfono fijo: +34 956 71 07 50\nFAX: +34 956 80 63 32\nNHC: 6347371\nNASS: 329354521318\nCondición de riesgo: Técnico de Laboratorio\n\nDatos asistenciales.\nMédico: Dra. Amparo Varela Beltran. NC 470629422. Neuróloga Investigadora en Trastornos Cognitivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 05/03/2009\nEpisodio: 57734972\nCentro de salud: Centro de Salud Sevilla Este\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática occidental de 56 años de edad, acompañado de su hijo. Se registró una sesión de reconocimiento facial, el código obtenido para revisarla es KO906ILU647.
# 547                                                                                                                                                            Datos del paciente.\nNombre: María Rosa Lozano Miranda\nDNI: 20350984D\nFecha de nacimiento: 16/07/1986\nGénero: F\nDomicilio: Calle de Amor de Dios 97, 10Q\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51044\nEmail: miranda@hotmail.com\nTeléfono fijo: +34 951 03 28 83\nTeléfono móvil: +34 751 42 88 96\nNHC: 1250188\nNASS: 190324521773\n\nDatos asistenciales.\nMédico: Dra. Vanessa Nieto Conde. NC 901605918. Investigadora Clínica en Enfermedades Digestivas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 30/01/2000\nEpisodio: 51306672\nHospital: Hospital Universitario Virgen Macarena\nMatrícula del coche: 4609EQK\nModelo: Toyota Corolla\nVIN: VSKOO3S1INU647944\n\nInforme clínico del paciente:\nPaciente musulman de 13 años de edad, acompañado de su hermano. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es BL762DNM310. Se registró una sesión de reconocimiento facial, el código obtenido para revisarla es SX439NGY377.
# 640                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: María Luz Conde Carrillo\nDNI: 88099852P\nFecha de nacimiento: 06/03/1973\nGénero: Mujer\nDomicilio: Calle de Santa Ana 9, 10N\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52630\nEmail: IulYmW0Z3lZExK4@ciberisciii.es\nTeléfono fijo: +34 956 66 28 82\nFAX: +34 956 41 06 84\nNHC: 3418229\nNASS: 266167109904\n\nDatos asistenciales.\nMédico: Dr. Marcos Blanco Marti. NC 050179597. Investigador Clínico en Síndromes Raros. Instituto de Investigación Biomédica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 12/08/1999\nHospital: Hospital Universitario Marqués de Valdecilla\n\nInforme clínico del paciente:\nPaciente de ascendencia caribeña de 26 años de edad.
# 644                                                                                                                                                                                                                                                                                                                                                                     Datos del paciente.\nNombre: Natalia Cano Suárez\nDNI: 61332652R\nFecha de nacimiento: 14/11/1989\nGénero: Femenino\nDomicilio: Calle Gran Vía 79\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52575\nEmail: natalia_cano@ciberned.es\nTeléfono fijo: +34 956 85 41 26\nTeléfono móvil: +34 656 08 54 80\nNHC: 1630125\nNASS: 670505373324\nCondición de riesgo: Fabricante\n\nDatos asistenciales.\nMédico: Dra. Cristina Gracia Fernández. NC 627314050. Cardióloga de Unidad de Cuidados Intensivos. Instituto de Investigación Sanitaria del Hospital 12 de Octubre (Imas12). Avenida de Córdoba, s/n. 28041. Madrid. España.\nFecha de ingreso: 31/01/2018\nEpisodio: 08882203\nCentro de salud: Centro de Salud Sevilla Este\nMatrícula del coche: 5317CKK\nModelo: Jeep Wrangler\nVIN: VSGKG2Q7F9H803708\n\nInforme clínico del paciente:\nPaciente musulman de 28 años de edad, acompañado de su hermana.
# 700                                                                                                                                                                                                                                                                                                              Datos del paciente.\nNombre: Ana Herrera Rivas\nDNI: 82534257E\nFecha de nacimiento: 30/06/1949\nGénero: M\nDomicilio: Calle de Santa Engracia 10\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52155\nEmail: rivas@ucm.es\nTeléfono fijo: +34 956 34 78 95\nTeléfono móvil: +34 656 71 31 49\nNHC: 1476793\nNASS: 124451101646\n\nDatos asistenciales.\nMédico: Dra. Andrea Guzman Carmona. NC 366241767. Cardióloga Especialista en Electrofisiología. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 17/07/1967\nEpisodio: 04835992\nCentro de salud: Centro de Salud Moratalaz\nMatrícula del coche: 1191RIN\nModelo: Volkswagen Golf\nVIN: VSRXLWKCMAR934741\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 18 años de edad, acompañado de su suegro. Se realizó un expediente con URL http://example-biotech.com//95125132Y.
# 709                                                                                                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Elvira Caballero Aranda\nDNI: 78765721J\nFecha de nacimiento: 02/05/1987\nGénero: M\nDomicilio: Calle de Velázquez 40, 8E\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52479\nEmail: elvira-caballero@yahoo.com\nTeléfono fijo: +34 956 45 81 11\nTeléfono móvil: +34 656 98 22 29\nNHC: 9419549\nNASS: 677193997607\n\nDatos asistenciales.\nMédico: Dra. María Josefa Lorenzo Montoya. NC 098958079. Investigadora Clínica en Insuficiencia Cardíaca. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 11/04/2023\nEpisodio: 79617729\nHospital: Hospital General Universitario Morales Meseguer\nMatrícula del coche: 4927SFV\nModelo: Ford Mustang\nVIN: VSCSZ3K4VFS313964\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática occidental de 35 años de edad, acompañado de su vecino.
# 726                                                                                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: Antonio Prieto De la Fuente\nDNI: 83723615G\nFecha de nacimiento: 09/06/1940\nGénero: V\nDomicilio: Calle del Amparo 52\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51073\nEmail: delafuente@icloud.com\nTeléfono fijo: +34 951 25 46 52\nTeléfono móvil: +34 651 49 74 64\nNHC: 2053236\nNASS: 475203107872\nCondición de riesgo: Policía\n\nDatos asistenciales.\nMédico: Dra. Irene Arias Blazquez. NC 352267669. Residente de 3° año en Gastroenterología. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 17/04/1995\nHospital: Hospital Universitari i Politècnic La Fe\nMatrícula del coche: 6691ZOC\nModelo: Chevrolet Silverado\nVIN: VSNTFVCOARZ349039\n\nInforme clínico del paciente:\nPaciente no fumador de 54 años de edad.
# 729                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: Rosa María Quintana Gil\nDNI: 95198621B\nFecha de nacimiento: 13/03/1942\nGénero: F\nDomicilio: Calle de la Ribera 68, 10E\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52182\nEmail: rosamariaquintana1903@icloud.com\nTeléfono fijo: +34 956 55 64 28\nTeléfono móvil: +34 756 17 16 51\nNHC: 7504458\nNASS: 072218479509\nCondición de riesgo: Trabajador de Laboratorio\n\nDatos asistenciales.\nMédico: Dr. Christian Lozano Alarcon. NC 136978874. Investigador Clínico en Síndromes Raros. Instituto de Investigación Biomédica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 02/08/1946\nEpisodio: 06795099\nHospital: Hospital Universitario Rey Juan Carlos de Mostoles\nMatrícula del coche: 9965TKB\nModelo: Honda Civic\nVIN: VSVYHZBEMBB254114\n\nInforme clínico del paciente:\nPaciente de comunidades vulnerables de 4 años de edad, acompañado de su madre.
# 730                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Mariano León Moya\nDNI: 68052475Y\nFecha de nacimiento: 07/06/1995\nGénero: Varón\nDomicilio: Calle del Marqués de Urquijo 51\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52226\nEmail: marianomoya@protonmail.com\nTeléfono fijo: +34 956 35 06 42\nFAX: +34 956 44 31 32\nNHC: 4035050\nCondición de riesgo: Trabajador de Mantenimiento\n\nDatos asistenciales.\nMédico: Dra. Almudena Parra Rivera. NC 339608598. Investigadora Clínica en Insuficiencia Cardíaca. Instituto de Investigación Biomédica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 07/09/2015\nEpisodio: 33917524\nHospital: Hospital Universitario Ramón y Cajal\nMatrícula del coche: 2420CBZ\nModelo: Chrysler Pacifica\nVIN: VSS2C99Y38I511154\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática occidental de 20 años de edad. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es MN175OSA832.
# 809                                                                                                                                                                                                                                                                                                                                           Datos del paciente.\nNombre: Héctor Flores Alarcon\nDNI: 26941999Y\nFecha de nacimiento: 04/01/1985\nGénero: H\nDomicilio: Calle de la Ribera 75\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52259\nEmail: BDhSlkAX@salud.madrid.org\nTeléfono fijo: +34 956 80 56 58\nTeléfono móvil: +34 756 07 98 58\nNHC: 7203477\nNASS: 963355106495\nCondición de riesgo: Técnico de Laboratorio\n\nDatos asistenciales.\nMédico: Dr. Javier Luque Mendoza. NC 368739438. Investigador Clínico en Epidemiología. Instituto de Investigación Biomédica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 21/10/2023\nEpisodio: 60653003\nHospital: Hospital General Universitario Morales Meseguer\nMatrícula del coche: 6001RYO\nModelo: BMW 3 Series\nVIN: VSLB2058BKR316540\n\nInforme clínico del paciente:\nPaciente musulman de 38 años de edad, acompañado de su hija.
# 815                                                                                                                                                                                                                                                                                                                                                                           Datos del paciente.\nNombre: Teresa Marín Medina\nDNI: 95353721E\nFecha de nacimiento: 20/10/1967\nGénero: F\nDomicilio: Calle de Moratín 89, 2A\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51106\nEmail: teresa.medina@ioba.med.uva.es\nTeléfono fijo: +34 951 89 74 23\nTeléfono móvil: +34 751 67 38 04\nNHC: 5963870\nNASS: 192341723709\n\nDatos asistenciales.\nMédico: Dra. Ariadna Rubio Vázquez. NC 049383306. Residente de 3° año en Oftalmología. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 30/06/1986\nEpisodio: 16833008\nCentro de salud: Centro de Salud Alhaurín de la Torre\n\nInforme clínico del paciente:\nPaciente usuario de drogas de 18 años de edad, acompañado de su hija. El servidor para envío de información desde cual el usuario se comunica es smtp://example-clinica.com.
# 817                                                                                                                                                                                                                                                                                    Datos del paciente.\nNombre: María Antonia Vázquez Aparicio\nDNI: 90799702A\nFecha de nacimiento: 29/07/2020\nGénero: Mujer\nDomicilio: Calle de Don Ramón de la Cruz 40, 6P\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51737\nEmail: mariaantonia.vazquez_aparicio1461@uca.es\nTeléfono fijo: +34 951 55 19 78\nTeléfono móvil: +34 651 84 18 91\nNHC: 7575995\nNASS: 243342363049\n\nDatos asistenciales.\nMédico: Dr. Roberto Moya Silva. NC 517564913. Gastroenterólogo Especialista en Enfermedades Hepáticas. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 17/10/2024\nEpisodio: 48065133\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clínico del paciente:\nPaciente de ascendencia asiática occidental de 4 años de edad, acompañado de su abuela. Se registró una sesión de huella dactilar, el código obtenido para revisarla es KR282FRG961.
# 822                                                                                                                                                                                                                      Datos del paciente.\nNombre: Aitor Sierra Manzano\nDNI: 60804925D\nFecha de nacimiento: 05/05/2009\nGénero: Hombre\nDomicilio: Calle de Covarrubias 55, 10B\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52241\nEmail: aitorsierra_manzano@aol.com\nTeléfono fijo: +34 956 09 68 03\nTeléfono móvil: +34 756 58 38 98\nNHC: 7791366\nNASS: 132605996404\nCondición de riesgo: Paramédico\n\nDatos asistenciales.\nMédico: Dra. Adriana Román Carrillo. NC 884723911. Especialista en Genética Médica. Instituto de Investigación Biomédica en Red de Enfermedades Raras (CIBERER). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 21/05/2023\nEpisodio: 68840571\nCentro de salud: Centro de Salud San Blas\n\nInforme clínico del paciente:\nPaciente de ascendencia sudamericana de 14 años de edad, acompañado de su hermana. El servidor para envío de información desde cual el usuario se comunica es smtp://example-research.net. Se registró una sesión de firma biométrica, el código obtenido para revisarla es WM837VZU514.
# 885                                                                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Consuelo Bernal Castillo\nDNI: 51053703M\nFecha de nacimiento: 29/11/1948\nGénero: M\nDomicilio: Calle del Carmen 1\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51024\nEmail: bernal-castillo@ub.edu\nTeléfono fijo: +34 951 20 23 87\nFAX: +34 951 91 96 35\nNHC: 3401525\nNASS: 029613204305\nCondición de riesgo: Policía\n\nDatos asistenciales.\nMédico: Dra. María Nieves Ramos Cortés. NC 076719061. Residente de 3° año en Gastroenterología. Instituto de Investigación Biomédica en Red de Enfermedades Hepáticas y Digestivas (CIBERehd). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 12/06/1981\nEpisodio: 95260304\nCentro de salud: Centro de Salud Carabanchel\nMatrícula del coche: 2793TUE\nModelo: Audi A4\nVIN: VSCRS9OP1FI445400\n\nInforme clínico del paciente:\nPaciente vegano de 32 años de edad. Se registró una sesión de huella dactilar, el código obtenido para revisarla es PD766JLF710.
# 890                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: Inés Ortiz Montes\nDNI: 26332127W\nFecha de nacimiento: 10/12/2012\nGénero: Mujer\nDomicilio: Calle de Argumosa 78\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52839\nEmail: ines.montes1672@ciberehd.org\nTeléfono fijo: +34 956 28 37 49\nFAX: +34 956 17 15 98\nNHC: 8266637\nNASS: 484408915295\nCondición de riesgo: Paramédico\n\nDatos asistenciales.\nMédico: Dr. Valentín Ruiz Carmona. NC 310562934. Residente de 5° año en Neurología. Instituto de Investigación Biomédica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 19/02/2022\nEpisodio: 67592056\nCentro de salud: Centro de Salud Collado Villalba\n\nInforme clínico del paciente:\nPaciente consumidor de alcohol de 9 años de edad, acompañado de su abuela. Se registró una consulta virtual desde la dirección IP (en red interna) 192.168.6.81, con dirección MAC 48:61:8E:0C:E6:F6.
# 907                                                                                                                                                                                                                                                                                                                                                                                                                                     Datos del paciente.\nNombre: José Antonio Prieto Giménez\nDNI: 41169184N\nFecha de nacimiento: 10/10/1948\nGénero: Varón\nDomicilio: Calle de la Cabeza del Rey Don Pedro 39\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52782\nEmail: joseantonioprieto697@ciberer.es\nTeléfono fijo: +34 956 37 39 64\nFAX: +34 956 91 68 92\nNHC: 6733704\nCondición de riesgo: Paramédico\n\nDatos asistenciales.\nMédico: Dr. Alejandro Navarro Ramos. NC 136832138. Neuropsicólogo Clínico Investigador. Instituto de Investigación Biomédica en Red de Salud Mental (CIBERSAM). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 18/01/1963\nEpisodio: 50786388\nHospital: Hospital Universitario de Basurto\n\nInforme clínico del paciente:\nPaciente de ascendencia norteamericana de 14 años de edad, acompañado de su madre.
# 930                                                                                                                                                                                                                                                                                          Datos del paciente.\nNombre: Patricia Aparicio Carrillo\nDNI: 60941715H\nFecha de nacimiento: 23/03/2001\nGénero: Mujer\nDomicilio: Calle de los Relatores 42\nCiudad: Ciudad autónoma de Ceuta, Ceuta, \nCódigo postal: 52230\nEmail: apariciocarrillo@aol.com\nTeléfono fijo: +34 956 32 25 96\nFAX: +34 956 51 97 60\nNHC: 3154216\nNASS: 889071580172\nCondición de riesgo: Electricista\n\nDatos asistenciales.\nMédico: Dr. Pau Bernal Parra. NC 772096285. Investigador Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 09/03/2025\nHospital: Hospital Universitario 12 de Octubre\nMatrícula del coche: 5656ZDQ\nModelo: Nissan Altima\nVIN: VSALBDVTB0Y560199\n\nInforme clínico del paciente:\nPaciente de ascendencia caribeña de 23 años de edad, acompañado de su vecina. Se registró una sesión de escaneo retiniano, el código obtenido para revisarla es UP286CWM593.
# 985                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Datos del paciente.\nNombre: Ángeles Camacho Bueno\nDNI: 68673248D\nFecha de nacimiento: 24/08/1940\nGénero: Femenino\nDomicilio: Calle del Doctor Esquerdo 90\nCiudad: Ciudad autónoma de Melilla, Melilla, \nCódigo postal: 51953\nEmail: angeles.bueno@gmail.com\nTeléfono fijo: +34 951 16 49 44\nTeléfono móvil: +34 751 30 88 68\nNHC: 4995356\nNASS: 680517827981\nCondición de riesgo: Soldador\n\nDatos asistenciales.\nMédico: Dr. Raúl Andres Casas. NC 016217881. Investigador Principal en Optometría Clínica. Instituto Universitario de Oftalmobiología Aplicada (IOBA). Avenida Ramón y Cajal, 7. 47011. Valladolid. España.\nFecha de ingreso: 26/12/1962\nHospital: Hospital Universitario Ramón y Cajal\n\nInforme clínico del paciente:\nPaciente vegano de 22 años de edad.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             preprocessed  \
# 42                                                                                                                                                                                                                                                                                                                                                                                Datos del paciente.\nNombre: Vanessa Fernandez Hidalgo\nDNI: 81323063P\nFecha de nacimiento: 06/10/1955\nGenero: M\nDomicilio: Calle de Amor de Dios 75, 4N\nCiudad: Ciudad autonoma de Ceuta, Ceuta, \nCodigo postal: 52956\nEmail: vanessahidalgo536@gmail.com\nTelefono fijo: +34 956 49 68 35\nTelefono movil: +34 756 27 78 89\nNHC: 0359081\nNASS: 066639713897\nCondicion de riesgo: Conductor de Camion\n\nDatos asistenciales.\nMedico: Dra. Noemi Santos Valero. NC 493742703. Investigadora Principal en Parkinson. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 12/03/1984\nHospital: Hospital Clinic Universitario de Valencia\nMatricula del coche: 1694JZP\nModelo: Ram 1500\nVIN: VSCYFG5QP0R652821\n\nInforme clinico del paciente:\nPaciente vegetariano de 28 años de edad.
# 62                                                                                                                                                                                                                                                                                                                                                                                               Datos del paciente.\nNombre: Miriam Contreras Escudero\nDNI: 80827695Z\nFecha de nacimiento: 09/05/2004\nGenero: M\nDomicilio: Calle del Duque de Alba 58\nCiudad: Ciudad autonoma de Ceuta, Ceuta, \nCodigo postal: 52023\nEmail: LS0mn@uhu.es\nTelefono fijo: +34 956 46 20 02\nTelefono movil: +34 656 90 48 64\nNHC: 5163263\nNASS: 781658362040\n\nDatos asistenciales.\nMedico: Dra. Maria Antonia Lopez Robles. NC 049471038. Psiquiatra Especialista en Trastornos de Ansiedad. Instituto de Investigacion Biomedica en Red de Salud Mental (CIBERSAM). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 28/02/2024\nHospital: Hospital General Universitario Morales Meseguer\nMatricula del coche: 4463EXT\nModelo: Ford F-150\nVIN: VSLHNKB2R9G964314\n\nInforme clinico del paciente:\nPaciente fumador de 19 años de edad, acompañado de su compañero de trabajo.
# 80                                                                                                                                                                                                                 Datos del paciente.\nNombre: Rebeca Miguel Gallego\nDNI: 63116393T\nFecha de nacimiento: 23/05/1931\nGenero: Mujer\nDomicilio: Calle de los Jardines 63\nCiudad: Ciudad autonoma de Ceuta, Ceuta, \nCodigo postal: 52076\nEmail: rebeca.gallego@ucm.es\nTelefono fijo: +34 956 45 98 95\nTelefono movil: +34 756 94 94 29\nNHC: 1308614\nNASS: 159849869885\nCondicion de riesgo: Conductor de Camion\n\nDatos asistenciales.\nMedico: Dra. Laia Mora Blazquez. NC 889514124. Residente de 4° año en Cardiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 26/05/1998\nEpisodio: 55830169\nHospital: Hospital Universitario de Fuenlabrada\n\nInforme clinico del paciente:\nPaciente usuario de drogas de 67 años de edad, acompañado de su padre. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.158.179, con direccion MAC C2:DC:65:68:94:73. Se realizo un expediente con URL http://example-cardiology.com//10205126J.
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: Bruno Nieto Lorenzo\nDNI: 40505628Y\nFecha de nacimiento: 09/09/1993\nGenero: V\nDomicilio: Calle de los Relatores 47\nCiudad: Ciudad autonoma de Ceuta, Ceuta, \nCodigo postal: 52398\nEmail: bruno-nieto@isciii.es\nTelefono fijo: +34 956 18 24 69\nTelefono movil: +34 756 88 11 96\nNHC: 1217030\nCondicion de riesgo: Trabajador de la Construccion\n\nDatos asistenciales.\nMedico: Dra. Andrea Suarez Nieto. NC 019378803. Psiquiatra Especialista en Trastornos de Ansiedad. Instituto de Investigacion Biomedica en Red de Salud Mental (CIBERSAM). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 17/02/1997\nCentro de salud: Centro de Salud Leganes\n\nInforme clinico del paciente:\nPaciente de tez blanca de 3 años de edad, acompañado de su padre.
# 98                                                                                                                                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: Sebastian Espinosa Flores\nDNI: 75812855W\nFecha de nacimiento: 29/04/1969\nGenero: H\nDomicilio: Calle de Arenal 3\nCiudad: Ciudad autonoma de Melilla, Melilla, \nCodigo postal: 51940\nEmail: sebastian.espinosa-flores@ioba.med.uva.es\nTelefono fijo: +34 951 17 35 28\nTelefono movil: +34 651 62 85 28\nNHC: 8846957\nNASS: 797769606499\nCondicion de riesgo: Trabajador Industrial\n\nDatos asistenciales.\nMedico: Dra. Carla Roman Marti. NC 694260634. Investigadora Principal en Parkinson. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida Monforte de Lemos 3-5. 28029. Madrid. España.\nFecha de ingreso: 02/03/2008\nHospital: Complejo Asistencial Universitario de Leon\n\nInforme clinico del paciente:\nPaciente no fumador de 38 años de edad, acompañado de su madre.
# ...
# 726                                                                                                                                                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: XPERSONAX De la XPERSONAX\nDNI: 83723615G\nFecha de nacimiento: XFECHAX\nGenero: V\nDomicilio: Calle  XDIRECCIONX Amparo 52\nXPERSONAX: XPERSONAX autoXEPoFX de Melilla, Melilla, \nCodigo postal: 51073\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 52\nTelefono movil: +34 6XFECHAX 64\nNHC: 2053236\nXPERSONAX: 475203107872\nCondicion de riesgo: Policia\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX. NC 352267669. Residente de 3° año en Gastroenterologia. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitari i Politecnic La Fe\nMatricula del XPERSONAX: 6691ZOC\nModelo: Chevrolet Silverado\nVIN: VSNTFVCOARZ349039\n\nInforme clinico del paciente:\nPaciente no fumador de 54 años de edad.
# 729                                                                                                                                                                                                                                                                                                                                  Datos del paciente.\nNombre: XPERSONAX Gil\nDNI: 95198621B\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX la XPERSONAX 68, 10E\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52182\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 28\nTelefono movil: +34 7XFECHAX 51\nNHC: 7504458\nXPERSONAX: 072218479509\nCondicion de riesgo: Trabajador de Laboratorio\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 136978874. Investigador Clinico en Sindromes Raros. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 06795099\nHospital: Hospital Universitario Rey XPERSONAX de Mostoles\nMatricula del XPERSONAX: 9965TKB\nModelo: Honda Civic\nVIN: VSVYHZBEMBB254114\n\nInforme clinico del paciente:\nPaciente de comunidades vulnerables de 4 años de edad, acompañado de su madre.
# 730                                                                                                                                                                                                                                                Datos del paciente.\nNombre: XPERSONAX\nDNI: 68052475Y\nFecha de nacimiento: XFECHAX\nGenero: Varon\nDomicilio: Calle  XDIRECCIONX XPERSONAX de XPERSONAX 51\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52226\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 42\nFAX: +34 9XFECHAX 32\nNHC: 4035050\nCondicion de riesgo: Trabajador de Mantenimiento\n\nDatos asistenciales.\nMedico: Dra. Almudena XPERSONAX. NC 339608598. Investigadora Clinica en Insuficiencia Cardiaca. Instituto de Investigacion Biomedica en Red de Enfermedades Cardiovasculares (CIBERCV). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 33917524\nHospital: Hospital Universitario XPERSONAX y XPERSONAX\nMatricula del XPERSONAX: 2420CBZ\nModelo: Chrysler Pacifica\nVIN: VSS2C99Y38I511154\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica occidental de 20 años de edad. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es MN175OSA832.
# 809                                                                                                                                                                                                                                                                                                                                                         Datos del paciente.\nNombre: XPERSONAX\nDNI: 26941999Y\nFecha de nacimiento: XFECHAX\nGenero: H\nDomicilio: Calle  XDIRECCIONX la XPERSONAX 75\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52259\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 58\nTelefono movil: +34 7XFECHAX 58\nNHC: 7203477\nXPERSONAX: 963355106495\nCondicion de riesgo: Tecnico de Laboratorio\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX XZONAX. NC 368739438. Investigador Clinico en Epidemiologia. Instituto de Investigacion Biomedica en Red de Enfermedades Infecciosas (CIBERINFEC). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 60653003\nHospital: Hospital General Universitario XPERSONAX\nMatricula del XPERSONAX: 6001RYO\nModelo: BMW 3 Series\nVIN: VSLB2058BKR316540\n\nInforme clinico del paciente:\nPaciente musulman de 38 años de edad, acompañado de su hija.
# 815                                                                                                                                                                                                                                                                                                                                                                                               Datos del paciente.\nNombre: XPERSONAX\nDNI: 95353721E\nFecha de nacimiento: XFECHAX\nGenero: F\nDomicilio: Calle  XDIRECCIONX Moratin 89, 2A\nXPERSONAX: XPERSONAX autoXEPoFX de Melilla, Melilla, \nCodigo postal: 51106\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 23\nTelefono movil: +34 7XFECHAX 04\nNHC: 5963870\nXPERSONAX: 192341723709\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX. NC 049383306. Residente de 3° año en Oftalmologia. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y XPERSONAX, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 16833008\nCentro de salud: Centro de Salud Alhaurin de la XPERSONAX\n\nInforme clinico del paciente:\nPaciente usuario de drogas de 18 años de edad, acompañado de su hija. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-clinica.com.
# 817                                                                                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: XPERSONAX\nDNI: 90799702A\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Don XPERSONAX de la XPERSONAX 40, 6P\nXPERSONAX: XPERSONAX autoXEPoFX de Melilla, Melilla, \nCodigo postal: 51737\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 78\nTelefono movil: +34 6XFECHAX 91\nNHC: 7575995\nXPERSONAX: 243342363049\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 517564913. Gastroenterologo Especialista en Enfermedades Hepaticas. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 48065133\nCentro de salud: Centro de Salud Aranjuez\n\nInforme clinico del paciente:\nPaciente de ascendencia asiatica occidental de 4 años de edad, acompañado de su abuela. Se registro una sesion de huella dactilar, el codigo obtenido para revisarla es KR282FRG961.
# 822                                                                                                                                                                                                                                        Datos del paciente.\nNombre: Aitor XPERSONAX\nDNI: 60804925D\nFecha de nacimiento: XFECHAX\nGenero: Hombre\nDomicilio: Calle  XDIRECCIONX XPERSONAX 55, 10B\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52241\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 03\nTelefono movil: +34 7XFECHAX 98\nNHC: 7791366\nXPERSONAX: 132605996404\nCondicion de riesgo: Paramedico\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX. NC 884723911. Especialista en Genetica Medica. Instituto de Investigacion Biomedica en Red de Enfermedades Raras (CIBERER). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 68840571\nCentro de salud: Centro de Salud XZONAX\n\nInforme clinico del paciente:\nPaciente de ascendencia sudamericana de 14 años de edad, acompañado de su hermana. El servidor para envio de informacion desde cual el usuario se comunica es smtp://example-research.net. Se registro una sesion de XPERSONAX biometrica, el codigo obtenido para revisarla es WM837VZU514.
# 885                                                                                                                                                                                                                                                                                                          Datos del paciente.\nNombre: Consuelo XPERSONAX\nDNI: 51053703M\nFecha de nacimiento: XFECHAX\nGenero: M\nDomicilio: Calle   XDIRECCIONX\nXPERSONAX: XPERSONAX autoXEPoFX de Melilla, Melilla, \nCodigo postal: 51024\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 87\nFAX: +34 9XFECHAX 35\nNHC: 3401525\nXPERSONAX: 029613204305\nCondicion de riesgo: Policia\n\nDatos asistenciales.\nMedico: Dra. XPERSONAX Cortes. NC 076719061. Residente de 3° año en Gastroenterologia. Instituto de Investigacion Biomedica en Red de Enfermedades Hepaticas y Digestivas (CIBERehd). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 95260304\nCentro de salud: Centro de Salud Carabanchel\nMatricula del XPERSONAX: 2793TUE\nModelo: XPERSONAX A4\nVIN: VSCRS9OP1FI445400\n\nInforme clinico del paciente:\nPaciente vegano de 32 años de edad. Se registro una sesion de huella dactilar, el codigo obtenido para revisarla es PD766JLF710.
# 890                                                                                                                                                                                                                                                                                                                                     Datos del paciente.\nNombre: XPERSONAX\nDNI: 26332127W\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX Argumosa 78\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52839\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 49\nFAX: +34 9XFECHAX 98\nNHC: 8266637\nXPERSONAX: 484408915295\nCondicion de riesgo: Paramedico\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 310562934. Residente de 5° año en Neurologia. Instituto de Investigacion Biomedica en Red de Enfermedades Neurodegenerativas (CIBERNED). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 67592056\nCentro de salud: Centro de Salud XPERSONAX\n\nInforme clinico del paciente:\nPaciente consumidor de alcohol de 9 años de edad, acompañado de su abuela. Se registro una consulta virtual desde la direccion IP (en red interna) 192.168.6.81, con direccion MAC 48:61:8E:0C:E6:F6.
# 907                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Datos del paciente.\nNombre: XPERSONAX\nDNI: 41169184N\nFecha de nacimiento: XFECHAX\nGenero: Varon\nDomicilio: Calle  XDIRECCIONX la Cabeza del Rey Don XPERSONAX 39\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52782\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 64\nFAX: +34 9XFECHAX 92\nNHC: 6733704\nCondicion de riesgo: Paramedico\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 136832138. Neuropsicologo Clinico Investigador. Instituto de Investigacion Biomedica en Red de Salud Mental (CIBERSAM). Avenida  XDIRECCIONX de XPERSONAX 3-5. 28029. XPERSONAX. XPAISX.\nFecha de ingreso: XFECHAX\nEpisodio: 50786388\nHospital: Hospital Universitario de XPERSONAX\n\nInforme clinico del paciente:\nPaciente de ascendencia norteamericana de 14 años de edad, acompañado de su madre.
# 930                                                                                                                                                                                                                                                                                                       Datos del paciente.\nNombre: XPERSONAX\nDNI: 60941715H\nFecha de nacimiento: XFECHAX\nGenero: Mujer\nDomicilio: Calle  XDIRECCIONX los Relatores 42\nXPERSONAX: XPERSONAX autoXEPoFX de Ceuta, Ceuta, \nCodigo postal: 52230\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 96\nFAX: +34 9XFECHAX 60\nNHC: 3154216\nXPERSONAX: 889071580172\nCondicion de riesgo: Electricista\n\nDatos asistenciales.\nMedico: Dr. Pau XPERSONAX. NC 772096285. Investigador Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y XPERSONAX, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario 12 de XFECHAX\nMatricula del XPERSONAX: 5656ZDQ\nModelo: Nissan Altima\nVIN: VSALBDVTB0Y560199\n\nInforme clinico del paciente:\nPaciente de ascendencia caribeña de 23 años de edad, acompañado de su vecina. Se registro una sesion de escaneo retiniano, el codigo obtenido para revisarla es UP286CWM593.
# 985                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Datos del paciente.\nNombre: XPERSONAX Bueno\nDNI: 68673248D\nFecha de nacimiento: XFECHAX\nGenero: Femenino\nDomicilio: Calle  XDIRECCIONX Doctor XPERSONAX 90\nXPERSONAX: XPERSONAX autoXEPoFX de Melilla, Melilla, \nCodigo postal: 51953\nEmail: XCORREO_ELECTRONICOX\nTelefono fijo: +34 9XFECHAX 44\nTelefono movil: +34 7XFECHAX 68\nNHC: 4995356\nXPERSONAX: 680517827981\nCondicion de riesgo: Soldador\n\nDatos asistenciales.\nMedico: Dr. XPERSONAX. NC 016217881. Investigador Principal en Optometria Clinica. Instituto Universitario de Oftalmobiologia Aplicada (IOBA). Avenida  XDIRECCIONX y XPERSONAX, 7. 47011. Valladolid. XPAISX.\nFecha de ingreso: XFECHAX\nHospital: Hospital Universitario XPERSONAX y XPERSONAX\n\nInforme clinico del paciente:\nPaciente vegano de 22 años de edad.

# %% [markdown]
# ## 5. Devuelve los datos procesados (output)
#
# ### Transforma entidades

# %% [markdown]
# ## 6. Guarda salida

# %%
documents.shape
output_filename =  '/home/usuario/Documentos/TrabajoEspecial/Modelos/REGEX/b) SPG/out.csv'
print('Saving to:', output_filename)
documents.to_csv(output_filename, sep=',', header=True, index=False)
# Out:
# Saving to: /home/usuario/Documentos/TrabajoEspecial/Modelos/REGEX/b) SPG/out.csv
